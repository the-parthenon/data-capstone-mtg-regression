# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
all_cards = pd.read_csv('cleaned_datasets/allsets_cleaned.csv', index_col=0)

# %%
all_cards.head()
# Out:
#                   name colors  manaValue   manaCost  power  toughness  \
# 0  Aerial Modification      W        5.0     {4}{W}    NaN        NaN
# 1     Aeronaut Admiral      W        4.0     {3}{W}    3.0        1.0
# 2     Aether Inspector      W        4.0     {3}{W}    2.0        3.0
# 3    Aethergeode Miner      W        2.0     {1}{W}    3.0        1.0
# 4    Airdrop Aeronauts      W        5.0  {3}{W}{W}    4.0        3.0
#
#    loyalty                                               text    rarity  \
# 0      NaN  Enchant creature or Vehicle\nAs long as enchan...  uncommon
# 1      NaN          Flying\nVehicles you control have flying.  uncommon
# 2      NaN  Vigilance\nWhen Aether Inspector enters the ba...    common
# 3      NaN  Whenever Aethergeode Miner attacks, you get {E...      rare
# 4      NaN  Flying\nRevolt — When Airdrop Aeronauts enters...  uncommon
#
#          keywords supertypes        types
# 0         Enchant        NaN  Enchantment
# 1          Flying        NaN     Creature
# 2       Vigilance        NaN     Creature
# 3             NaN        NaN     Creature
# 4  Flying, Revolt        NaN     Creature

# %%
all_cards.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7125 entries, 0 to 7124
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        7125 non-null   object
#  1   colors      7125 non-null   object
#  2   manaValue   7125 non-null   float64
#  3   manaCost    6617 non-null   object
#  4   power       3867 non-null   float64
#  5   toughness   3877 non-null   float64
#  6   loyalty     168 non-null    float64
#  7   text        7025 non-null   object
#  8   rarity      7125 non-null   object
#  9   keywords    3399 non-null   object
#  10  supertypes  763 non-null    object
#  11  types       7125 non-null   object
# dtypes: float64(4), object(8)
# memory usage: 723.6+ KB

# %% [markdown]
# NaN values in the `keywords` column are to be expected, as many cards do not have keywords.  We will replace these with empty strings.

# %%
all_cards['keywords'].fillna('', inplace=True)

# %% [markdown]
# I want to get a dataframe that includes only creatures, but first we have to deal with one edge case:  non-creature cards that contain the "Transform" keyword.  I do this by writing out a function that can extract the mana value for cards that are formatted in the following way: "{B}{B}{2}: Transform".  We find the Transform keyword in the text of the card, then grab the string that immediately precedes it, calculate the additional cost to transform the card and add it to the correct cell (which will, in all cases, be the row immediately following the card with the Transform keyword.  This also fixes the mana value for the back sides of modal cards with the Transform keyword that are both creatures.

# %%
all_cards['text'].fillna('', inplace=True)

# %%
all_cards.loc[all_cards.keywords.str.contains('Transform', case=False)]
# Out:
#                                name         colors  manaValue  \
# 1546              Extricator of Sin              W        3.0
# 1557                     Lone Rider              W        2.0
# 1579             Curious Homunculus              U        2.0
# 1582           Docent of Perfection              U        5.0
# 1590                Grizzled Angler              U        3.0
# 1640                Voldaren Pariah              B        5.0
# 1641        Abolisher of Bloodlines              C        5.0
# 1654              Conduit of Storms              R        3.0
# 1674            Smoldering Werewolf              R        4.0
# 1681            Vildin-Pack Outcast              R        5.0
# 1697                 Kessig Prowler              G        1.0
# 1702                  Shrill Howler              G        3.0
# 1709            Tangleclaw Werewolf              G        4.0
# 1711              Ulvenwald Captive              G        2.0
# 1714                    Waxing Moon              G        2.0
# 1728     Ulrich of the Krallenhorde           G, R        5.0
# 1729      Ulrich, Uncontested Alpha           G, R        5.0
# 1731            Cryptolith Fragment              C        3.0
# 3006             Ambitious Farmhand              W        2.0
# 3008                 Beloved Beggar              W        2.0
# 3010              Bereaved Survivor              W        3.0
# 3021               Chaplain of Alms              W        1.0
# 3026                 Enduring Angel              W        5.0
# 3037                Lunarch Veteran              W        1.0
# 3039                Mourning Patrol              W        3.0
# 3054                Baithook Angler              U        2.0
# 3058              Covetous Castaway              U        2.0
# 3061              Delver of Secrets              U        1.0
# 3069                    Galedrifter              U        4.0
# 3076              Malevolent Hermit              U        2.0
# 3079                Mysterious Tome              U        3.0
# 3080             Chilling Chronicle              U        3.0
# 3085          Overwhelmed Archivist              U        3.0
# 3089                Poppet Stitcher              U        3.0
# 3090                 Poppet Factory              U        3.0
# 3113                Covert Cutpurse              B        3.0
# 3123              Ecstatic Awakener              B        1.0
# 3130                Heirloom Mirror              B        2.0
# 3135       Jerren, Corrupted Bishop              B        3.0
# 3154             Vengeful Strangler              B        2.0
# 3171                Flame Channeler              R        2.0
# 3192                 Smoldering Egg              R        2.0
# 3218             Deathbonnet Sprout              G        1.0
# 3258      Dennick, Pious Apprentice           U, W        2.0
# 3260             Devoted Grafkeeper           U, W        2.0
# 3277           Ludevic, Necrogenius           B, U        2.0
# 3278         Olag, Ludevic's Hubris           B, U        2.0
# 3291         Tovolar, Dire Overlord           G, R        3.0
# 3302                   Mystic Skull              C        2.0
# 3310                 Hostile Hostel              L        0.0
# 3500       Nicol Bolas, the Ravager        B, R, U        4.0
# 4044          Befriending the Moths              W        4.0
# 4052           Era of Enlightenment              W        2.0
# 4054         The Fall of Lord Konda              W        3.0
# 4072       Michiko's Reign of Truth              W        2.0
# 4078     The Restoration of Eiganjo              W        3.0
# 4093         Behold the Unspeakable              U        5.0
# 4103            Inventive Iteration              U        4.0
# 4113                 The Modern Age              U        2.0
# 4156        Life of Toshiro Umezawa              B        2.0
# 4158        The Long Reach of Night              B        4.0
# 4167            Okiba Reckoner Raid              B        1.0
# 4175              Tribute to Horobi              B        2.0
# 4193    Fable of the Mirror-Breaker              R        3.0
# 4204          Kumano Faces Kakkazan              R        1.0
# 4215       The Shattered States Era              R        5.0
# 4226          Azusa's Many Journeys              G        2.0
# 4232        Boseiju Reaches Skyward              G        4.0
# 4237         The Dragon-Kami Reborn              G        3.0
# 4251       Jugan Defends the Temple              G        3.0
# 4268        Tales of Master Seshiro              G        5.0
# 4271         Teachings of the Kirin              G        2.0
# 4281         Hidetsugu Consumes All           B, R        3.0
# 4288                   The Kami War  B, G, R, U, W        6.0
# 4649                 Hadana's Climb           G, U        3.0
# 4650        Winged Temple of Orazca              L        3.0
# 4652            Journey to Eternity           B, G        3.0
# 4653        Atzal, Cave of Eternity              L        3.0
# 4658                 Path of Mettle           R, W        2.0
# 4659      Metzali, Tower of Triumph              L        2.0
# 4660             Profane Procession           B, W        3.0
# 4661          Tomb of the Dusk Rose              L        3.0
# 4668                Storm the Vault           R, U        4.0
# 4669              Vault of Catlacan              L        4.0
# 4672                 Azor's Gateway              C        2.0
# 4673             Sanctum of the Sun              L        2.0
# 4676                Golden Guardian              C        4.0
# 4677            Gold-Forge Garrison              L        4.0
# 5208               Archangel Avacyn              W        5.0
# 5209           Avacyn, the Purifier              R        5.0
# 5210         Avacynian Missionaries              W        4.0
# 5211            Lunarch Inquisitors              W        4.0
# 5212            Bound by Moonsilver              W        3.0
# 5226        Hanweir Militia Captain              W        2.0
# 5239                  Pious Evangel              W        3.0
# 5252              Town Gossipmonger              W        1.0
# 5255            Aberrant Researcher              U        4.0
# 5261                  Daring Sleuth              U        2.0
# 5295                 Startled Awake              U        4.0
# 5299               Thing in the Ice              U        2.0
# 5300                  Awoken Horror              U        2.0
# 5302                Uninvited Geist              U        3.0
# 5306                 Accursed Witch              B        4.0
# 5317              Elusive Tormentor              B        4.0
# 5318                 Insidious Mist              U        4.0
# 5326             Heir of Falkenrath              B        2.0
# 5330                Kindly Stranger              B        3.0
# 5331          Demon-Possessed Witch              B        3.0
# 5357                Breakneck Rider              R        3.0
# 5358                   Neck Breaker              R        3.0
# 5360               Convicted Killer              R        3.0
# 5361                 Branded Howler              R        3.0
# 5370              Gatstaf Arsonists              R        5.0
# 5371               Gatstaf Ravagers              R        5.0
# 5372             Geier Reach Bandit              R        3.0
# 5373              Vildin-Pack Alpha              R        3.0
# 5383             Kessig Forgemaster              R        2.0
# 5384            Flameheart Werewolf              R        2.0
# 5396                  Skin Invasion              R        1.0
# 5403              Village Messenger              R        1.0
# 5404              Moonrise Intruder              R        1.0
# 5408                 Autumnal Gloom              G        3.0
# 5418            Duskwatch Recruiter              G        2.0
# 5419            Krallenhorde Howler              G        2.0
# 5425     Hermit of the Natterknolls              G        3.0
# 5426  Lone Wolf of the Natterknolls              G        3.0
# 5427              Hinterland Logger              G        2.0
# 5428                Timber Shredder              G        2.0
# 5433              Lambholt Pacifist              G        2.0
# 5434               Lambholt Butcher              G        2.0
# 5443           Sage of Ancient Lore              G        5.0
# 5444     Werewolf of Ancient Hunger              G        5.0
# 5448                Solitary Hunter              G        4.0
# 5449                One of the Pack              G        4.0
# 5462                    Arlinn Kord           G, R        4.0
# 5463   Arlinn, Embraced by the Moon           G, R        4.0
# 5474                   Harvest Hand              C        3.0
# 5479             Neglected Heirloom              C        1.0
# 5486               Thraben Gargoyle              C        1.0
# 5498                 Westvale Abbey              L        0.0
# 6045              Distracting Geist              W        3.0
# 6047              Drogskol Infantry              W        2.0
# 6060       Katilda, Dawnhart Martyr              W        3.0
# 6062                Kindly Ancestor              W        3.0
# 6069             Panicked Bystander              W        2.0
# 6073                  Radiant Grace              W        1.0
# 6083                Twinblade Geist              W        2.0
# 6089           Wedding Announcement              W        3.0
# 6093                  Binding Geist              U        3.0
# 6095                    Biolume Egg              U        3.0
# 6109                 Gutter Skulker              U        4.0
# 6113        Jacob Hauken, Inspector              U        2.0
# 6115                 Lantern Bearer              U        1.0
# 6118               Mirrorhall Mimic              U        4.0
# 6120           Mischievous Catgeist              U        2.0
# 6131               Soulcipher Board              U        2.0
# 6149              Bloodsworn Squire              B        4.0
# 6152                Catapult Fodder              B        3.0
# 6155            Concealing Curtains              B        1.0
# 6156                  Revealing Eye              B        1.0
# 6159               Desperate Farmer              B        3.0
# 6174               Henrika Domnathi              B        4.0
# 6177              Innocent Traveler              B        4.0
# 6184                 Ragged Recluse              B        2.0
# 6186           Restless Bloodseeker              B        2.0
# 6196           Voldaren Bloodcaster              B        2.0
# 6200                Alluring Suitor              R        3.0
# 6201                  Deadly Dancer              R        3.0
# 6247              Voltaic Visionary              R        2.0
# 6263                  Dormant Grove              G        4.0
# 6293               Ulvenwald Oddity              G        4.0
# 6304                   Brine Comber           U, W        3.0
# 6308      Dorothea, Vengeful Victim           U, W        2.0
# 6310           Edgar, Charmed Groom           B, W        4.0
# 6311          Edgar Markov's Coffin           B, W        4.0
# 6321                 Runo Stromkirk           B, U        3.0
# 6332              Foreboding Statue              C        3.0
# 6599               Legion's Landing              W        1.0
# 6600         Adanto, the First Fort              L        1.0
# 6647             Search for Azcanta              U        2.0
# 6648       Azcanta, the Sunken Ruin              L        2.0
# 6663            Arguel's Blood Fast              B        2.0
# 6664             Temple of Aclazotz              L        2.0
# 6737       Vance's Blasting Cannons              R        4.0
# 6738               Spitfire Bastion              L        4.0
# 6754       Growing Rites of Itlimoc              G        3.0
# 6755     Itlimoc, Cradle of the Sun              L        3.0
# 6797            Conqueror's Galleon              C        4.0
# 6798           Conqueror's Foothold              L        4.0
# 6799                 Dowsing Dagger              C        2.0
# 6800                      Lost Vale              L        2.0
# 6808                  Primal Amulet              C        4.0
# 6809              Primal Wellspring              L        4.0
# 6814              Thaumatic Compass              C        2.0
# 6815               Spires of Orazca              L        2.0
# 6816                   Treasure Map              C        2.0
# 6817                  Treasure Cove              L        2.0
#
#                 manaCost  power  toughness  loyalty  \
# 1546              {2}{W}    0.0        3.0      NaN
# 1557              {1}{W}    1.0        1.0      NaN
# 1579              {1}{U}    1.0        1.0      NaN
# 1582           {3}{U}{U}    5.0        4.0      NaN
# 1590              {2}{U}    2.0        3.0      NaN
# 1640           {3}{B}{B}    3.0        3.0      NaN
# 1641                 NaN    6.0        5.0      NaN
# 1654              {2}{R}    2.0        3.0      NaN
# 1674           {2}{R}{R}    3.0        2.0      NaN
# 1681              {4}{R}    4.0        4.0      NaN
# 1697                 {G}    2.0        1.0      NaN
# 1702              {2}{G}    3.0        1.0      NaN
# 1709           {2}{G}{G}    2.0        4.0      NaN
# 1711              {1}{G}    1.0        2.0      NaN
# 1714              {1}{G}    NaN        NaN      NaN
# 1728           {3}{R}{G}    4.0        4.0      NaN
# 1729                 NaN    6.0        6.0      NaN
# 1731                 {3}    NaN        NaN      NaN
# 3006              {1}{W}    1.0        1.0      NaN
# 3008              {1}{W}    0.0        4.0      NaN
# 3010              {2}{W}    2.0        1.0      NaN
# 3021                 {W}    1.0        1.0      NaN
# 3026        {2}{W}{W}{W}    3.0        3.0      NaN
# 3037                 {W}    1.0        1.0      NaN
# 3039              {2}{W}    2.0        3.0      NaN
# 3054              {1}{U}    2.0        1.0      NaN
# 3058              {1}{U}    1.0        3.0      NaN
# 3061                 {U}    1.0        1.0      NaN
# 3069              {3}{U}    3.0        2.0      NaN
# 3076              {1}{U}    2.0        1.0      NaN
# 3079              {2}{U}    NaN        NaN      NaN
# 3080                 NaN    NaN        NaN      NaN
# 3085              {2}{U}    3.0        2.0      NaN
# 3089              {2}{U}    2.0        3.0      NaN
# 3090                 NaN    NaN        NaN      NaN
# 3113              {2}{B}    2.0        1.0      NaN
# 3123                 {B}    1.0        1.0      NaN
# 3130              {1}{B}    NaN        NaN      NaN
# 3135              {2}{B}    2.0        3.0      NaN
# 3154              {1}{B}    2.0        1.0      NaN
# 3171              {1}{R}    2.0        2.0      NaN
# 3192              {1}{R}    0.0        4.0      NaN
# 3218                 {G}    1.0        1.0      NaN
# 3258              {W}{U}    2.0        3.0      NaN
# 3260              {W}{U}    2.0        1.0      NaN
# 3277              {U}{B}    2.0        3.0      NaN
# 3278                 NaN    4.0        4.0      NaN
# 3291           {1}{R}{G}    3.0        3.0      NaN
# 3302                 {2}    NaN        NaN      NaN
# 3310                 NaN    NaN        NaN      NaN
# 3500        {1}{U}{B}{R}    4.0        4.0      NaN
# 4044              {3}{W}    NaN        NaN      NaN
# 4052              {1}{W}    NaN        NaN      NaN
# 4054              {2}{W}    NaN        NaN      NaN
# 4072              {1}{W}    NaN        NaN      NaN
# 4078              {2}{W}    NaN        NaN      NaN
# 4093           {3}{U}{U}    NaN        NaN      NaN
# 4103              {3}{U}    NaN        NaN      NaN
# 4113              {1}{U}    NaN        NaN      NaN
# 4156              {1}{B}    NaN        NaN      NaN
# 4158              {3}{B}    NaN        NaN      NaN
# 4167                 {B}    NaN        NaN      NaN
# 4175              {1}{B}    NaN        NaN      NaN
# 4193              {2}{R}    NaN        NaN      NaN
# 4204                 {R}    NaN        NaN      NaN
# 4215              {4}{R}    NaN        NaN      NaN
# 4226              {1}{G}    NaN        NaN      NaN
# 4232              {3}{G}    NaN        NaN      NaN
# 4237              {2}{G}    NaN        NaN      NaN
# 4251              {2}{G}    NaN        NaN      NaN
# 4268              {4}{G}    NaN        NaN      NaN
# 4271              {1}{G}    NaN        NaN      NaN
# 4281           {1}{B}{R}    NaN        NaN      NaN
# 4288  {1}{W}{U}{B}{R}{G}    NaN        NaN      NaN
# 4649           {1}{G}{U}    NaN        NaN      NaN
# 4650                 NaN    NaN        NaN      NaN
# 4652           {1}{B}{G}    NaN        NaN      NaN
# 4653                 NaN    NaN        NaN      NaN
# 4658              {R}{W}    NaN        NaN      NaN
# 4659                 NaN    NaN        NaN      NaN
# 4660           {1}{W}{B}    NaN        NaN      NaN
# 4661                 NaN    NaN        NaN      NaN
# 4668           {2}{U}{R}    NaN        NaN      NaN
# 4669                 NaN    NaN        NaN      NaN
# 4672                 {2}    NaN        NaN      NaN
# 4673                 NaN    NaN        NaN      NaN
# 4676                 {4}    4.0        4.0      NaN
# 4677                 NaN    NaN        NaN      NaN
# 5208           {3}{W}{W}    4.0        4.0      NaN
# 5209                 NaN    6.0        5.0      NaN
# 5210              {3}{W}    3.0        3.0      NaN
# 5211                 NaN    4.0        4.0      NaN
# 5212              {2}{W}    NaN        NaN      NaN
# 5226              {1}{W}    2.0        2.0      NaN
# 5239              {2}{W}    2.0        2.0      NaN
# 5252                 {W}    1.0        1.0      NaN
# 5255              {3}{U}    3.0        2.0      NaN
# 5261              {1}{U}    2.0        1.0      NaN
# 5295           {2}{U}{U}    NaN        NaN      NaN
# 5299              {1}{U}    0.0        4.0      NaN
# 5300                 NaN    7.0        8.0      NaN
# 5302              {2}{U}    2.0        2.0      NaN
# 5306              {3}{B}    4.0        2.0      NaN
# 5317           {2}{B}{B}    4.0        4.0      NaN
# 5318                 NaN    0.0        1.0      NaN
# 5326              {1}{B}    2.0        1.0      NaN
# 5330              {2}{B}    2.0        3.0      NaN
# 5331                 NaN    4.0        3.0      NaN
# 5357           {1}{R}{R}    3.0        3.0      NaN
# 5358                 NaN    4.0        3.0      NaN
# 5360              {2}{R}    2.0        2.0      NaN
# 5361                 NaN    4.0        4.0      NaN
# 5370              {4}{R}    5.0        4.0      NaN
# 5371                 NaN    6.0        5.0      NaN
# 5372              {2}{R}    3.0        2.0      NaN
# 5373                 NaN    4.0        3.0      NaN
# 5383              {1}{R}    2.0        1.0      NaN
# 5384                 NaN    3.0        2.0      NaN
# 5396                 {R}    NaN        NaN      NaN
# 5403                 {R}    1.0        1.0      NaN
# 5404                 NaN    2.0        2.0      NaN
# 5408              {2}{G}    NaN        NaN      NaN
# 5418              {1}{G}    2.0        2.0      NaN
# 5419                 NaN    3.0        3.0      NaN
# 5425              {2}{G}    2.0        3.0      NaN
# 5426                 NaN    3.0        5.0      NaN
# 5427              {1}{G}    2.0        1.0      NaN
# 5428                 NaN    4.0        2.0      NaN
# 5433              {1}{G}    3.0        3.0      NaN
# 5434                 NaN    4.0        4.0      NaN
# 5443              {4}{G}    NaN        NaN      NaN
# 5444                 NaN    NaN        NaN      NaN
# 5448              {3}{G}    3.0        4.0      NaN
# 5449                 NaN    5.0        6.0      NaN
# 5462           {2}{R}{G}    NaN        NaN      3.0
# 5463                 NaN    NaN        NaN      NaN
# 5474                 {3}    2.0        2.0      NaN
# 5479                 {1}    NaN        NaN      NaN
# 5486                 {1}    2.0        2.0      NaN
# 5498                 NaN    NaN        NaN      NaN
# 6045              {2}{W}    2.0        1.0      NaN
# 6047              {1}{W}    2.0        2.0      NaN
# 6060           {1}{W}{W}    NaN        NaN      NaN
# 6062              {2}{W}    2.0        3.0      NaN
# 6069              {1}{W}    2.0        2.0      NaN
# 6073                 {W}    NaN        NaN      NaN
# 6083              {1}{W}    1.0        1.0      NaN
# 6089              {2}{W}    NaN        NaN      NaN
# 6093              {2}{U}    3.0        1.0      NaN
# 6095              {2}{U}    0.0        4.0      NaN
# 6109              {3}{U}    3.0        3.0      NaN
# 6113              {1}{U}    0.0        2.0      NaN
# 6115                 {U}    1.0        1.0      NaN
# 6118              {3}{U}    0.0        0.0      NaN
# 6120              {1}{U}    1.0        1.0      NaN
# 6131              {1}{U}    NaN        NaN      NaN
# 6149              {3}{B}    3.0        3.0      NaN
# 6152              {2}{B}    1.0        5.0      NaN
# 6155                 {B}    0.0        4.0      NaN
# 6156                 NaN    3.0        4.0      NaN
# 6159              {2}{B}    2.0        2.0      NaN
# 6174           {2}{B}{B}    1.0        3.0      NaN
# 6177           {2}{B}{B}    1.0        3.0      NaN
# 6184              {1}{B}    2.0        1.0      NaN
# 6186              {1}{B}    1.0        3.0      NaN
# 6196              {1}{B}    2.0        1.0      NaN
# 6200              {2}{R}    2.0        3.0      NaN
# 6201                 NaN    3.0        3.0      NaN
# 6247              {1}{R}    3.0        1.0      NaN
# 6263              {3}{G}    NaN        NaN      NaN
# 6293           {2}{G}{G}    4.0        4.0      NaN
# 6304           {1}{W}{U}    1.0        1.0      NaN
# 6308              {W}{U}    4.0        4.0      NaN
# 6310           {2}{W}{B}    4.0        4.0      NaN
# 6311                 NaN    NaN        NaN      NaN
# 6321           {1}{U}{B}    1.0        4.0      NaN
# 6332                 {3}    1.0        2.0      NaN
# 6599                 {W}    NaN        NaN      NaN
# 6600                 NaN    NaN        NaN      NaN
# 6647              {1}{U}    NaN        NaN      NaN
# 6648                 NaN    NaN        NaN      NaN
# 6663              {1}{B}    NaN        NaN      NaN
# 6664                 NaN    NaN        NaN      NaN
# 6737              {3}{R}    NaN        NaN      NaN
# 6738                 NaN    NaN        NaN      NaN
# 6754              {2}{G}    NaN        NaN      NaN
# 6755                 NaN    NaN        NaN      NaN
# 6797                 {4}    2.0       10.0      NaN
# 6798                 NaN    NaN        NaN      NaN
# 6799                 {2}    NaN        NaN      NaN
# 6800                 NaN    NaN        NaN      NaN
# 6808                 {4}    NaN        NaN      NaN
# 6809                 NaN    NaN        NaN      NaN
# 6814                 {2}    NaN        NaN      NaN
# 6815                 NaN    NaN        NaN      NaN
# 6816                 {2}    NaN        NaN      NaN
# 6817                 NaN    NaN        NaN      NaN
#
#                                                    text    rarity  \
# 1546  When Extricator of Sin enters the battlefield,...  uncommon
# 1557  First strike, lifelink\nAt the beginning of th...  uncommon
# 1579  {T}: Add {C}. Spend this mana only to cast an ...  uncommon
# 1582  Flying\nWhenever you cast an instant or sorcer...      rare
# 1590  {T}: Mill two cards. Then if there is a colorl...  uncommon
# 1640  Flying\nSacrifice three other creatures: Trans...      rare
# 1641  Flying\nWhen this creature transforms into Abo...      rare
# 1654  Whenever Conduit of Storms attacks, add {R} at...  uncommon
# 1674  When Smoldering Werewolf enters the battlefiel...  uncommon
# 1681  Trample\n{R}: Vildin-Pack Outcast gets +1/-1 u...    common
# 1697                  {4}{G}: Transform Kessig Prowler.  uncommon
# 1702  Creatures with power less than Shrill Howler's...  uncommon
# 1709  Tangleclaw Werewolf can block an additional cr...  uncommon
# 1711  Defender\n{T}: Add {G}.\n{5}{G}{G}: Transform ...    common
# 1714  Transform up to one target Werewolf you contro...    common
# 1728  Whenever this creature enters the battlefield ...    mythic
# 1729  Whenever this creature transforms into Ulrich,...    mythic
# 1731  Cryptolith Fragment enters the battlefield tap...  uncommon
# 3006  When Ambitious Farmhand enters the battlefield...  uncommon
# 3008  Disturb {4}{W}{W} (You may cast this card from...  uncommon
# 3010  When another creature you control dies, transf...  uncommon
# 3021  First strike\nWard {1} (Whenever this creature...  uncommon
# 3026  Flying, double strike\nYou have hexproof.\nIf ...    mythic
# 3037  Whenever another creature enters the battlefie...    common
# 3039  Vigilance\nDisturb {3}{W} (You may cast this c...    common
# 3054  Disturb {1}{U} (You may cast this card from yo...    common
# 3058  When Covetous Castaway dies, mill three cards....  uncommon
# 3061  At the beginning of your upkeep, look at the t...  uncommon
# 3069  Flying\nDisturb {4}{U} (You may cast this card...    common
# 3076  {U}, Sacrifice Malevolent Hermit: Counter targ...      rare
# 3079  {2}, {T}: Draw a card. Transform Mysterious Tome.  uncommon
# 3080  {1}, {T}: Tap target nonland permanent. Transf...  uncommon
# 3085  When Overwhelmed Archivist enters the battlefi...  uncommon
# 3089  Whenever you cast an instant or sorcery spell,...    mythic
# 3090  Creature tokens you control lose all abilities...    mythic
# 3113  When Covert Cutpurse enters the battlefield, d...  uncommon
# 3123  {2}{B}, Sacrifice another creature: Draw a car...    common
# 3130  {1}, {T}, Pay 1 life, Discard a card: Draw a c...  uncommon
# 3135  Whenever Jerren, Corrupted Bishop enters the b...    mythic
# 3154  Vengeful Strangler can't block.\nWhen Vengeful...  uncommon
# 3171  When a spell you control deals damage, transfo...  uncommon
# 3192  Defender\nWhenever you cast an instant or sorc...      rare
# 3218  At the beginning of your upkeep, mill a card. ...  uncommon
# 3258  Lifelink\nCards in graveyards can't be the tar...      rare
# 3260  When Devoted Grafkeeper enters the battlefield...  uncommon
# 3277  Whenever Ludevic, Necrogenius enters the battl...      rare
# 3278  As this creature transforms into Olag, Ludevic...      rare
# 3291  Whenever a Wolf or Werewolf you control deals ...      rare
# 3302  {1}, {T}: Add one mana of any color.\n{5}, {T}...  uncommon
# 3310  {T}: Add {C}.\n{1}, {T}, Sacrifice a creature:...    mythic
# 3500  Flying\nWhen Nicol Bolas, the Ravager enters t...    mythic
# 4044  (As this Saga enters and after your draw step,...    common
# 4052  (As this Saga enters and after your draw step,...    common
# 4054  (As this Saga enters and after your draw step,...  uncommon
# 4072  (As this Saga enters and after your draw step,...  uncommon
# 4078  (As this Saga enters and after your draw step,...      rare
# 4093  (As this Saga enters and after your draw step,...  uncommon
# 4103  (As this Saga enters and after your draw step,...      rare
# 4113  (As this Saga enters and after your draw step,...    common
# 4156  (As this Saga enters and after your draw step,...  uncommon
# 4158  (As this Saga enters and after your draw step,...  uncommon
# 4167  (As this Saga enters and after your draw step,...    common
# 4175  (As this Saga enters and after your draw step,...      rare
# 4193  (As this Saga enters and after your draw step,...      rare
# 4204  (As this Saga enters and after your draw step,...  uncommon
# 4215  (As this Saga enters and after your draw step,...    common
# 4226  (As this Saga enters and after your draw step,...  uncommon
# 4232  (As this Saga enters and after your draw step,...  uncommon
# 4237  (As this Saga enters and after your draw step,...      rare
# 4251  (As this Saga enters and after your draw step,...    mythic
# 4268  (As this Saga enters and after your draw step,...    common
# 4271  (As this Saga enters and after your draw step,...      rare
# 4281  (As this Saga enters and after your draw step,...    mythic
# 4288  (As this Saga enters and after your draw step,...    mythic
# 4649  At the beginning of combat on your turn, put a...      rare
# 4650  (Transforms from Hadana's Climb.)\n{T}: Add on...      rare
# 4652  Enchant creature you control\nWhen enchanted c...      rare
# 4653  (Transforms from Journey to Eternity.)\n{T}: A...      rare
# 4658  When Path of Mettle enters the battlefield, it...      rare
# 4659  (Transforms from Path of Mettle.)\n{T}: Add on...      rare
# 4660  {3}{W}{B}: Exile target creature. Then if ther...      rare
# 4661  (Transforms from Profane Procession.)\n{T}: Ad...      rare
# 4668  Whenever one or more creatures you control dea...      rare
# 4669  (Transforms from Storm the Vault.)\n{T}: Add o...      rare
# 4672  {1}, {T}: Draw a card, then exile a card from ...    mythic
# 4673  (Transforms from Azor's Gateway.)\n{T}: Add X ...    mythic
# 4676  Defender\n{2}: Golden Guardian fights another ...      rare
# 4677  (Transforms from Golden Guardian.)\n{T}: Add t...      rare
# 5208  Flash\nFlying, vigilance\nWhen Archangel Avacy...    mythic
# 5209  Flying\nWhen this creature transforms into Ava...    mythic
# 5210  At the beginning of your end step, if Avacynia...  uncommon
# 5211  When this creature transforms into Lunarch Inq...  uncommon
# 5212  Enchant creature\nEnchanted creature can't att...  uncommon
# 5226  At the beginning of your upkeep, if you contro...      rare
# 5239  Whenever Pious Evangel or another creature ent...  uncommon
# 5252  {T}, Tap an untapped creature you control: Tra...  uncommon
# 5255  Flying\nAt the beginning of your upkeep, mill ...  uncommon
# 5261  When you sacrifice a Clue, transform Daring Sl...  uncommon
# 5295  Target opponent mills thirteen cards.\n{3}{U}{...    mythic
# 5299  Defender\nThing in the Ice enters the battlefi...      rare
# 5300  When this creature transforms into Awoken Horr...      rare
# 5302  Skulk (This creature can't be blocked by creat...  uncommon
# 5306  Spells your opponents cast that target Accurse...  uncommon
# 5317  {1}, Discard a card: Transform Elusive Tormentor.      rare
# 5318  Hexproof, indestructible\nInsidious Mist can't...      rare
# 5326  Discard a card: Transform Heir of Falkenrath. ...  uncommon
# 5330  Delirium — {2}{B}: Transform Kindly Stranger. ...  uncommon
# 5331  When this creature transforms into Demon-Posse...  uncommon
# 5357  At the beginning of each upkeep, if no spells ...  uncommon
# 5358  Attacking creatures you control get +1/+0 and ...  uncommon
# 5360  At the beginning of each upkeep, if no spells ...    common
# 5361  At the beginning of each upkeep, if a player c...    common
# 5370  At the beginning of each upkeep, if no spells ...    common
# 5371  Menace (This creature can't be blocked except ...    common
# 5372  Haste\nAt the beginning of each upkeep, if no ...      rare
# 5373  Whenever a Werewolf enters the battlefield und...      rare
# 5383  Whenever Kessig Forgemaster blocks or becomes ...  uncommon
# 5384  Whenever Flameheart Werewolf blocks or becomes...  uncommon
# 5396  Enchant creature\nEnchanted creature attacks e...  uncommon
# 5403  Haste\nAt the beginning of each upkeep, if no ...  uncommon
# 5404  Menace (This creature can't be blocked except ...  uncommon
# 5408  {B}: Mill a card.\nDelirium — At the beginning...  uncommon
# 5418  {2}{G}: Look at the top three cards of your li...  uncommon
# 5419  Creature spells you cast cost {1} less to cast...  uncommon
# 5425  Whenever an opponent casts a spell during your...  uncommon
# 5426  Whenever an opponent casts a spell during your...  uncommon
# 5427  At the beginning of each upkeep, if no spells ...    common
# 5428  Trample\nAt the beginning of each upkeep, if a...    common
# 5433  Lambholt Pacifist can't attack unless you cont...  uncommon
# 5434  At the beginning of each upkeep, if a player c...  uncommon
# 5443  Sage of Ancient Lore's power and toughness are...      rare
# 5444  Vigilance, trample\nWerewolf of Ancient Hunger...      rare
# 5448  At the beginning of each upkeep, if no spells ...    common
# 5449  At the beginning of each upkeep, if a player c...    common
# 5462  [+1]: Until end of turn, up to one target crea...    mythic
# 5463  [+1]: Creatures you control get +1/+1 and gain...    mythic
# 5474  When Harvest Hand dies, return it to the battl...  uncommon
# 5479  Equipped creature gets +1/+1.\nWhen equipped c...  uncommon
# 5486         Defender\n{6}: Transform Thraben Gargoyle.  uncommon
# 5498  {T}: Add {C}.\n{5}, {T}, Pay 1 life: Create a ...      rare
# 6045  Whenever Distracting Geist attacks, tap target...  uncommon
# 6047  Disturb {3}{W} (You may cast this card from yo...    common
# 6060  Flying, lifelink, protection from Vampires\nKa...      rare
# 6062  Lifelink\nDisturb {1}{W} (You may cast this ca...    common
# 6069  Whenever Panicked Bystander or another creatur...  uncommon
# 6073  Enchant creature\nEnchanted creature gets +1/+...  uncommon
# 6083  Double strike\nDisturb {2}{W} (You may cast th...  uncommon
# 6089  At the beginning of your end step, put an invi...      rare
# 6093  Whenever Binding Geist attacks, target creatur...    common
# 6095  Defender\nWhen Biolume Egg enters the battlefi...  uncommon
# 6109  Gutter Skulker can't be blocked as long as it'...  uncommon
# 6113  {T}: Draw a card, then exile a card from your ...    mythic
# 6115  Flying\nDisturb {2}{U} (You may cast this card...    common
# 6118  You may have Mirrorhall Mimic enter the battle...      rare
# 6120  Whenever Mischievous Catgeist deals combat dam...  uncommon
# 6131  Soulcipher Board enters the battlefield with t...  uncommon
# 6149  {1}{B}, Discard a card: Bloodsworn Squire gain...  uncommon
# 6152  At the beginning of combat on your turn, if yo...  uncommon
# 6155  Defender\n{2}{B}: Transform Concealing Curtain...      rare
# 6156  Menace\nWhen this creature transforms into Rev...      rare
# 6159  Lifelink\nWhen another creature you control di...    common
# 6174  Flying\nAt the beginning of combat on your tur...    mythic
# 6177  At the beginning of your upkeep, any opponent ...  uncommon
# 6184  At the beginning of your end step, if you disc...    common
# 6186  At the beginning of your end step, if you gain...  uncommon
# 6196  Flying\nWhenever Voldaren Bloodcaster or anoth...      rare
# 6200  When you attack with exactly two creatures, tr...  uncommon
# 6201  Trample\nWhen this creature transforms into De...  uncommon
# 6247  {T}: Voltaic Visionary deals 2 damage to you. ...  uncommon
# 6263  At the beginning of combat on your turn, put a...  uncommon
# 6293  Trample, haste\n{5}{G}{G}: Transform Ulvenwald...      rare
# 6304  Whenever Brine Comber enters the battlefield o...  uncommon
# 6308  Flying\nWhen Dorothea, Vengeful Victim attacks...      rare
# 6310  Other Vampires you control get +1/+1.\nWhen Ed...      rare
# 6311  At the beginning of your upkeep, create a 1/1 ...      rare
# 6321  Flying\nWhen Runo Stromkirk enters the battlef...      rare
# 6332  {T}: Add one mana of any color. Put an omen co...  uncommon
# 6599  When Legion's Landing enters the battlefield, ...      rare
# 6600  (Transforms from Legion's Landing.)\n{T}: Add ...      rare
# 6647  At the beginning of your upkeep, look at the t...      rare
# 6648  (Transforms from Search for Azcanta.)\n{T}: Ad...      rare
# 6663  {1}{B}, Pay 2 life: Draw a card.\nAt the begin...      rare
# 6664  (Transforms from Arguel's Blood Fast.)\n{T}: A...      rare
# 6737  At the beginning of your upkeep, exile the top...      rare
# 6738  (Transforms from Vance's Blasting Cannons.)\n{...      rare
# 6754  When Growing Rites of Itlimoc enters the battl...      rare
# 6755  (Transforms from Growing Rites of Itlimoc.)\n{...      rare
# 6797  When Conqueror's Galleon attacks, exile it at ...      rare
# 6798  (Transforms from Conqueror's Galleon.)\n{T}: A...      rare
# 6799  When Dowsing Dagger enters the battlefield, ta...      rare
# 6800  (Transforms from Dowsing Dagger.)\n{T}: Add th...      rare
# 6808  Instant and sorcery spells you cast cost {1} l...      rare
# 6809  (Transforms from Primal Amulet.)\n{T}: Add one...      rare
# 6814  {3}, {T}: Search your library for a basic land...      rare
# 6815  (Transforms from Thaumatic Compass.)\n{T}: Add...      rare
# 6816  {1}, {T}: Scry 1. Put a landmark counter on Tr...      rare
# 6817  (Transforms from Treasure Map.)\n{T}: Add {C}....      rare
#
#                                                keywords supertypes  \
# 1546                                Delirium, Transform        NaN
# 1557                  First strike, Lifelink, Transform        NaN
# 1579                                          Transform        NaN
# 1582                                  Flying, Transform        NaN
# 1590                                    Mill, Transform        NaN
# 1640                         Flying, Madness, Transform        NaN
# 1641                                  Flying, Transform        NaN
# 1654                                          Transform        NaN
# 1674                                          Transform        NaN
# 1681                                 Trample, Transform        NaN
# 1697                                          Transform        NaN
# 1702                                          Transform        NaN
# 1709                                          Transform        NaN
# 1711                                Defender, Transform        NaN
# 1714                                          Transform        NaN
# 1728                                          Transform  Legendary
# 1729                                   Fight, Transform  Legendary
# 1731                                          Transform        NaN
# 3006                                   Coven, Transform        NaN
# 3008                                 Disturb, Transform        NaN
# 3010                                          Transform        NaN
# 3021             Disturb, First strike, Transform, Ward        NaN
# 3026                   Double strike, Flying, Transform        NaN
# 3037                                 Disturb, Transform        NaN
# 3039                      Disturb, Transform, Vigilance        NaN
# 3054                                 Disturb, Transform        NaN
# 3058                           Disturb, Mill, Transform        NaN
# 3061                                          Transform        NaN
# 3069                         Disturb, Flying, Transform        NaN
# 3076                                 Disturb, Transform        NaN
# 3079                                          Transform        NaN
# 3080                                          Transform        NaN
# 3085                                 Disturb, Transform        NaN
# 3089                                          Transform        NaN
# 3090                                          Transform        NaN
# 3113                                 Disturb, Transform        NaN
# 3123                                          Transform        NaN
# 3130                                    Mill, Transform        NaN
# 3135                                Lifelink, Transform  Legendary
# 3154                                          Transform        NaN
# 3171                                          Transform        NaN
# 3192                                Defender, Transform        NaN
# 3218                                    Mill, Transform        NaN
# 3258                       Disturb, Lifelink, Transform  Legendary
# 3260                           Disturb, Mill, Transform        NaN
# 3277                                    Mill, Transform  Legendary
# 3278                                          Transform  Legendary
# 3291                                Daybound, Transform  Legendary
# 3302                                          Transform        NaN
# 3310                                          Transform        NaN
# 3500                                  Flying, Transform  Legendary
# 4044                                  Flying, Transform        NaN
# 4052                                    Scry, Transform        NaN
# 4054                                          Transform        NaN
# 4072                                          Transform        NaN
# 4078                                          Transform        NaN
# 4093                                    Scry, Transform        NaN
# 4103                                          Transform        NaN
# 4113                                          Transform        NaN
# 4156                                          Transform        NaN
# 4158                                          Transform        NaN
# 4167                                          Transform        NaN
# 4175                                          Transform        NaN
# 4193                                          Transform        NaN
# 4204                                          Transform        NaN
# 4215                                   Haste, Transform        NaN
# 4226                                          Transform        NaN
# 4232                                          Transform        NaN
# 4237                                          Transform        NaN
# 4251                                          Transform        NaN
# 4268                               Transform, Vigilance        NaN
# 4271                                    Mill, Transform        NaN
# 4281                                          Transform        NaN
# 4288                                          Transform        NaN
# 4649                                          Transform  Legendary
# 4650                                          Transform  Legendary
# 4652                                 Enchant, Transform  Legendary
# 4653                                          Transform  Legendary
# 4658                                          Transform  Legendary
# 4659                                          Transform  Legendary
# 4660                                          Transform  Legendary
# 4661                                          Transform  Legendary
# 4668                                          Transform  Legendary
# 4669                                          Transform  Legendary
# 4672                                          Transform  Legendary
# 4673                                          Transform  Legendary
# 4676                         Defender, Fight, Transform        NaN
# 4677                                          Transform        NaN
# 5208                Flash, Flying, Transform, Vigilance  Legendary
# 5209                                  Flying, Transform  Legendary
# 5210                                          Transform        NaN
# 5211                                          Transform        NaN
# 5212                                 Enchant, Transform        NaN
# 5226                                          Transform        NaN
# 5239                                          Transform        NaN
# 5252                                          Transform        NaN
# 5255                            Flying, Mill, Transform        NaN
# 5261                                          Transform        NaN
# 5295                                    Mill, Transform        NaN
# 5299                                Defender, Transform        NaN
# 5300                                          Transform        NaN
# 5302                                   Skulk, Transform        NaN
# 5306                                          Transform        NaN
# 5317                                          Transform        NaN
# 5318                Hexproof, Indestructible, Transform        NaN
# 5326                                          Transform        NaN
# 5330                                Delirium, Transform        NaN
# 5331                                          Transform        NaN
# 5357                                          Transform        NaN
# 5358                                          Transform        NaN
# 5360                                          Transform        NaN
# 5361                                          Transform        NaN
# 5370                                          Transform        NaN
# 5371                                  Menace, Transform        NaN
# 5372                                   Haste, Transform        NaN
# 5373                                          Transform        NaN
# 5383                                          Transform        NaN
# 5384                                          Transform        NaN
# 5396                                 Enchant, Transform        NaN
# 5403                                   Haste, Transform        NaN
# 5404                                  Menace, Transform        NaN
# 5408                          Delirium, Mill, Transform        NaN
# 5418                                          Transform        NaN
# 5419                                          Transform        NaN
# 5425                                          Transform        NaN
# 5426                                          Transform        NaN
# 5427                                          Transform        NaN
# 5428                                 Trample, Transform        NaN
# 5433                                          Transform        NaN
# 5434                                          Transform        NaN
# 5443                                          Transform        NaN
# 5444                      Trample, Transform, Vigilance        NaN
# 5448                                          Transform        NaN
# 5449                                          Transform        NaN
# 5462                                          Transform  Legendary
# 5463                                          Transform  Legendary
# 5474                                          Transform        NaN
# 5479                                   Equip, Transform        NaN
# 5486                                Defender, Transform        NaN
# 5498                                          Transform        NaN
# 6045                                 Disturb, Transform        NaN
# 6047                                 Disturb, Transform        NaN
# 6060  Disturb, Enchant, Flying, Lifelink, Protection...  Legendary
# 6062                       Disturb, Lifelink, Transform        NaN
# 6069                                          Transform        NaN
# 6073                                 Enchant, Transform        NaN
# 6083                  Disturb, Double strike, Transform        NaN
# 6089                                          Transform        NaN
# 6093                                 Disturb, Transform        NaN
# 6095                          Defender, Scry, Transform        NaN
# 6109                                 Disturb, Transform        NaN
# 6113                                          Transform  Legendary
# 6115                         Disturb, Flying, Transform        NaN
# 6118                                 Disturb, Transform        NaN
# 6120                                 Disturb, Transform        NaN
# 6131                                          Transform        NaN
# 6149                                          Transform        NaN
# 6152                                          Transform        NaN
# 6155                                Defender, Transform        NaN
# 6156                                  Menace, Transform        NaN
# 6159                                Lifelink, Transform        NaN
# 6174                                  Flying, Transform  Legendary
# 6177                                          Transform        NaN
# 6184                                          Transform        NaN
# 6186                                          Transform        NaN
# 6196                                  Flying, Transform        NaN
# 6200                                          Transform        NaN
# 6201                                 Trample, Transform        NaN
# 6247                                          Transform        NaN
# 6263                                          Transform        NaN
# 6293                          Haste, Trample, Transform        NaN
# 6304                                 Disturb, Transform        NaN
# 6308                         Disturb, Flying, Transform  Legendary
# 6310                                          Transform  Legendary
# 6311                                          Transform  Legendary
# 6321                                  Flying, Transform  Legendary
# 6332                                          Transform        NaN
# 6599                                          Transform  Legendary
# 6600                                          Transform  Legendary
# 6647                                          Transform  Legendary
# 6648                                          Transform  Legendary
# 6663                                          Transform  Legendary
# 6664                                          Transform  Legendary
# 6737                                          Transform  Legendary
# 6738                                          Transform  Legendary
# 6754                                          Transform  Legendary
# 6755                                          Transform  Legendary
# 6797                                    Crew, Transform        NaN
# 6798                                          Transform        NaN
# 6799                                   Equip, Transform        NaN
# 6800                                          Transform        NaN
# 6808                                          Transform        NaN
# 6809                                          Transform        NaN
# 6814                                          Transform        NaN
# 6815                                          Transform        NaN
# 6816                                    Scry, Transform        NaN
# 6817                                          Transform        NaN
#
#                    types
# 1546            Creature
# 1557            Creature
# 1579            Creature
# 1582            Creature
# 1590            Creature
# 1640            Creature
# 1641            Creature
# 1654            Creature
# 1674            Creature
# 1681            Creature
# 1697            Creature
# 1702            Creature
# 1709            Creature
# 1711            Creature
# 1714             Instant
# 1728            Creature
# 1729            Creature
# 1731            Artifact
# 3006            Creature
# 3008            Creature
# 3010            Creature
# 3021            Creature
# 3026            Creature
# 3037            Creature
# 3039            Creature
# 3054            Creature
# 3058            Creature
# 3061            Creature
# 3069            Creature
# 3076            Creature
# 3079            Artifact
# 3080            Artifact
# 3085            Creature
# 3089            Creature
# 3090            Artifact
# 3113            Creature
# 3123            Creature
# 3130            Artifact
# 3135            Creature
# 3154            Creature
# 3171            Creature
# 3192            Creature
# 3218            Creature
# 3258            Creature
# 3260            Creature
# 3277            Creature
# 3278            Creature
# 3291            Creature
# 3302            Artifact
# 3310                Land
# 3500            Creature
# 4044         Enchantment
# 4052         Enchantment
# 4054         Enchantment
# 4072         Enchantment
# 4078         Enchantment
# 4093         Enchantment
# 4103         Enchantment
# 4113         Enchantment
# 4156         Enchantment
# 4158         Enchantment
# 4167         Enchantment
# 4175         Enchantment
# 4193         Enchantment
# 4204         Enchantment
# 4215         Enchantment
# 4226         Enchantment
# 4232         Enchantment
# 4237         Enchantment
# 4251         Enchantment
# 4268         Enchantment
# 4271         Enchantment
# 4281         Enchantment
# 4288         Enchantment
# 4649         Enchantment
# 4650                Land
# 4652         Enchantment
# 4653                Land
# 4658         Enchantment
# 4659                Land
# 4660         Enchantment
# 4661                Land
# 4668         Enchantment
# 4669                Land
# 4672            Artifact
# 4673                Land
# 4676  Artifact, Creature
# 4677                Land
# 5208            Creature
# 5209            Creature
# 5210            Creature
# 5211            Creature
# 5212         Enchantment
# 5226            Creature
# 5239            Creature
# 5252            Creature
# 5255            Creature
# 5261            Creature
# 5295             Sorcery
# 5299            Creature
# 5300            Creature
# 5302            Creature
# 5306            Creature
# 5317            Creature
# 5318            Creature
# 5326            Creature
# 5330            Creature
# 5331            Creature
# 5357            Creature
# 5358            Creature
# 5360            Creature
# 5361            Creature
# 5370            Creature
# 5371            Creature
# 5372            Creature
# 5373            Creature
# 5383            Creature
# 5384            Creature
# 5396         Enchantment
# 5403            Creature
# 5404            Creature
# 5408         Enchantment
# 5418            Creature
# 5419            Creature
# 5425            Creature
# 5426            Creature
# 5427            Creature
# 5428            Creature
# 5433            Creature
# 5434            Creature
# 5443            Creature
# 5444            Creature
# 5448            Creature
# 5449            Creature
# 5462        Planeswalker
# 5463        Planeswalker
# 5474  Artifact, Creature
# 5479            Artifact
# 5486  Artifact, Creature
# 5498                Land
# 6045            Creature
# 6047            Creature
# 6060            Creature
# 6062            Creature
# 6069            Creature
# 6073         Enchantment
# 6083            Creature
# 6089         Enchantment
# 6093            Creature
# 6095            Creature
# 6109            Creature
# 6113            Creature
# 6115            Creature
# 6118            Creature
# 6120            Creature
# 6131            Artifact
# 6149            Creature
# 6152            Creature
# 6155            Creature
# 6156            Creature
# 6159            Creature
# 6174            Creature
# 6177            Creature
# 6184            Creature
# 6186            Creature
# 6196            Creature
# 6200            Creature
# 6201            Creature
# 6247            Creature
# 6263         Enchantment
# 6293            Creature
# 6304            Creature
# 6308            Creature
# 6310            Creature
# 6311            Artifact
# 6321            Creature
# 6332  Artifact, Creature
# 6599         Enchantment
# 6600                Land
# 6647         Enchantment
# 6648                Land
# 6663         Enchantment
# 6664                Land
# 6737         Enchantment
# 6738                Land
# 6754         Enchantment
# 6755                Land
# 6797            Artifact
# 6798                Land
# 6799            Artifact
# 6800                Land
# 6808            Artifact
# 6809                Land
# 6814            Artifact
# 6815                Land
# 6816            Artifact
# 6817                Land

# %%
def backwards_extract (df, keyword):
    import re
    
    # store the relevant index numbers from the dataframe
    indexes = df.loc[df.text.str.contains(keyword)].index

    # loop over each element to be changed
    for count, text in enumerate(df.loc[df.text.str.contains(keyword)].text):

        # find occurence of keyword
        c = text.find(keyword)

        # capture the text before the keyword
        if c <= 12:
            text_value = text[:c]
        else:
            text_value = text[c-12:c-2]

        # check to see that a curly brace exists before the keyword, confirming
        # that the text directly before it indicates an additional mana cost
        if '}' in text_value:
            text_value = text_value[text_value.find('{'):]

            # remove curly braces, Tap symbols, whitespace, colons
            text_value = re.sub('[,T:\s}{]', '', text_value)            

            # calculate value to use in dataframe 
            new_value = len(text_value) 
            if text_value[0].isdigit():
                new_value += int(text_value[0]) - 1

            # update the value of the NEXT card in the dataframe, the one that
            # our identified cards transform into
            df.iat[indexes[count] + 1, 2] += new_value
            
            # print a list of changes made so we can confirm we got it right
            print(df.iloc[indexes[count] +1, :4])

# %%
backwards_extract(all_cards, 'Transform')
# Out:
# name         Conduit of Emrakul
# colors                        C
# manaValue                   8.0
# manaCost                    NaN
# Name: 1655, dtype: object
# name         Erupting Dreadwolf
# colors                        C
# manaValue                  10.0
# manaCost                    NaN
# Name: 1675, dtype: object
# name         Dronepack Kindred
# colors                       C
# manaValue                 12.0
# manaCost                   NaN
# Name: 1682, dtype: object
# name         Sinuous Predator
# colors                      C
# manaValue                 6.0
# manaCost                  NaN
# Name: 1698, dtype: object
# name         Howling Chorus
# colors                    C
# manaValue               9.0
# manaCost                NaN
# Name: 1703, dtype: object
# name         Fibrous Entangler
# colors                       C
# manaValue                 11.0
# manaCost                   NaN
# Name: 1710, dtype: object
# name         Ulvenwald Abomination
# colors                           C
# manaValue                      9.0
# manaCost                       NaN
# Name: 1712, dtype: object
# name         Seasoned Cathar
# colors                     W
# manaValue                5.0
# manaCost                 NaN
# Name: 3007, dtype: object
# name         Mystic Monstrosity
# colors                        C
# manaValue                   7.0
# manaCost                    NaN
# Name: 3303, dtype: object
# name         Demon-Possessed Witch
# colors                           B
# manaValue                      6.0
# manaCost                       NaN
# Name: 5331, dtype: object
# name         Stonewing Antagonizer
# colors                           C
# manaValue                      7.0
# manaCost                       NaN
# Name: 5487, dtype: object
# name         Revealing Eye
# colors                   B
# manaValue              4.0
# manaCost               NaN
# Name: 6156, dtype: object
# name         Ulvenwald Behemoth
# colors                        G
# manaValue                  11.0
# manaCost                    NaN
# Name: 6294, dtype: object

# %%
creatures = all_cards.loc[all_cards.types.str.contains('Creature')].copy()
creatures.reset_index(drop=True, inplace=True)

# %%
creatures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3845 entries, 0 to 3844
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        3845 non-null   object
#  1   colors      3845 non-null   object
#  2   manaValue   3845 non-null   float64
#  3   manaCost    3698 non-null   object
#  4   power       3814 non-null   float64
#  5   toughness   3824 non-null   float64
#  6   loyalty     0 non-null      float64
#  7   text        3845 non-null   object
#  8   rarity      3845 non-null   object
#  9   keywords    3845 non-null   object
#  10  supertypes  457 non-null    object
#  11  types       3845 non-null   object
# dtypes: float64(4), object(8)
# memory usage: 360.6+ KB

# %%
creatures.head()
# Out:
#                     name colors  manaValue   manaCost  power  toughness  \
# 0       Aeronaut Admiral      W        4.0     {3}{W}    3.0        1.0
# 1       Aether Inspector      W        4.0     {3}{W}    2.0        3.0
# 2      Aethergeode Miner      W        2.0     {1}{W}    3.0        1.0
# 3      Airdrop Aeronauts      W        5.0  {3}{W}{W}    4.0        3.0
# 4  Audacious Infiltrator      W        2.0     {1}{W}    3.0        1.0
#
#    loyalty                                               text    rarity  \
# 0      NaN          Flying\nVehicles you control have flying.  uncommon
# 1      NaN  Vigilance\nWhen Aether Inspector enters the ba...    common
# 2      NaN  Whenever Aethergeode Miner attacks, you get {E...      rare
# 3      NaN  Flying\nRevolt — When Airdrop Aeronauts enters...  uncommon
# 4      NaN  Audacious Infiltrator can't be blocked by arti...    common
#
#          keywords supertypes     types
# 0          Flying        NaN  Creature
# 1       Vigilance        NaN  Creature
# 2                        NaN  Creature
# 3  Flying, Revolt        NaN  Creature
# 4                        NaN  Creature

# %% [markdown]
# Here, I use a seaborn heatmap to visually indicate which columns have a large amount of NaN values.  We expect that the column loyalty should be entirely NaN, so we're going to drop that right away.  I plan to also drop the columns manaCost and text, but we'll first investigate why those columns have missing values, to confirm that our data is accurate.

# %%
plt.figure(figsize=(12,8))
sns.heatmap(creatures.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
creatures.drop(['loyalty'], axis=1, inplace=True)

# %%
creatures.head()
# Out:
#                     name colors  manaValue   manaCost  power  toughness  \
# 0       Aeronaut Admiral      W        4.0     {3}{W}    3.0        1.0
# 1       Aether Inspector      W        4.0     {3}{W}    2.0        3.0
# 2      Aethergeode Miner      W        2.0     {1}{W}    3.0        1.0
# 3      Airdrop Aeronauts      W        5.0  {3}{W}{W}    4.0        3.0
# 4  Audacious Infiltrator      W        2.0     {1}{W}    3.0        1.0
#
#                                                 text    rarity  \
# 0          Flying\nVehicles you control have flying.  uncommon
# 1  Vigilance\nWhen Aether Inspector enters the ba...    common
# 2  Whenever Aethergeode Miner attacks, you get {E...      rare
# 3  Flying\nRevolt — When Airdrop Aeronauts enters...  uncommon
# 4  Audacious Infiltrator can't be blocked by arti...    common
#
#          keywords supertypes     types
# 0          Flying        NaN  Creature
# 1       Vigilance        NaN  Creature
# 2                        NaN  Creature
# 3  Flying, Revolt        NaN  Creature
# 4                        NaN  Creature

# %%
len(creatures[creatures.manaCost.isna()])
# Out:
# 147

# %% [markdown]
# There are 147 rows with NaN values for manaCost.  We have zero rows that have NaN values in manaValue, though, so these are almost definitely the backs of modal cards that transform through one game mechanic or another.  The amount of resources spent to cast the card is accurately reflected in the manaValue column, though the conditions for flipping the card are not going to be considered at this stage of our investigation.  Still, we'll do the same as we did above and check that this is true of about 10% of the data before dropping the column to make sure we didn't inadvertently introduce any errors.

# %%
creatures[creatures.manaCost.isna()].sample(15)
# Out:
#                            name colors  manaValue manaCost  power  toughness  \
# 2213   Architect of Restoration      W        3.0      NaN    3.0        4.0
# 1693              Wing Shredder      G        3.0      NaN    3.0        5.0
# 2832        Lunarch Inquisitors      W        4.0      NaN    4.0        4.0
# 3427         Ulvenwald Behemoth      G       11.0      NaN    8.0        8.0
# 3396       Wrathful Jailbreaker      R        4.0      NaN    6.0        6.0
# 1725  Dennick, Pious Apparition   U, W        2.0      NaN    3.0        2.0
# 1606                Waildrifter      U        4.0      NaN    2.0        2.0
# 2840       Westvale Cult Leader      W        2.0      NaN    NaN        NaN
# 1635            Leeching Lurker      B        3.0      NaN    4.0        4.0
# 2858             Perfected Form      U        4.0      NaN    5.0        4.0
# 2882       Unimpeded Trespasser      U        3.0      NaN    3.0        3.0
# 1736     Olag, Ludevic's Hubris   B, U        2.0      NaN    4.0        4.0
# 3375          Fearsome Werewolf      R        3.0      NaN    4.0        3.0
# 2915             Branded Howler      R        3.0      NaN    4.0        4.0
# 1647   Ormendahl, the Corrupter      B        3.0      NaN    6.0        6.0
#
#                                                    text    rarity  \
# 2213  Vigilance\nWhenever Architect of Restoration a...      rare
# 1693  Reach\nNightbound (If a player casts at least ...    common
# 2832  When this creature transforms into Lunarch Inq...  uncommon
# 3427  Trample, haste\nOther creatures you control ge...      rare
# 3396  Wrathful Jailbreaker attacks each combat if ab...    common
# 1725  Flying\nWhenever one or more creature cards ar...      rare
# 1606  Flying\nIf Waildrifter would be put into a gra...    common
# 2840  Westvale Cult Leader's power and toughness are...      rare
# 1635  Lifelink\nNightbound (If a player casts at lea...      rare
# 2858                                             Flying  uncommon
# 2882             Unimpeded Trespasser can't be blocked.  uncommon
# 1736  As this creature transforms into Olag, Ludevic...      rare
# 3375  Menace (This creature can't be blocked except ...    common
# 2915  At the beginning of each upkeep, if a player c...    common
# 1647  Flying, trample, lifelink\nSacrifice another c...    mythic
#
#                        keywords supertypes                  types
# 2213                  Vigilance        NaN  Enchantment, Creature
# 1693          Nightbound, Reach        NaN               Creature
# 2832                  Transform        NaN               Creature
# 3427             Haste, Trample        NaN               Creature
# 3396                 Nightbound        NaN               Creature
# 1725        Flying, Investigate  Legendary               Creature
# 1606                     Flying        NaN               Creature
# 2840                                   NaN               Creature
# 1635       Lifelink, Nightbound        NaN               Creature
# 2858                     Flying        NaN               Creature
# 2882                                   NaN               Creature
# 1736                  Transform  Legendary               Creature
# 3375         Menace, Nightbound        NaN               Creature
# 2915                  Transform        NaN               Creature
# 1647  Flying, Lifelink, Trample  Legendary               Creature

# %% [markdown]
# In checking to make sure I didn't introduce any errors, I realized that the listed Mana Values for cards with the "Disturb" keyword were not reflective of the cost to cast their disturb mode, so I went ahead and built out a function that will let us extract the Disturb cost from the card text and replace that in the mana value field.

# %%
def extract_mana_value (df, keyword):
    import re
    
    # store the relevant index numbers from the dataframe
    indexes = df.loc[df.text.str.contains(keyword)].index

    # loop over each element to be changed
    for count, text in enumerate(df.loc[df.text.str.contains(keyword)].text):

        # find occurence of keyword
        c = text.find(keyword)

        # capture the text after the keyword that lists the mana cost of casting 
        # the card, leaving out leading and trailing curly braces.
        text_value = text[c+9:text.rfind('}', c+8, c+20)]

        # remove the rest of the curly braces
        text_value = re.sub('[,T:\s}{]', '', text_value)

        # calculate value to use in dataframe 
        new_value = len(text_value) 
        if text_value[0].isdigit():
            new_value += int(text_value[0]) - 1

        # update the value in the dataframe
        df.iat[indexes[count], 2] = new_value

# %%
extract_mana_value(creatures, 'Disturb')

# %%
creatures.loc[creatures.text.str.contains('Disturb')].head()
# Out:
#                   name colors  manaValue manaCost  power  toughness  \
# 1564    Beloved Beggar      W        6.0   {1}{W}    0.0        4.0
# 1573  Chaplain of Alms      W        4.0      {W}    1.0        1.0
# 1584   Lunarch Veteran      W        2.0      {W}    1.0        1.0
# 1586   Mourning Patrol      W        4.0   {2}{W}    2.0        3.0
# 1595   Baithook Angler      U        2.0   {1}{U}    2.0        1.0
#
#                                                    text    rarity  \
# 1564  Disturb {4}{W}{W} (You may cast this card from...  uncommon
# 1573  First strike\nWard {1} (Whenever this creature...  uncommon
# 1584  Whenever another creature enters the battlefie...    common
# 1586  Vigilance\nDisturb {3}{W} (You may cast this c...    common
# 1595  Disturb {1}{U} (You may cast this card from yo...    common
#
#                                     keywords supertypes     types
# 1564                      Disturb, Transform        NaN  Creature
# 1573  Disturb, First strike, Transform, Ward        NaN  Creature
# 1584                      Disturb, Transform        NaN  Creature
# 1586           Disturb, Transform, Vigilance        NaN  Creature
# 1595                      Disturb, Transform        NaN  Creature

# %% [markdown]
# We have two exceptions with cards that come into play as lands and then can later be flipped into creatures.  I'll go ahead and manually set reasonable manaValues for those two, since it's such a small number.

# %%
creatures[creatures.manaCost.isna()].query('manaValue == 0')
# Out:
#                            name colors  manaValue manaCost  power  toughness  \
# 1750               Creeping Inn      B        0.0      NaN    3.0        7.0
# 2989  Ormendahl, Profane Prince      B        0.0      NaN    9.0        7.0
#
#                                                    text  rarity  \
# 1750  Whenever Creeping Inn attacks, you may exile a...  mythic
# 2989            Flying, lifelink, indestructible, haste    rare
#
#                                      keywords supertypes               types
# 1750                                                 NaN  Artifact, Creature
# 2989  Flying, Haste, Indestructible, Lifelink  Legendary            Creature

# %%
creatures.iat[2989, 2] = 5
creatures.iat[1750, 2] = 3

# %%
creatures.info()

# %%
creatures[creatures.manaCost.isna()].sample(15)
# Out:
#                             name colors  manaValue manaCost  power  toughness  \
# 1567           Dauntless Avenger      W        3.0      NaN    3.0        2.0
# 3415           Infested Werewolf      G        5.0      NaN    4.0        5.0
# 3396        Wrathful Jailbreaker      R        4.0      NaN    6.0        6.0
# 885            Dronepack Kindred      C       12.0      NaN    5.0        7.0
# 2264        Echo of Death's Wail      B        2.0      NaN    3.0        3.0
# 2888              Insidious Mist      U        4.0      NaN    0.0        1.0
# 3297             Biolume Serpent      U        3.0      NaN    4.0        4.0
# 908        Ulvenwald Abomination      C        9.0      NaN    4.0        6.0
# 2200       Hand of Enlightenment      W        2.0      NaN    2.0        2.0
# 896             Sinuous Predator      C        6.0      NaN    4.0        4.0
# 3336          Depraved Harvester      B        3.0      NaN    4.0        3.0
# 2230               Vector Glider      U        2.0      NaN    2.0        3.0
# 2307  Remnant of the Rising Star      G        3.0      NaN    2.0        2.0
# 2956             Timber Shredder      G        2.0      NaN    4.0        2.0
# 2196               Imperial Moth      W        4.0      NaN    2.0        4.0
#
#                                                    text    rarity  \
# 1567  Whenever Dauntless Avenger attacks, return tar...  uncommon
# 3415  Whenever Infested Werewolf enters the battlefi...  uncommon
# 3396  Wrathful Jailbreaker attacks each combat if ab...    common
# 885   Trample\n{1}: Dronepack Kindred gets +1/+0 unt...    common
# 2264  Flying, haste\nWhen Echo of Death's Wail enter...      rare
# 2888  Hexproof, indestructible\nInsidious Mist can't...      rare
# 3297  Sacrifice two Islands: Biolume Serpent can't b...  uncommon
# 908                                    {T}: Add {C}{C}.    common
# 2200                                       First strike    common
# 896   Sinuous Predator can't be blocked by more than...  uncommon
# 3336                                           Lifelink    common
# 2230                                             Flying    common
# 2307  Flying\nWhenever another creature enters the b...    mythic
# 2956  Trample\nAt the beginning of each upkeep, if a...    common
# 2196                                             Flying    common
#
#                                  keywords supertypes                  types
# 1567                                             NaN               Creature
# 3415                           Nightbound        NaN               Creature
# 3396                           Nightbound        NaN               Creature
# 885                               Trample        NaN               Creature
# 2264                        Flying, Haste        NaN  Enchantment, Creature
# 2888  Hexproof, Indestructible, Transform        NaN               Creature
# 3297                                             NaN               Creature
# 908                                              NaN               Creature
# 2200                         First strike        NaN  Enchantment, Creature
# 896                                              NaN               Creature
# 3336                             Lifelink        NaN               Creature
# 2230                               Flying        NaN  Enchantment, Creature
# 2307                               Flying        NaN  Enchantment, Creature
# 2956                   Trample, Transform        NaN               Creature
# 2196                               Flying        NaN  Enchantment, Creature

# %% [markdown]
# At this point, we should have dealt with most or all of the incorrectly assigned manaValue creatures, though we are not accounting for non-mana costs.  Doing so would be significantly more complicated and goes beyond the scope of the current investigation, so I'm happy to move on to other things that need to be corrected.  At this point, we should not need the manaCost column any longer, so I'll drop it.

# %%
creatures.drop(columns='manaCost', inplace=True)

# %%
creatures.head()
# Out:
#                     name colors  manaValue  power  toughness  \
# 0       Aeronaut Admiral      W        4.0    3.0        1.0
# 1       Aether Inspector      W        4.0    2.0        3.0
# 2      Aethergeode Miner      W        2.0    3.0        1.0
# 3      Airdrop Aeronauts      W        5.0    4.0        3.0
# 4  Audacious Infiltrator      W        2.0    3.0        1.0
#
#                                                 text    rarity  \
# 0          Flying\nVehicles you control have flying.  uncommon
# 1  Vigilance\nWhen Aether Inspector enters the ba...    common
# 2  Whenever Aethergeode Miner attacks, you get {E...      rare
# 3  Flying\nRevolt — When Airdrop Aeronauts enters...  uncommon
# 4  Audacious Infiltrator can't be blocked by arti...    common
#
#          keywords supertypes     types
# 0          Flying        NaN  Creature
# 1       Vigilance        NaN  Creature
# 2                        NaN  Creature
# 3  Flying, Revolt        NaN  Creature
# 4                        NaN  Creature

# %% [markdown]
# There is a small subset of creatures whose power and/or toughness is listed as '*'.  This means that those values are variable and dependent on game-state conditions.  We've only got 34 of these creatures in our dataset of almost 4,000, comprising less than 1% of the creatures.  Rather than spend an inordinate amount of time accounting for these edge cases, I choose to drop them from the dataframe.

# %%
len(creatures[creatures.power.isnull() | creatures.toughness.isnull()])
# Out:
# 34

# %%
creatures.drop(creatures[creatures.power.isnull() | creatures.toughness.isnull()].index, inplace=True)
creatures.reset_index(drop=True, inplace=True)

# %%
creatures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3811 entries, 0 to 3810
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        3811 non-null   object
#  1   colors      3811 non-null   object
#  2   manaValue   3811 non-null   float64
#  3   power       3811 non-null   float64
#  4   toughness   3811 non-null   float64
#  5   text        3811 non-null   object
#  6   rarity      3811 non-null   object
#  7   keywords    3811 non-null   object
#  8   supertypes  446 non-null    object
#  9   types       3811 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 297.9+ KB

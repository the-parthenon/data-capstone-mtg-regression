# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
all_cards = pd.read_csv('cleaned_datasets/allsets_cleaned.csv', index_col=0)

# %%
all_cards.head()
# Out:
#                   name colors  manaValue   manaCost  power  toughness  \
# 0  Aerial Modification      W        5.0     {4}{W}    NaN        NaN
# 1     Aeronaut Admiral      W        4.0     {3}{W}    3.0        1.0
# 2     Aether Inspector      W        4.0     {3}{W}    2.0        3.0
# 3    Aethergeode Miner      W        2.0     {1}{W}    3.0        1.0
# 4    Airdrop Aeronauts      W        5.0  {3}{W}{W}    4.0        3.0
#
#    loyalty                                               text    rarity  \
# 0      NaN  Enchant creature or Vehicle\nAs long as enchan...  uncommon
# 1      NaN          Flying\nVehicles you control have flying.  uncommon
# 2      NaN  Vigilance\nWhen Aether Inspector enters the ba...    common
# 3      NaN  Whenever Aethergeode Miner attacks, you get {E...      rare
# 4      NaN  Flying\nRevolt — When Airdrop Aeronauts enters...  uncommon
#
#          keywords supertypes        types          subtypes
# 0         Enchant        NaN  Enchantment              Aura
# 1          Flying        NaN     Creature      Human, Pilot
# 2       Vigilance        NaN     Creature  Dwarf, Artificer
# 3             NaN        NaN     Creature      Dwarf, Scout
# 4  Flying, Revolt        NaN     Creature      Dwarf, Scout

# %%
all_cards.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7125 entries, 0 to 7124
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        7125 non-null   object
#  1   colors      7125 non-null   object
#  2   manaValue   7125 non-null   float64
#  3   manaCost    6617 non-null   object
#  4   power       3867 non-null   float64
#  5   toughness   3877 non-null   float64
#  6   loyalty     168 non-null    float64
#  7   text        7025 non-null   object
#  8   rarity      7125 non-null   object
#  9   keywords    3399 non-null   object
#  10  supertypes  763 non-null    object
#  11  types       7125 non-null   object
#  12  subtypes    4636 non-null   object
# dtypes: float64(4), object(9)
# memory usage: 779.3+ KB

# %% [markdown]
# NaN values in the `keywords` column are to be expected, as many cards do not have keywords.  We will replace these with empty strings.

# %%
all_cards['keywords'].fillna('', inplace=True)

# %% [markdown]
# I want to get a dataframe that includes only creatures, but first we have to deal with one edge case:  non-creature cards that contain the "Transform" keyword.  I do this by writing out a function that can extract the mana value for cards that are formatted in the following way: "{B}{B}{2}: Transform".  We find the Transform keyword in the text of the card, then grab the string that immediately precedes it, calculate the additional cost to transform the card and add it to the correct cell (which will, in all cases, be the row immediately following the card with the Transform keyword.  This also fixes the mana value for the back sides of modal cards with the Transform keyword that are both creatures.

# %%
all_cards['text'].fillna('', inplace=True)

# %%
all_cards.loc[all_cards.keywords.str.contains('Transform', case=False)]
# Out:
#                       name colors  manaValue   manaCost  power  toughness  \
# 1546     Extricator of Sin      W        3.0     {2}{W}    0.0        3.0
# 1557            Lone Rider      W        2.0     {1}{W}    1.0        1.0
# 1579    Curious Homunculus      U        2.0     {1}{U}    1.0        1.0
# 1582  Docent of Perfection      U        5.0  {3}{U}{U}    5.0        4.0
# 1590       Grizzled Angler      U        3.0     {2}{U}    2.0        3.0
# ...                    ...    ...        ...        ...    ...        ...
# 6809     Primal Wellspring      L        4.0        NaN    NaN        NaN
# 6814     Thaumatic Compass      C        2.0        {2}    NaN        NaN
# 6815      Spires of Orazca      L        2.0        NaN    NaN        NaN
# 6816          Treasure Map      C        2.0        {2}    NaN        NaN
# 6817         Treasure Cove      L        2.0        NaN    NaN        NaN
#
#       loyalty                                               text    rarity  \
# 1546      NaN  When Extricator of Sin enters the battlefield,...  uncommon
# 1557      NaN  First strike, lifelink\nAt the beginning of th...  uncommon
# 1579      NaN  {T}: Add {C}. Spend this mana only to cast an ...  uncommon
# 1582      NaN  Flying\nWhenever you cast an instant or sorcer...      rare
# 1590      NaN  {T}: Mill two cards. Then if there is a colorl...  uncommon
# ...       ...                                                ...       ...
# 6809      NaN  (Transforms from Primal Amulet.)\n{T}: Add one...      rare
# 6814      NaN  {3}, {T}: Search your library for a basic land...      rare
# 6815      NaN  (Transforms from Thaumatic Compass.)\n{T}: Add...      rare
# 6816      NaN  {1}, {T}: Scry 1. Put a landmark counter on Tr...      rare
# 6817      NaN  (Transforms from Treasure Map.)\n{T}: Add {C}....      rare
#
#                                keywords supertypes     types        subtypes
# 1546                Delirium, Transform        NaN  Creature   Human, Cleric
# 1557  First strike, Lifelink, Transform        NaN  Creature   Human, Knight
# 1579                          Transform        NaN  Creature      Homunculus
# 1582                  Flying, Transform        NaN  Creature  Insect, Horror
# 1590                    Mill, Transform        NaN  Creature           Human
# ...                                 ...        ...       ...             ...
# 6809                          Transform        NaN      Land             NaN
# 6814                          Transform        NaN  Artifact             NaN
# 6815                          Transform        NaN      Land             NaN
# 6816                    Scry, Transform        NaN  Artifact             NaN
# 6817                          Transform        NaN      Land             NaN
#
# [197 rows x 13 columns]

# %%
def backwards_extract (df, keyword):
    import re
    
    # store the relevant index numbers from the dataframe
    indexes = df.loc[df.text.str.contains(keyword)].index

    # loop over each element to be changed
    for count, text in enumerate(df.loc[df.text.str.contains(keyword)].text):

        # find occurence of keyword
        c = text.find(keyword)

        # capture the text before the keyword
        if c <= 12:
            text_value = text[:c]
        else:
            text_value = text[c-12:c-2]

        # check to see that a curly brace exists before the keyword, confirming
        # that the text directly before it indicates an additional mana cost
        if '}' in text_value:
            text_value = text_value[text_value.find('{'):]

            # remove curly braces, Tap symbols, whitespace, colons
            text_value = re.sub('[,T:\s}{]', '', text_value)            

            # calculate value to use in dataframe 
            new_value = len(text_value) 
            if text_value[0].isdigit():
                new_value += int(text_value[0]) - 1

            # update the value of the NEXT card in the dataframe, the one that
            # our identified cards transform into
            df.iat[indexes[count] + 1, 2] += new_value
            
            # print a list of changes made so we can confirm we got it right
            print(df.iloc[indexes[count] +1, :4])

# %%
backwards_extract(all_cards, 'Transform')
# Out:
# name         Conduit of Emrakul
# colors                        C
# manaValue                   8.0
# manaCost                    NaN
# Name: 1655, dtype: object
# name         Erupting Dreadwolf
# colors                        C
# manaValue                  10.0
# manaCost                    NaN
# Name: 1675, dtype: object
# name         Dronepack Kindred
# colors                       C
# manaValue                 12.0
# manaCost                   NaN
# Name: 1682, dtype: object
# name         Sinuous Predator
# colors                      C
# manaValue                 6.0
# manaCost                  NaN
# Name: 1698, dtype: object
# name         Howling Chorus
# colors                    C
# manaValue               9.0
# manaCost                NaN
# Name: 1703, dtype: object
# name         Fibrous Entangler
# colors                       C
# manaValue                 11.0
# manaCost                   NaN
# Name: 1710, dtype: object
# name         Ulvenwald Abomination
# colors                           C
# manaValue                      9.0
# manaCost                       NaN
# Name: 1712, dtype: object
# name         Seasoned Cathar
# colors                     W
# manaValue                5.0
# manaCost                 NaN
# Name: 3007, dtype: object
# name         Mystic Monstrosity
# colors                        C
# manaValue                   7.0
# manaCost                    NaN
# Name: 3303, dtype: object
# name         Demon-Possessed Witch
# colors                           B
# manaValue                      6.0
# manaCost                       NaN
# Name: 5331, dtype: object
# name         Stonewing Antagonizer
# colors                           C
# manaValue                      7.0
# manaCost                       NaN
# Name: 5487, dtype: object
# name         Revealing Eye
# colors                   B
# manaValue              4.0
# manaCost               NaN
# Name: 6156, dtype: object
# name         Ulvenwald Behemoth
# colors                        G
# manaValue                  11.0
# manaCost                    NaN
# Name: 6294, dtype: object

# %% [markdown]
# We have a very similar problem with cards that have the "Disturb" mechanic, but the added difficulty that the mechanic is templated differently than the Transform mechanic (in that the keyword "Disturb" precedes the mana cost, where as the keyword "Transform" follows the mana cost).  So, below, I have a slightly tweaked function that grabs the mana value following the keyword, and we'll run that to update mana values for our Disturb creatures.

# %%
def extract_mana_value (df, keyword):
    import re
    
    # store the relevant index numbers from the dataframe
    indexes = df.loc[df.text.str.contains(keyword)].index

    # loop over each element to be changed
    for count, text in enumerate(df.loc[df.text.str.contains(keyword)].text):

        # find occurence of keyword
        c = text.find(keyword)

        # capture the text after the keyword that lists the mana cost of casting 
        # the card, leaving out leading and trailing curly braces.
        text_value = text[c+9:text.rfind('}', c+8, c+20)]

        # remove the rest of the curly braces
        text_value = re.sub('[,T:\s}{]', '', text_value)

        # calculate value to use in dataframe 
        new_value = len(text_value) 
        if text_value[0].isdigit():
            new_value += int(text_value[0]) - 1

        # update the value in the dataframe
        df.iat[indexes[count] + 1, 2] = new_value
        
        # print a list of changes made so we can confirm we got it right
        print(df.iloc[indexes[count] +1, :4])

# %%
creatures.loc[creatures.text.str.contains('Disturb')].head()
# Out:
#                   name colors  manaValue manaCost  power  toughness  \
# 1564    Beloved Beggar      W        2.0   {1}{W}    0.0        4.0
# 1573  Chaplain of Alms      W        1.0      {W}    1.0        1.0
# 1584   Lunarch Veteran      W        1.0      {W}    1.0        1.0
# 1586   Mourning Patrol      W        3.0   {2}{W}    2.0        3.0
# 1595   Baithook Angler      U        2.0   {1}{U}    2.0        1.0
#
#                                                    text    rarity  \
# 1564  Disturb {4}{W}{W} (You may cast this card from...  uncommon
# 1573  First strike\nWard {1} (Whenever this creature...  uncommon
# 1584  Whenever another creature enters the battlefie...    common
# 1586  Vigilance\nDisturb {3}{W} (You may cast this c...    common
# 1595  Disturb {1}{U} (You may cast this card from yo...    common
#
#                                     keywords supertypes     types  \
# 1564                      Disturb, Transform        NaN  Creature
# 1573  Disturb, First strike, Transform, Ward        NaN  Creature
# 1584                      Disturb, Transform        NaN  Creature
# 1586           Disturb, Transform, Vigilance        NaN  Creature
# 1595                      Disturb, Transform        NaN  Creature
#
#             subtypes
# 1564  Human, Peasant
# 1573   Human, Cleric
# 1584   Human, Cleric
# 1586  Human, Soldier
# 1595  Human, Peasant

# %%
extract_mana_value(creatures, 'Disturb')
# Out:
# name         Generous Soul
# colors                   W
# manaValue              6.0
# manaCost               NaN
# Name: 1565, dtype: object
# name         Chapel Shieldgeist
# colors                        W
# manaValue                   4.0
# manaCost                    NaN
# Name: 1574, dtype: object
# name         Luminous Phantom
# colors                      W
# manaValue                 2.0
# manaCost                  NaN
# Name: 1585, dtype: object
# name         Morning Apparition
# colors                        W
# manaValue                   4.0
# manaCost                    NaN
# Name: 1587, dtype: object
# name         Hook-Haunt Drifter
# colors                        U
# manaValue                   2.0
# manaCost                    NaN
# Name: 1596, dtype: object
# name         Ghostly Castigator
# colors                        U
# manaValue                   5.0
# manaCost                    NaN
# Name: 1599, dtype: object
# name         Waildrifter
# colors                 U
# manaValue            5.0
# manaCost             NaN
# Name: 1606, dtype: object
# name         Benevolent Geist
# colors                      U
# manaValue                 3.0
# manaCost                  NaN
# Name: 1610, dtype: object
# name         Archive Haunt
# colors                   U
# manaValue              4.0
# manaCost               NaN
# Name: 1614, dtype: object
# name         Covetous Geist
# colors                    B
# manaValue               5.0
# manaCost                NaN
# Name: 1634, dtype: object
# name         Dennick, Pious Apparition
# colors                            U, W
# manaValue                          4.0
# manaCost                           NaN
# Name: 1725, dtype: object
# name         Departed Soulkeeper
# colors                      U, W
# manaValue                    3.0
# manaCost                     NaN
# Name: 1727, dtype: object
# name         Drogskol Infantry
# colors                       W
# manaValue                  5.0
# manaCost                {1}{W}
# Name: 3269, dtype: object
# name         Estwald Shieldbasher
# colors                          W
# manaValue                     4.0
# manaCost                   {3}{W}
# Name: 3270, dtype: object
# name         Fleeting Spirit
# colors                     W
# manaValue                7.0
# manaCost              {1}{W}
# Name: 3272, dtype: object
# name         Kindly Ancestor
# colors                     W
# manaValue                5.0
# manaCost              {2}{W}
# Name: 3279, dtype: object
# name         Militia Rallier
# colors                     W
# manaValue                2.0
# manaCost              {2}{W}
# Name: 3280, dtype: object
# name         Unholy Officiant
# colors                      W
# manaValue                 3.0
# manaCost                  {W}
# Name: 3291, dtype: object
# name         Biolume Egg
# colors                 U
# manaValue            2.0
# manaCost          {2}{U}
# Name: 3296, dtype: object
# name         Hullbreaker Horror
# colors                        U
# manaValue                   4.0
# manaCost              {5}{U}{U}
# Name: 3306, dtype: object
# name         Mirrorhall Mimic
# colors                      U
# manaValue                 3.0
# manaCost               {3}{U}
# Name: 3309, dtype: object
# name         Mischievous Catgeist
# colors                          U
# manaValue                     5.0
# manaCost                   {1}{U}
# Name: 3310, dtype: object
# name         Overcharged Amalgam
# colors                         U
# manaValue                    3.0
# manaCost               {2}{U}{U}
# Name: 3311, dtype: object
# name         Child of the Pack
# colors                    G, R
# manaValue                  2.0
# manaCost             {2}{R}{G}
# Name: 3436, dtype: object
# name         Edgar, Charmed Groom
# colors                       B, W
# manaValue                     3.0
# manaCost                {2}{W}{B}
# Name: 3439, dtype: object

# %%
creatures = all_cards.loc[all_cards.types.str.contains('Creature')].copy()
creatures.reset_index(drop=True, inplace=True)

# %%
creatures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3845 entries, 0 to 3844
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        3845 non-null   object
#  1   colors      3845 non-null   object
#  2   manaValue   3845 non-null   float64
#  3   manaCost    3698 non-null   object
#  4   power       3814 non-null   float64
#  5   toughness   3824 non-null   float64
#  6   loyalty     0 non-null      float64
#  7   text        3845 non-null   object
#  8   rarity      3845 non-null   object
#  9   keywords    3845 non-null   object
#  10  supertypes  457 non-null    object
#  11  types       3845 non-null   object
#  12  subtypes    3845 non-null   object
# dtypes: float64(4), object(9)
# memory usage: 390.6+ KB

# %%
creatures.head()
# Out:
#                     name colors  manaValue   manaCost  power  toughness  \
# 0       Aeronaut Admiral      W        4.0     {3}{W}    3.0        1.0
# 1       Aether Inspector      W        4.0     {3}{W}    2.0        3.0
# 2      Aethergeode Miner      W        2.0     {1}{W}    3.0        1.0
# 3      Airdrop Aeronauts      W        5.0  {3}{W}{W}    4.0        3.0
# 4  Audacious Infiltrator      W        2.0     {1}{W}    3.0        1.0
#
#    loyalty                                               text    rarity  \
# 0      NaN          Flying\nVehicles you control have flying.  uncommon
# 1      NaN  Vigilance\nWhen Aether Inspector enters the ba...    common
# 2      NaN  Whenever Aethergeode Miner attacks, you get {E...      rare
# 3      NaN  Flying\nRevolt — When Airdrop Aeronauts enters...  uncommon
# 4      NaN  Audacious Infiltrator can't be blocked by arti...    common
#
#          keywords supertypes     types          subtypes
# 0          Flying        NaN  Creature      Human, Pilot
# 1       Vigilance        NaN  Creature  Dwarf, Artificer
# 2                        NaN  Creature      Dwarf, Scout
# 3  Flying, Revolt        NaN  Creature      Dwarf, Scout
# 4                        NaN  Creature      Dwarf, Rogue

# %% [markdown]
# The column "Loyalty" is a value that is unique to planeswalkers, so we're going to drop that right away.

# %%
creatures.drop(['loyalty'], axis=1, inplace=True)

# %%
creatures.head()
# Out:
#                     name colors  manaValue   manaCost  power  toughness  \
# 0       Aeronaut Admiral      W        4.0     {3}{W}    3.0        1.0
# 1       Aether Inspector      W        4.0     {3}{W}    2.0        3.0
# 2      Aethergeode Miner      W        2.0     {1}{W}    3.0        1.0
# 3      Airdrop Aeronauts      W        5.0  {3}{W}{W}    4.0        3.0
# 4  Audacious Infiltrator      W        2.0     {1}{W}    3.0        1.0
#
#                                                 text    rarity  \
# 0          Flying\nVehicles you control have flying.  uncommon
# 1  Vigilance\nWhen Aether Inspector enters the ba...    common
# 2  Whenever Aethergeode Miner attacks, you get {E...      rare
# 3  Flying\nRevolt — When Airdrop Aeronauts enters...  uncommon
# 4  Audacious Infiltrator can't be blocked by arti...    common
#
#          keywords supertypes     types          subtypes
# 0          Flying        NaN  Creature      Human, Pilot
# 1       Vigilance        NaN  Creature  Dwarf, Artificer
# 2                        NaN  Creature      Dwarf, Scout
# 3  Flying, Revolt        NaN  Creature      Dwarf, Scout
# 4                        NaN  Creature      Dwarf, Rogue

# %%
len(creatures[creatures.manaCost.isna()])
# Out:
# 147

# %% [markdown]
# There are 147 rows with NaN values for manaCost.  We have zero rows that have NaN values in manaValue, though, so these are almost definitely the backs of modal cards that transform through one game mechanic or another.  The amount of resources spent to cast the card is accurately reflected in the manaValue column, though the conditions for flipping the card are not going to be considered at this stage of our investigation.  Still, we'll do the same as we did above and check that this is true of about 10% of the data before dropping the column to make sure we didn't inadvertently introduce any errors.

# %%
creatures[creatures.manaCost.isna()].sample(15)
# Out:
#                             name colors  manaValue manaCost  power  toughness  \
# 2272     Reflection of Kiki-Jiki      R        3.0      NaN    2.0        2.0
# 1681             Ashmouth Dragon      R        2.0      NaN    4.0        4.0
# 2971             One of the Pack      G        4.0      NaN    5.0        6.0
# 2210         Portrait of Michiko      W        2.0      NaN    0.0        0.0
# 3379            Howlpack Avenger      R        4.0      NaN    4.0        4.0
# 1567           Dauntless Avenger      W        3.0      NaN    3.0        2.0
# 2937                Skin Shedder      R        1.0      NaN    3.0        4.0
# 2968  Werewolf of Ancient Hunger      G        5.0      NaN    NaN        NaN
# 862      Abolisher of Bloodlines      C        5.0      NaN    6.0        5.0
# 3391       Dire-Strain Anarchist      R        5.0      NaN    5.0        5.0
# 3317          Cipherbound Spirit      U        2.0      NaN    3.0        2.0
# 2943      Ancient of the Equinox      G        3.0      NaN    4.0        4.0
# 1624          Seafaring Werewolf      G        2.0      NaN    2.0        1.0
# 896             Sinuous Predator      C        6.0      NaN    4.0        4.0
# 3365            Ballista Wielder      R        4.0      NaN    5.0        5.0
#
#                                                    text    rarity  \
# 2272  {1}, {T}: Create a token that's a copy of anot...      rare
# 1681  Flying\nWhenever you cast an instant or sorcer...      rare
# 2971  At the beginning of each upkeep, if a player c...    common
# 2210  Portrait of Michiko gets +1/+1 for each artifa...  uncommon
# 3379  Whenever a permanent you control is dealt dama...      rare
# 1567  Whenever Dauntless Avenger attacks, return tar...  uncommon
# 2937                                                     uncommon
# 2968  Vigilance, trample\nWerewolf of Ancient Hunger...      rare
# 862   Flying\nWhen this creature transforms into Abo...      rare
# 3391  Menace, haste\nWhenever Dire-Strain Anarchist ...    mythic
# 3317  Flying\nCipherbound Spirit can block only crea...  uncommon
# 2943                                  Trample, hexproof  uncommon
# 1624  Seafaring Werewolf can't be blocked.\nWhenever...      rare
# 896   Sinuous Predator can't be blocked by more than...  uncommon
# 3365  {2}{R}: Ballista Wielder deals 1 damage to any...  uncommon
#
#                            keywords supertypes                  types  \
# 2272                                       NaN  Enchantment, Creature
# 1681                         Flying        NaN               Creature
# 2971                      Transform        NaN               Creature
# 2210                                       NaN  Enchantment, Creature
# 3379                     Nightbound        NaN               Creature
# 1567                                       NaN               Creature
# 2937                                       NaN               Creature
# 2968  Trample, Transform, Vigilance        NaN               Creature
# 862               Flying, Transform        NaN               Creature
# 3391      Haste, Menace, Nightbound        NaN               Creature
# 3317                         Flying        NaN               Creature
# 2943              Hexproof, Trample        NaN               Creature
# 1624                     Nightbound        NaN               Creature
# 896                                        NaN               Creature
# 3365                     Nightbound        NaN               Creature
#
#                subtypes
# 2272     Goblin, Shaman
# 1681             Dragon
# 2971           Werewolf
# 2210       Human, Noble
# 3379           Werewolf
# 1567     Human, Soldier
# 2937     Insect, Horror
# 2968           Werewolf
# 862    Eldrazi, Vampire
# 3391           Werewolf
# 3317             Spirit
# 2943           Treefolk
# 1624           Werewolf
# 896   Eldrazi, Werewolf
# 3365           Werewolf

# %% [markdown]
# In checking to make sure I didn't introduce any errors, I realized that the listed Mana Values for cards with the "Disturb" keyword were not reflective of the cost to cast their disturb mode, so I went ahead and built out a function that will let us extract the Disturb cost from the card text and replace that in the mana value field.

# %%
creatures.iat[25, 0]

# %%
creatures.loc[creatures.keywords.str.contains('Disturb')].head()
# Out:
#                   name colors  manaValue manaCost  power  toughness  \
# 1564    Beloved Beggar      W        2.0   {1}{W}    0.0        4.0
# 1573  Chaplain of Alms      W        1.0      {W}    1.0        1.0
# 1584   Lunarch Veteran      W        1.0      {W}    1.0        1.0
# 1586   Mourning Patrol      W        3.0   {2}{W}    2.0        3.0
# 1595   Baithook Angler      U        2.0   {1}{U}    2.0        1.0
#
#                                                    text    rarity  \
# 1564  Disturb {4}{W}{W} (You may cast this card from...  uncommon
# 1573  First strike\nWard {1} (Whenever this creature...  uncommon
# 1584  Whenever another creature enters the battlefie...    common
# 1586  Vigilance\nDisturb {3}{W} (You may cast this c...    common
# 1595  Disturb {1}{U} (You may cast this card from yo...    common
#
#                                     keywords supertypes     types  \
# 1564                      Disturb, Transform        NaN  Creature
# 1573  Disturb, First strike, Transform, Ward        NaN  Creature
# 1584                      Disturb, Transform        NaN  Creature
# 1586           Disturb, Transform, Vigilance        NaN  Creature
# 1595                      Disturb, Transform        NaN  Creature
#
#             subtypes
# 1564  Human, Peasant
# 1573   Human, Cleric
# 1584   Human, Cleric
# 1586  Human, Soldier
# 1595  Human, Peasant

# %% [markdown]
# We have two exceptions with cards that come into play as lands and then can later be flipped into creatures.  I'll go ahead and manually set reasonable manaValues for those two, since it's such a small number.

# %%
creatures[creatures.manaCost.isna()].query('manaValue == 0')

# %%
creatures.iat[2989, 2] = 5
creatures.iat[1750, 2] = 3

# %%
creatures.info()

# %%
creatures[creatures.manaCost.isna()].sample(15)

# %% [markdown]
# At this point, we should have dealt with most or all of the incorrectly assigned manaValue creatures, though we are not accounting for non-mana costs.  Doing so would be significantly more complicated and goes beyond the scope of the current investigation, so I'm happy to move on to other things that need to be corrected.  At this point, we should not need the manaCost column any longer, so I'll drop it.

# %%
creatures.drop(columns='manaCost', inplace=True)

# %%
creatures.head()

# %% [markdown]
# There is a small subset of creatures whose power and/or toughness is listed as '*'.  This means that those values are variable and dependent on game-state conditions.  We've only got 34 of these creatures in our dataset of almost 4,000, comprising less than 1% of the creatures.  Rather than spend an inordinate amount of time accounting for these edge cases, I choose to drop them from the dataframe.

# %%
len(creatures[creatures.power.isnull() | creatures.toughness.isnull()])

# %%
creatures.drop(creatures[creatures.power.isnull() | creatures.toughness.isnull()].index, inplace=True)
creatures.reset_index(drop=True, inplace=True)

# %%
creatures.info()

# %%
creatures = pd.concat([creatures, creatures.keywords.str.get_dummies(sep=", ")], axis=1)

# %%
creatures.head()

# %%
creatures.shape

# %%
creatures.columns

# %%
creatures.types.unique()

# %%
creatures = pd.concat([creatures, creatures.types.str.get_dummies(sep=", ")], axis=1)

# %%
creatures.head()

# %%
creatures.shape

# %% [markdown]
# Note to self:  Creature column should be 100% 1.  Probably need to drop it.

# %%
#creatures.supertypes.unique()

# %%
#creatures = pd.concat([creatures, creatures.supertypes.str.get_dummies(sep=", ")], axis=1)

# %%
#creatures.shape

# %%
#creatures.subtypes.unique()

# %%
#creatures = pd.concat([creatures, creatures.subtypes.str.get_dummies(sep=", ")], axis=1)

# %%
#creatures.shape

# %%
#creatures.head()

# %%
#creatures = pd.concat([creatures, creatures.colors.str.get_dummies(sep=", ")], axis=1)

# %%
#creatures.shape

# %%
#creatures.colors.unique()

# %%
creatures_transformed = creatures.drop(columns=['text', 'rarity', 'keywords', 'supertypes', 'types', 'subtypes'])

# %%
creatures_transformed.head()

# %%
creatures_transformed.info(verbose=True)

# %%
creatures_transformed.describe()

# %% [markdown]
# This is looking like we could actually start to use it for some machine learning analysis, so I'm going to export it to a CSV and pick up in a new file.

# %%
creatures_transformed.to_csv('cleaned_datasets/creatures_transformed.csv')

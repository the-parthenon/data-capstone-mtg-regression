# %%
import pandas as pd
import json

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# The files we are using are from the project MTGJSON (https://mtgjson.com/), and are actively maintained, so we won't expect much in the way of missing or incorrect information.  However, the original format includes a lot of extranneous information, and we'll need to do several different transformations of datatypes and similar small formatting in order to get each dataframe into the shape that we want for Exploratory Data Analysis and, eventually, model building.  I'll be downloading individual `.json` files for each set that will be included in our analysis, so we will start by looking at what is necessary to clean one file, then create a function that will allow us to quickly and easily clean up any additional sets.
#
#
# Each `.json` file is named via a three-character set abbreviation.  We'll use the Adventures in the Forgotten Realms (AFR) set to do our initial step-by-step cleaning.

# %%
df = pd.read_json('datasets/AFR.json', orient='index')
df
# Out:
#            date         version  baseSetSize  \
# meta 2022-06-20  5.2.0+20220620          NaN
# data        NaT             NaN        281.0
#
#                                                 booster  \
# meta                                                NaN
# data  {'arena': {'boosters': [{'contents': {'common'...
#
#                                                   cards  cardsphereSetId code  \
# meta                                                NaN              NaN  NaN
# data  [{'artist': 'Jarel Threat', 'availability': ['...           1337.0  AFR
#
#       isFoilOnly  isOnlineOnly keyruneCode   mcmId  mcmIdExtras  \
# meta         NaN           NaN         NaN     NaN          NaN
# data         0.0           0.0         AFR  4259.0       4260.0
#
#                                  mcmName mtgoCode  \
# meta                                 NaN      NaN
# data  Adventures in the Forgotten Realms      AFR
#
#                                     name releaseDate  \
# meta                                 NaN         NaN
# data  Adventures in the Forgotten Realms  2021-07-23
#
#                                           sealedProduct  tcgplayerGroupId  \
# meta                                                NaN               NaN
# data  [{'identifiers': {'tcgplayerProductId': '23873...            2823.0
#
#                                                  tokens  totalSetSize  \
# meta                                                NaN           NaN
# data  [{'artist': 'Irina Nordsol', 'availability': [...         402.0
#
#      translations       type
# meta          NaN        NaN
# data           {}  expansion

# %% [markdown]
# The initial dataframe consists of only two rows, "meta" and "data."  All of the data that we're currently interested in can be found in the cards column of the data row, so we will extract that as its own dataframe.

# %%
df = pd.DataFrame(df.cards[1])

# %%
df.head()
# Out:
#              artist          availability boosterTypes borderColor  \
# 0      Jarel Threat  [arena, mtgo, paper]      [draft]       black
# 1       Justyna Gil  [arena, mtgo, paper]      [draft]       black
# 2   Oriana Menendez  [arena, mtgo, paper]      [draft]       black
# 3  Daniel Ljunggren  [arena, mtgo, paper]      [draft]       black
# 4     Johannes Voss  [arena, mtgo, paper]      [draft]       black
#
#   colorIdentity colors  convertedManaCost  edhrecRank         finishes  \
# 0           [W]    [W]                2.0     11959.0  [nonfoil, foil]
# 1           [W]    [W]                4.0     16970.0  [nonfoil, foil]
# 2           [W]    [W]                3.0     12876.0  [nonfoil, foil]
# 3           [W]    [W]                3.0      3378.0  [nonfoil, foil]
# 4           [W]    [W]                3.0      7131.0  [nonfoil, foil]
#
#                                           flavorText  \
# 0  The weight of this magic weapon falls heavy on...
# 1  The noble steeds of the elven gods can sometim...
# 2  Blink dogs protect the wild places of the worl...
# 3                                                NaN
# 4            When all hope fails, its light remains.
#
#                                          foreignData frameVersion  hasFoil  \
# 0                                                 []         2015     True
# 1  [{'flavorText': 'Die edlen Reittiere der elfis...         2015     True
# 2  [{'flavorText': 'Flimmerhunde beschützen die w...         2015     True
# 3  [{'language': 'German', 'multiverseId': 527551...         2015     True
# 4  [{'flavorText': 'Wenn alle Hoffnung schwindet,...         2015     True
#
#    hasNonFoil                                        identifiers  \
# 0        True  {'cardKingdomFoilId': '248423', 'cardKingdomId...
# 1        True  {'cardKingdomFoilId': '248542', 'cardKingdomId...
# 2        True  {'cardKingdomFoilId': '248564', 'cardKingdomId...
# 3        True  {'cardKingdomFoilId': '248511', 'cardKingdomId...
# 4        True  {'cardKingdomFoilId': '248369', 'cardKingdomId...
#
#           keywords language  layout  \
# 0          [Equip]  English  normal
# 1         [Flying]  English  normal
# 2  [Double strike]  English  normal
# 3              NaN  English  normal
# 4              NaN  English  normal
#
#                                           legalities   manaCost  manaValue  \
# 0  {'alchemy': 'Legal', 'brawl': 'Legal', 'comman...     {1}{W}        2.0
# 1  {'alchemy': 'Legal', 'brawl': 'Legal', 'comman...     {3}{W}        4.0
# 2  {'alchemy': 'Legal', 'brawl': 'Legal', 'comman...     {2}{W}        3.0
# 3  {'alchemy': 'Legal', 'brawl': 'Legal', 'comman...  {W}{W}{W}        3.0
# 4  {'alchemy': 'Legal', 'brawl': 'Legal', 'comman...     {2}{W}        3.0
#
#                         name number    printings  \
# 0                    +2 Mace      1        [AFR]
# 1            Arborea Pegasus      2        [AFR]
# 2                  Blink Dog      3        [AFR]
# 3  The Book of Exalted Deeds      4  [AFR, PAFR]
# 4          Celestial Unicorn      5        [AFR]
#
#                                         purchaseUrls    rarity  \
# 0  {'cardKingdom': 'https://mtgjson.com/links/246...    common
# 1  {'cardKingdom': 'https://mtgjson.com/links/d46...    common
# 2  {'cardKingdom': 'https://mtgjson.com/links/d18...  uncommon
# 3  {'cardKingdom': 'https://mtgjson.com/links/eba...    mythic
# 4  {'cardKingdom': 'https://mtgjson.com/links/7c6...    common
#
#                                              rulings setCode     subtypes  \
# 0                                                 []     AFR  [Equipment]
# 1                                                 []     AFR    [Pegasus]
# 2  [{'date': '2021-07-23', 'text': 'Phased out pe...     AFR        [Dog]
# 3  [{'date': '2021-07-23', 'text': 'The enlighten...     AFR           []
# 4  [{'date': '2021-07-23', 'text': 'If you gain l...     AFR    [Unicorn]
#
#     supertypes                                               text  \
# 0           []  Equipped creature gets +2/+2.\nEquip {3} ({3}:...
# 1           []  Flying\nWhen Arborea Pegasus enters the battle...
# 2           []  Double strike\nTeleport — {3}{W}: Blink Dog ph...
# 3  [Legendary]  At the beginning of your end step, if you gain...
# 4           []  Whenever you gain life, put a +1/+1 counter on...
#
#                    type       types                                  uuid  \
# 0  Artifact — Equipment  [Artifact]  84d2e61d-46ef-5fa7-aeff-7a4cd8db71c8
# 1    Creature — Pegasus  [Creature]  6d3bc1d2-45a5-5010-b36b-6cc33c962d33
# 2        Creature — Dog  [Creature]  567a3bb4-1ad0-529f-9e0b-fe882f560c93
# 3    Legendary Artifact  [Artifact]  e5465719-ba59-52ef-b475-f553e6fc57f9
# 4    Creature — Unicorn  [Creature]  c228e9d4-2a6c-5f5c-bf27-93b3a8bd0852
#
#   power toughness                              variations frameEffects  \
# 0   NaN       NaN                                     NaN          NaN
# 1     2         3  [245a7947-877e-5b5d-b523-69bdf17a0950]          NaN
# 2     1         1  [196318b1-4d1a-5f41-a024-256e63c89a55]          NaN
# 3   NaN       NaN  [5031765f-0bd8-5866-89ac-2e9a3ec1b7e7]  [legendary]
# 4     3         2  [80a6282b-7e49-583e-b725-7d0d4ba8a13d]          NaN
#
#   securityStamp rebalancedPrintings isAlternative isOnlineOnly isRebalanced  \
# 0           NaN                 NaN           NaN          NaN          NaN
# 1           NaN                 NaN           NaN          NaN          NaN
# 2           NaN                 NaN           NaN          NaN          NaN
# 3          oval                 NaN           NaN          NaN          NaN
# 4           NaN                 NaN           NaN          NaN          NaN
#
#   isStarter originalPrintings leadershipSkills loyalty isReprint promoTypes  \
# 0       NaN               NaN              NaN     NaN       NaN        NaN
# 1       NaN               NaN              NaN     NaN       NaN        NaN
# 2       NaN               NaN              NaN     NaN       NaN        NaN
# 3       NaN               NaN              NaN     NaN       NaN        NaN
# 4       NaN               NaN              NaN     NaN       NaN        NaN
#
#   isPromo watermark
# 0     NaN       NaN
# 1     NaN       NaN
# 2     NaN       NaN
# 3     NaN       NaN
# 4     NaN       NaN

# %%
df.shape
# Out:
# (420, 51)

# %%
df.columns
# Out:
# Index(['artist', 'availability', 'boosterTypes', 'borderColor',
#        'colorIdentity', 'colors', 'convertedManaCost', 'edhrecRank',
#        'finishes', 'flavorText', 'foreignData', 'frameVersion', 'hasFoil',
#        'hasNonFoil', 'identifiers', 'keywords', 'language', 'layout',
#        'legalities', 'manaCost', 'manaValue', 'name', 'number', 'printings',
#        'purchaseUrls', 'rarity', 'rulings', 'setCode', 'subtypes',
#        'supertypes', 'text', 'type', 'types', 'uuid', 'power', 'toughness',
#        'variations', 'frameEffects', 'securityStamp', 'rebalancedPrintings',
#        'isAlternative', 'isOnlineOnly', 'isRebalanced', 'isStarter',
#        'originalPrintings', 'leadershipSkills', 'loyalty', 'isReprint',
#        'promoTypes', 'isPromo', 'watermark'],
#       dtype='object')

# %% [markdown]
# We can see from our row count that we have 420 different cards represented, however a quick reference of the List of MTG Sets article on Wikipedia (https://en.wikipedia.org/wiki/List_of_Magic:_The_Gathering_sets#Expansion_sets) tells us we should expect to see only 281 cards.  The MTGJSON files include separate entries for promotional versions of cards with alternate art as well as digital-only versions of cards that won't be important to our analysis, so we'll drop these from the list.

# %%
df = df[df['promoTypes'].isnull()]
df.shape
# Out:
# (299, 51)

# %%
df = df.loc[df['securityStamp'] != 'arena']
df.shape
# Out:
# (281, 51)

# %% [markdown]
# 281 cards is exactly what we expect to see, so now we will drop the Basic Lands from the dataset.  Every expansion includes the five basic land cards that are necessary to play the game, but they are in and of themselves irrelevant to any analysis that we plan to do, so we can drop them from each of the sets that we include in our analysis.

# %%
df = df.loc[~df['supertypes'].map(lambda x: bool('Basic' in x))]
df.shape
# Out:
# (261, 51)

# %% [markdown]
# The MTGJSON files include a wealth of information about each card, most of which will not be germaine to this specific analysis, so we choose a number that should be relevant, and drop the rest.

# %%
df = df.loc[:, ['name', 'colors', 'manaValue', 'manaCost', 'power', 'toughness', 
                    'loyalty', 'text', 'rarity', 'keywords', 'supertypes', 'types', 'subtypes']]

# %%
df.head(10)
# Out:
#                          name colors  manaValue   manaCost power toughness  \
# 0                     +2 Mace    [W]        2.0     {1}{W}   NaN       NaN
# 1             Arborea Pegasus    [W]        4.0     {3}{W}     2         3
# 2                   Blink Dog    [W]        3.0     {2}{W}     1         1
# 3   The Book of Exalted Deeds    [W]        3.0  {W}{W}{W}   NaN       NaN
# 4           Celestial Unicorn    [W]        3.0     {2}{W}     3         2
# 5                Cleric Class    [W]        1.0        {W}   NaN       NaN
# 6           Cloister Gargoyle    [W]        3.0     {2}{W}     0         4
# 8               Dancing Sword    [W]        2.0     {1}{W}   NaN       NaN
# 9          Dawnbringer Cleric    [W]        2.0     {1}{W}     1         3
# 10             Delver's Torch    [W]        2.0     {1}{W}   NaN       NaN
#
#    loyalty                                               text    rarity  \
# 0      NaN  Equipped creature gets +2/+2.\nEquip {3} ({3}:...    common
# 1      NaN  Flying\nWhen Arborea Pegasus enters the battle...    common
# 2      NaN  Double strike\nTeleport — {3}{W}: Blink Dog ph...  uncommon
# 3      NaN  At the beginning of your end step, if you gain...    mythic
# 4      NaN  Whenever you gain life, put a +1/+1 counter on...    common
# 5      NaN  (Gain the next level as a sorcery to add its a...  uncommon
# 6      NaN  When Cloister Gargoyle enters the battlefield,...  uncommon
# 8      NaN  Equipped creature gets +2/+1.\nWhen equipped c...      rare
# 9      NaN  When Dawnbringer Cleric enters the battlefield...    common
# 10     NaN  Equipped creature gets +1/+1.\nWhenever equipp...    common
#
#                              keywords   supertypes                 types  \
# 0                             [Equip]           []            [Artifact]
# 1                            [Flying]           []            [Creature]
# 2                     [Double strike]           []            [Creature]
# 3                                 NaN  [Legendary]            [Artifact]
# 4                                 NaN           []            [Creature]
# 5                                 NaN           []         [Enchantment]
# 6          [Venture into the dungeon]           []  [Artifact, Creature]
# 8                             [Equip]           []            [Artifact]
# 9                                 NaN           []            [Creature]
# 10  [Equip, Venture into the dungeon]           []            [Artifact]
#
#            subtypes
# 0       [Equipment]
# 1         [Pegasus]
# 2             [Dog]
# 3                []
# 4         [Unicorn]
# 5           [Class]
# 6        [Gargoyle]
# 8       [Equipment]
# 9   [Human, Cleric]
# 10      [Equipment]

# %% [markdown]
# Several columns of information that will be important to us are formatted as lists, which makes getting to the information with Pandas a bit tricky, so we're going to convert them from lists to strings.  We'll do this for the columns "colors", "keywords", "supertypes", and "types".  Unfortunately, the keywords column has NaN values instead of empty lists if the card has no keywords, so we'll first replace those NaNs with empty strings.

# %%
df['keywords'].fillna('', inplace=True)
to_unlist = ['colors', 'types', 'supertypes', 'subtypes', 'keywords']
for column in to_unlist:
    df[column] = [', '.join(map(str, l)) for l in df[column]]

# %%
df['text'].fillna('', inplace=True)

# %%
df.head(10)
# Out:
#                          name colors  manaValue   manaCost power toughness  \
# 0                     +2 Mace      W        2.0     {1}{W}   NaN       NaN
# 1             Arborea Pegasus      W        4.0     {3}{W}     2         3
# 2                   Blink Dog      W        3.0     {2}{W}     1         1
# 3   The Book of Exalted Deeds      W        3.0  {W}{W}{W}   NaN       NaN
# 4           Celestial Unicorn      W        3.0     {2}{W}     3         2
# 5                Cleric Class      W        1.0        {W}   NaN       NaN
# 6           Cloister Gargoyle      W        3.0     {2}{W}     0         4
# 8               Dancing Sword      W        2.0     {1}{W}   NaN       NaN
# 9          Dawnbringer Cleric      W        2.0     {1}{W}     1         3
# 10             Delver's Torch      W        2.0     {1}{W}   NaN       NaN
#
#    loyalty                                               text    rarity  \
# 0      NaN  Equipped creature gets +2/+2.\nEquip {3} ({3}:...    common
# 1      NaN  Flying\nWhen Arborea Pegasus enters the battle...    common
# 2      NaN  Double strike\nTeleport — {3}{W}: Blink Dog ph...  uncommon
# 3      NaN  At the beginning of your end step, if you gain...    mythic
# 4      NaN  Whenever you gain life, put a +1/+1 counter on...    common
# 5      NaN  (Gain the next level as a sorcery to add its a...  uncommon
# 6      NaN  When Cloister Gargoyle enters the battlefield,...  uncommon
# 8      NaN  Equipped creature gets +2/+1.\nWhen equipped c...      rare
# 9      NaN  When Dawnbringer Cleric enters the battlefield...    common
# 10     NaN  Equipped creature gets +1/+1.\nWhenever equipp...    common
#
#                            keywords supertypes               types  \
# 0                             Equip                       Artifact
# 1                            Flying                       Creature
# 2                     Double strike                       Creature
# 3                                    Legendary            Artifact
# 4                                                         Creature
# 5                                                      Enchantment
# 6          Venture into the dungeon             Artifact, Creature
# 8                             Equip                       Artifact
# 9                                                         Creature
# 10  Equip, Venture into the dungeon                       Artifact
#
#          subtypes
# 0       Equipment
# 1         Pegasus
# 2             Dog
# 3
# 4         Unicorn
# 5           Class
# 6        Gargoyle
# 8       Equipment
# 9   Human, Cleric
# 10      Equipment

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 261 entries, 0 to 278
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        261 non-null    object
#  1   colors      261 non-null    object
#  2   manaValue   261 non-null    float64
#  3   manaCost    252 non-null    object
#  4   power       142 non-null    object
#  5   toughness   142 non-null    object
#  6   loyalty     5 non-null      object
#  7   text        261 non-null    object
#  8   rarity      261 non-null    object
#  9   keywords    261 non-null    object
#  10  supertypes  261 non-null    object
#  11  types       261 non-null    object
#  12  subtypes    261 non-null    object
# dtypes: float64(1), object(12)
# memory usage: 28.5+ KB

# %% [markdown]
# We can see that there are four numeric columns that will likely interest us:  manaValue, power, toughness & loyalty.  However, the latter three are currently formatted as strings, so we will fix that. There is the possibility that values in these lists may include the value '*', indicating that they value is variable.  For simplicity's sake, we will use `errors='coerce'` to replace the variable power indicator with NaN.

# %%
to_convert = ['power', 'toughness', 'loyalty']
for column in to_convert:
    df[column] = pd.to_numeric(df[column], errors='coerce')

# %% [markdown]
# Another small edge case to consider is spells with variable costs to cast.  These are represented by having an 'X' in their manaCost.  There are a small number of them, so we can safely drop them from the dataframe, rather than do a ton of work to handle this small amount of edge cases.

# %%
df.manaCost.fillna('', inplace=True)

# %%
df[df.manaCost.str.contains('X')]
# Out:
#                          name colors  manaValue      manaCost  power  \
# 130    Sphere of Annihilation      B        1.0        {X}{B}    NaN
# 165              Meteor Swarm      R        3.0  {X}{R}{R}{R}    NaN
# 206                 Long Rest      G        3.0  {X}{G}{G}{G}    NaN
# 209               Ochre Jelly      G        1.0        {X}{G}    0.0
# 243  Orcus, Prince of Undeath   B, R        4.0  {X}{2}{B}{R}    5.0
#
#      toughness  loyalty                                               text  \
# 130        NaN      NaN  Sphere of Annihilation enters the battlefield ...
# 165        NaN      NaN  Meteor Swarm deals 8 damage divided as you cho...
# 206        NaN      NaN  Return X target cards with different mana valu...
# 209        0.0      NaN  Trample\nOchre Jelly enters the battlefield wi...
# 243        3.0      NaN  Flying, trample\nWhen Orcus, Prince of Undeath...
#
#     rarity         keywords supertypes     types subtypes
# 130   rare                              Artifact
# 165   rare                               Sorcery
# 206   rare                               Sorcery
# 209   rare          Trample             Creature     Ooze
# 243   rare  Flying, Trample  Legendary  Creature    Demon

# %%
df.drop(df[df.manaCost.str.contains('X')].index, inplace=True)

# %% [markdown]
# We've removed some items from the set, so we'll go ahead and reset the index numbers.

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        256 non-null    object
#  1   colors      256 non-null    object
#  2   manaValue   256 non-null    float64
#  3   manaCost    256 non-null    object
#  4   power       140 non-null    float64
#  5   toughness   140 non-null    float64
#  6   loyalty     5 non-null      float64
#  7   text        256 non-null    object
#  8   rarity      256 non-null    object
#  9   keywords    256 non-null    object
#  10  supertypes  256 non-null    object
#  11  types       256 non-null    object
#  12  subtypes    256 non-null    object
# dtypes: float64(4), object(9)
# memory usage: 26.1+ KB

# %% [markdown]
# The `colors` column needs some attention.  By game rules, lands themselves do not have colors, even though they are the main way to produce colored mana.  There are also some cards, known as 'colorless' cards that can be cast using any color of mana, and should be currently listed as an empty string in the colors column.  For lands, we will change the `colors` value to 'L'.  For colorless, we'll represent it by the letter 'C'.  Neither of these letters is used anywhere else in the `colors` column, so this should safely designate them without conflict.

# %%
df.colors.unique()
# Out:
# array(['W', 'U', 'B', 'R', 'G', 'R, W', 'G, R', 'B, W', 'G, W', 'R, U',
#        'G, U', 'U, W', 'B, R', 'B, U', 'G, R, W', 'B, G', 'B, G, R, U, W',
#        ''], dtype=object)

# %%
df.colors = df.colors.mask(df.colors.eq('') & df.types.str.contains('Land', case=False), 'L')

# %%
df.loc[df.types.eq('Land')].head()
# Out:
#                          name colors  manaValue manaCost  power  toughness  \
# 247  Cave of the Frost Dragon      L        0.0             NaN        NaN
# 248        Den of the Bugbear      L        0.0             NaN        NaN
# 249           Dungeon Descent      L        0.0             NaN        NaN
# 250            Evolving Wilds      L        0.0             NaN        NaN
# 251      Hall of Storm Giants      L        0.0             NaN        NaN
#
#      loyalty                                               text  rarity  \
# 247      NaN  If you control two or more other lands, Cave o...    rare
# 248      NaN  If you control two or more other lands, Den of...    rare
# 249      NaN  Dungeon Descent enters the battlefield tapped....    rare
# 250      NaN  {T}, Sacrifice Evolving Wilds: Search your lib...  common
# 251      NaN  If you control two or more other lands, Hall o...    rare
#
#                      keywords supertypes types subtypes
# 247                                       Land
# 248                                       Land
# 249  Venture into the dungeon             Land
# 250                                       Land
# 251                                       Land

# %%
df.colors = df.colors.mask(df.colors.eq(''), 'C')

# %%
df.colors.unique()
# Out:
# array(['W', 'U', 'B', 'R', 'G', 'R, W', 'G, R', 'B, W', 'G, W', 'R, U',
#        'G, U', 'U, W', 'B, R', 'B, U', 'G, R, W', 'B, G', 'B, G, R, U, W',
#        'C', 'L'], dtype=object)

# %% [markdown]
# The above array indicates zero instances of empty strings in the `colors` column, so we'll consider that handled.

# %% [markdown]
# This looks like a good place to start from, so we'll create a function that includes all of these steps.  We can then put each of the individual sets that we want to clean in a list and iterate over it with the function to give us a list of dataframes, which we can then write out to `.csv` format to give us a number of cleaned individual datasets that are identically formatted, which will allow us to easily combine them.

# %% [markdown]
# #### Handling Modal Cards
#
# Many cards in the sets that we are considering are modal in nature, meaning that a single card can be played in one of two distinct ways.  In the MTGJSON datasets, each mode of a single card has its own row, but both rows have the same name in the format "MODE 1 // MODE 2". For the sake of this analysis, we will treat each mode of such a card as its own card. We will add a function to be called within our cleaning function that will rename each of these entries to reflect the name of casting that specific mode.

# %%
def drop_modal_names (df):
    if 'faceName' in df.columns:
        df['faceName'].fillna(df['name'], inplace=True)
        df.drop(['name'], inplace=True, axis=1)
        df.rename(columns={'faceName':'name'}, inplace=True)

# %%
def initial_cleaning (json_file):
    df = pd.read_json(json_file, orient='index')
    df = pd.DataFrame(df.cards[1])
    
    # Removing promos, online only cards, basic lands.    
    if 'promoTypes' in df.columns:
        df = df[df['promoTypes'].isnull()]
    df = df.loc[df['securityStamp'] != 'arena']
    df = df.loc[~df['supertypes'].map(lambda x: bool('Basic' in x))]
    
    # Renaming modal cards
    drop_modal_names(df)
    
    # Choosing the columns we want to keep.
    df = df.loc[:, ['name', 'colors', 'manaValue', 'manaCost', 'power', 'toughness', 
                    'loyalty', 'text', 'rarity', 'keywords', 'supertypes', 'types', 'subtypes']]
    
    # Resetting the index before we do anything else.
    df.reset_index(drop=True, inplace=True)
    
    # Changing list values to string values
    to_unlist = ['colors', 'types', 'supertypes', 'keywords', 'subtypes']
    df['keywords'].fillna('', inplace=True)
    for column in to_unlist:
        df[column] = [', '.join(map(str, l)) for l in df[column]]
    
    # Converting numeric columns to numeric datatypes
    to_convert = ['power', 'toughness', 'loyalty']
    for column in to_convert:
        df[column] = pd.to_numeric(df[column], errors='coerce')
        
    # Dropping cards with variable manaValues
    df.manaCost.fillna('', inplace=True)
    df.drop(df[df.manaCost.str.contains('X')].index, inplace=True)
        
    # Assigning color values of 'L' to Lands and 'C' to colorless cards.
    df.colors = df.colors.mask(df.colors.eq('') & df.types.str.contains('Land', case=False), 'L')
    df.colors = df.colors.mask(df.colors.eq(''), 'C')

    # Just in case we missed any duplicated entries with our initial cleaning steps, we drop them here and
    # reset the index one last time.
    df.drop_duplicates(inplace=True)
    df.reset_index(drop=True, inplace=True)
    return df

# %%
files = ['AER', 'AFR', 'AKH', 'BFZ', 'DOM', 'ELD', 'EMN', 'GRN', 'HOU', 'IKO', 'KHM', 'KLD', 'MID', 'M19', 'M20', 'M21',
         'NEO', 'OGW', 'RIX', 'RNA', 'SNC', 'SOI', 'STX', 'THB', 'VOW', 'WAR', 'XLN', 'ZNR']
dfs = []

# %%
len(files)
# Out:
# 28

# %%
for f in files:
    dfs.append(initial_cleaning('datasets/'+f+'.json'))

# %%
for df, f in zip(dfs, files):
    df.to_csv('cleaned_datasets/'+f+'_cleaned.csv')

# %% [markdown]
# With our individual sets cleaned and exported, we'll now merge them all in to a single dataframe, using the `reduce()` function.

# %%
from functools import reduce

# %%
df_merged = reduce(lambda left,right: pd.merge(left, right, how='outer'), dfs)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7045 entries, 0 to 7044
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        7045 non-null   object
#  1   colors      7045 non-null   object
#  2   manaValue   7045 non-null   float64
#  3   manaCost    7045 non-null   object
#  4   power       3848 non-null   float64
#  5   toughness   3858 non-null   float64
#  6   loyalty     167 non-null    float64
#  7   text        6945 non-null   object
#  8   rarity      7045 non-null   object
#  9   keywords    7045 non-null   object
#  10  supertypes  7045 non-null   object
#  11  types       7045 non-null   object
#  12  subtypes    7045 non-null   object
# dtypes: float64(4), object(9)
# memory usage: 770.5+ KB

# %% [markdown]
# We check for any cards that are have identical names.  A handful pop up, and the reason for this is that they are cards that have been reprinted at later times with a different rarity value than their earlier printing.  The number of cards this applies to is fairly small, so we'll just drop the duplicates, keeping the first occurrence of that particular card.

# %%
df_merged[df_merged.duplicated(subset= 'name', keep=False)]
# Out:
#                     name colors  manaValue   manaCost  power  toughness  \
# 182     Tranquil Expanse      L        0.0               NaN        NaN
# 187   Submerged Boneyard      L        0.0               NaN        NaN
# 422       Bag of Holding      C        1.0        {1}    NaN        NaN
# 607     Gift of Paradise      G        3.0     {2}{G}    NaN        NaN
# 704         Stone Quarry      L        0.0               NaN        NaN
# 709         Foul Orchard      L        0.0               NaN        NaN
# 710       Cinder Barrens      L        0.0               NaN        NaN
# 711   Forsaken Sanctuary      L        0.0               NaN        NaN
# 712        Highland Lake      L        0.0               NaN        NaN
# 713     Meandering River      L        0.0               NaN        NaN
# 714         Timber Gorge      L        0.0               NaN        NaN
# 715      Woodland Stream      L        0.0               NaN        NaN
# 1596              Murder      B        3.0  {1}{B}{B}    NaN        NaN
# 1650    Thermo-Alchemist      R        2.0     {1}{R}    0.0        3.0
# 1958         Silent Dart      C        1.0        {1}    NaN        NaN
# 2060              Abrade      R        2.0     {1}{R}    NaN        NaN
# 3156    Thermo-Alchemist      R        2.0     {1}{R}    0.0        3.0
# 3309         Bone to Ash      U        4.0  {2}{U}{U}    NaN        NaN
# 3406       Tectonic Rift      R        4.0     {3}{R}    NaN        NaN
# 3423    Gift of Paradise      G        3.0     {2}{G}    NaN        NaN
# 3554         Bone to Ash      U        4.0  {2}{U}{U}    NaN        NaN
# 3603              Murder      B        3.0  {1}{B}{B}    NaN        NaN
# 3649       Tectonic Rift      R        4.0     {3}{R}    NaN        NaN
# 3651        Uncaged Fury      R        3.0     {2}{R}    NaN        NaN
# 3670     Pulse of Murasa      G        3.0     {2}{G}    NaN        NaN
# 3700      Bag of Holding      C        1.0        {1}    NaN        NaN
# 3859   Grasp of Darkness      B        2.0     {B}{B}    NaN        NaN
# 3970         Silent Dart      C        1.0        {1}    NaN        NaN
# 4360   Grasp of Darkness      B        2.0     {B}{B}    NaN        NaN
# 4413     Pulse of Murasa      G        3.0     {2}{G}    NaN        NaN
# 4439     Strider Harness      C        3.0        {3}    NaN        NaN
# 4440      Cinder Barrens      L        0.0               NaN        NaN
# 4445    Meandering River      L        0.0               NaN        NaN
# 4450  Submerged Boneyard      L        0.0               NaN        NaN
# 4451        Timber Gorge      L        0.0               NaN        NaN
# 4452    Tranquil Expanse      L        0.0               NaN        NaN
# 4633     Strider Harness      C        3.0        {3}    NaN        NaN
# 4635  Forsaken Sanctuary      L        0.0               NaN        NaN
# 4636        Foul Orchard      L        0.0               NaN        NaN
# 4637       Highland Lake      L        0.0               NaN        NaN
# 4638        Stone Quarry      L        0.0               NaN        NaN
# 4639     Woodland Stream      L        0.0               NaN        NaN
# 5349        Uncaged Fury      R        3.0     {2}{R}    NaN        NaN
# 6132              Abrade      R        2.0     {1}{R}    NaN        NaN
#
#       loyalty                                               text    rarity  \
# 182       NaN  Tranquil Expanse enters the battlefield tapped...    common
# 187       NaN  Submerged Boneyard enters the battlefield tapp...    common
# 422       NaN  Whenever you discard a card, exile that card f...  uncommon
# 607       NaN  Enchant land\nWhen Gift of Paradise enters the...    common
# 704       NaN  Stone Quarry enters the battlefield tapped.\n{...    common
# 709       NaN  Foul Orchard enters the battlefield tapped.\n{...    common
# 710       NaN  Cinder Barrens enters the battlefield tapped.\...    common
# 711       NaN  Forsaken Sanctuary enters the battlefield tapp...    common
# 712       NaN  Highland Lake enters the battlefield tapped.\n...    common
# 713       NaN  Meandering River enters the battlefield tapped...    common
# 714       NaN  Timber Gorge enters the battlefield tapped.\n{...    common
# 715       NaN  Woodland Stream enters the battlefield tapped....    common
# 1596      NaN                           Destroy target creature.  uncommon
# 1650      NaN  Defender\n{T}: Thermo-Alchemist deals 1 damage...    common
# 1958      NaN  {4}, {T}, Sacrifice Silent Dart: It deals 3 da...  uncommon
# 2060      NaN  Choose one —\n• Abrade deals 3 damage to targe...  uncommon
# 3156      NaN  Defender\n{T}: Thermo-Alchemist deals 1 damage...  uncommon
# 3309      NaN       Counter target creature spell.\nDraw a card.  uncommon
# 3406      NaN  Destroy target land. Creatures without flying ...  uncommon
# 3423      NaN  Enchant land\nWhen Gift of Paradise enters the...  uncommon
# 3554      NaN       Counter target creature spell.\nDraw a card.    common
# 3603      NaN                           Destroy target creature.    common
# 3649      NaN  Destroy target land. Creatures without flying ...    common
# 3651      NaN  Target creature gets +1/+1 and gains double st...  uncommon
# 3670      NaN  Return target creature or land card from a gra...  uncommon
# 3700      NaN  Whenever you discard a card, exile that card f...      rare
# 3859      NaN      Target creature gets -4/-4 until end of turn.    common
# 3970      NaN  {4}, {T}, Sacrifice Silent Dart: It deals 3 da...    common
# 4360      NaN      Target creature gets -4/-4 until end of turn.  uncommon
# 4413      NaN  Return target creature or land card from a gra...    common
# 4439      NaN  Equipped creature gets +1/+1 and has haste.\nE...  uncommon
# 4440      NaN  Cinder Barrens enters the battlefield tapped.\...  uncommon
# 4445      NaN  Meandering River enters the battlefield tapped...  uncommon
# 4450      NaN  Submerged Boneyard enters the battlefield tapp...  uncommon
# 4451      NaN  Timber Gorge enters the battlefield tapped.\n{...  uncommon
# 4452      NaN  Tranquil Expanse enters the battlefield tapped...  uncommon
# 4633      NaN  Equipped creature gets +1/+1 and has haste.\nE...    common
# 4635      NaN  Forsaken Sanctuary enters the battlefield tapp...  uncommon
# 4636      NaN  Foul Orchard enters the battlefield tapped.\n{...  uncommon
# 4637      NaN  Highland Lake enters the battlefield tapped.\n...  uncommon
# 4638      NaN  Stone Quarry enters the battlefield tapped.\n{...  uncommon
# 4639      NaN  Woodland Stream enters the battlefield tapped....  uncommon
# 5349      NaN  Target creature gets +1/+1 and gains double st...    common
# 6132      NaN  Choose one —\n• Abrade deals 3 damage to targe...    common
#
#       keywords supertypes        types       subtypes
# 182                               Land
# 187                               Land
# 422                           Artifact
# 607    Enchant             Enchantment           Aura
# 704                               Land
# 709                               Land
# 710                               Land
# 711                               Land
# 712                               Land
# 713                               Land
# 714                               Land
# 715                               Land
# 1596                           Instant
# 1650  Defender                Creature  Human, Shaman
# 1958                          Artifact
# 2060                           Instant
# 3156  Defender                Creature  Human, Shaman
# 3309                           Instant
# 3406                           Sorcery
# 3423   Enchant             Enchantment           Aura
# 3554                           Instant
# 3603                           Instant
# 3649                           Sorcery
# 3651                           Instant
# 3670                           Instant
# 3700                          Artifact
# 3859                           Instant
# 3970                          Artifact
# 4360                           Instant
# 4413                           Instant
# 4439     Equip                Artifact      Equipment
# 4440                              Land
# 4445                              Land
# 4450                              Land
# 4451                              Land
# 4452                              Land
# 4633     Equip                Artifact      Equipment
# 4635                              Land
# 4636                              Land
# 4637                              Land
# 4638                              Land
# 4639                              Land
# 5349                           Instant
# 6132                           Instant

# %%
df_merged.drop_duplicates(subset='name', keep='first', inplace=True)

# %%
df_merged[df_merged.duplicated(subset= 'name', keep=False)]
# Out:
# Empty DataFrame
# Columns: [name, colors, manaValue, manaCost, power, toughness, loyalty, text, rarity, keywords, supertypes, types, subtypes]
# Index: []

# %% [markdown]
# There is one more edge case to deal with at this point, and it is a keyword that the MTGJson db lists as "Venture into the dungeon."  While it is in fact the official name of the mechanic, it's pretty verbose, so we'll replace that with just "Venture" going forward.

# %%
df_merged[df_merged.keywords.str.contains('Venture', case=False)].head()
# Out:
#                          name colors  manaValue   manaCost  power  toughness  \
# 194         Cloister Gargoyle      W        3.0     {2}{W}    0.0        4.0
# 197            Delver's Torch      W        2.0     {1}{W}    NaN        NaN
# 209         Keen-Eared Sentry      W        2.0     {1}{W}    2.0        1.0
# 214  Nadaar, Selfless Paladin      W        3.0     {2}{W}    3.0        3.0
# 218               Planar Ally      W        5.0  {3}{W}{W}    3.0        3.0
#
#      loyalty                                               text    rarity  \
# 194      NaN  When Cloister Gargoyle enters the battlefield,...  uncommon
# 197      NaN  Equipped creature gets +1/+1.\nWhenever equipp...    common
# 209      NaN  You have hexproof. (You can't be the target of...  uncommon
# 214      NaN  Vigilance\nWhenever Nadaar, Selfless Paladin e...      rare
# 218      NaN  Flying\nWhenever Planar Ally attacks, venture ...    common
#
#                                 keywords supertypes               types  \
# 194             Venture into the dungeon             Artifact, Creature
# 197      Equip, Venture into the dungeon                       Artifact
# 209             Venture into the dungeon                       Creature
# 214  Venture into the dungeon, Vigilance  Legendary            Creature
# 218     Flying, Venture into the dungeon                       Creature
#
#            subtypes
# 194        Gargoyle
# 197       Equipment
# 209  Human, Soldier
# 214  Dragon, Knight
# 218           Angel

# %%
df_merged.keywords.replace(to_replace='Venture into the dungeon', value='Venture', regex=True, inplace=True)

# %%
df_merged[df_merged.keywords.str.contains('Venture', case=False)].head()
# Out:
#                          name colors  manaValue   manaCost  power  toughness  \
# 194         Cloister Gargoyle      W        3.0     {2}{W}    0.0        4.0
# 197            Delver's Torch      W        2.0     {1}{W}    NaN        NaN
# 209         Keen-Eared Sentry      W        2.0     {1}{W}    2.0        1.0
# 214  Nadaar, Selfless Paladin      W        3.0     {2}{W}    3.0        3.0
# 218               Planar Ally      W        5.0  {3}{W}{W}    3.0        3.0
#
#      loyalty                                               text    rarity  \
# 194      NaN  When Cloister Gargoyle enters the battlefield,...  uncommon
# 197      NaN  Equipped creature gets +1/+1.\nWhenever equipp...    common
# 209      NaN  You have hexproof. (You can't be the target of...  uncommon
# 214      NaN  Vigilance\nWhenever Nadaar, Selfless Paladin e...      rare
# 218      NaN  Flying\nWhenever Planar Ally attacks, venture ...    common
#
#                keywords supertypes               types        subtypes
# 194             Venture             Artifact, Creature        Gargoyle
# 197      Equip, Venture                       Artifact       Equipment
# 209             Venture                       Creature  Human, Soldier
# 214  Venture, Vigilance  Legendary            Creature  Dragon, Knight
# 218     Flying, Venture                       Creature           Angel

# %%
df_merged.shape
# Out:
# (7023, 13)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7023 entries, 0 to 7044
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        7023 non-null   object
#  1   colors      7023 non-null   object
#  2   manaValue   7023 non-null   float64
#  3   manaCost    7023 non-null   object
#  4   power       3847 non-null   float64
#  5   toughness   3857 non-null   float64
#  6   loyalty     167 non-null    float64
#  7   text        6923 non-null   object
#  8   rarity      7023 non-null   object
#  9   keywords    7023 non-null   object
#  10  supertypes  7023 non-null   object
#  11  types       7023 non-null   object
#  12  subtypes    7023 non-null   object
# dtypes: float64(4), object(9)
# memory usage: 768.1+ KB

# %%
df_merged.reset_index(drop=True, inplace=True)

# %% [markdown]
# We have two exceptions with cards that come into play as lands and then can later be flipped into creatures.  I'll go ahead and manually set reasonable manaValues for those two, since it's such a small number.

# %%
df_merged[df_merged.manaValue.eq(0)].query('colors != "L"')
# Out:
#                            name colors  manaValue manaCost  power  toughness  \
# 161                 Ornithopter      C        0.0      {0}    0.0        2.0
# 1178                  Mox Amber      C        0.0      {0}    NaN        NaN
# 1700            Cathar's Shield      C        0.0      {0}    NaN        NaN
# 3265               Creeping Inn      B        0.0             3.0        7.0
# 3966             Tormod's Crypt      C        0.0      {0}    NaN        NaN
# 4424                   Bone Saw      C        0.0      {0}    NaN        NaN
# 5425  Ormendahl, Profane Prince      B        0.0             9.0        7.0
#
#       loyalty                                               text    rarity  \
# 161       NaN                                             Flying  uncommon
# 1178      NaN  {T}: Add one mana of any color among legendary...    mythic
# 1700      NaN  Equipped creature gets +0/+3 and has vigilance...    common
# 3265      NaN  Whenever Creeping Inn attacks, you may exile a...    mythic
# 3966      NaN  {T}, Sacrifice Tormod's Crypt: Exile target pl...  uncommon
# 4424      NaN  Equipped creature gets +1/+0.\nEquip {1} ({1}:...    common
# 5425      NaN            Flying, lifelink, indestructible, haste      rare
#
#                                      keywords supertypes               types  \
# 161                                    Flying             Artifact, Creature
# 1178                                           Legendary            Artifact
# 1700                                    Equip                       Artifact
# 3265                                                      Artifact, Creature
# 3966                                                                Artifact
# 4424                                    Equip                       Artifact
# 5425  Flying, Haste, Indestructible, Lifelink  Legendary            Creature
#
#                subtypes
# 161             Thopter
# 1178
# 1700          Equipment
# 3265  Horror, Construct
# 3966
# 4424          Equipment
# 5425              Demon

# %%
df_merged.iat[3265, 2] = 3
df_merged.iat[5425, 2] = 5

# %%
df_merged.head()
# Out:
#                   name colors  manaValue   manaCost  power  toughness  \
# 0  Aerial Modification      W        5.0     {4}{W}    NaN        NaN
# 1     Aeronaut Admiral      W        4.0     {3}{W}    3.0        1.0
# 2     Aether Inspector      W        4.0     {3}{W}    2.0        3.0
# 3    Aethergeode Miner      W        2.0     {1}{W}    3.0        1.0
# 4    Airdrop Aeronauts      W        5.0  {3}{W}{W}    4.0        3.0
#
#    loyalty                                               text    rarity  \
# 0      NaN  Enchant creature or Vehicle\nAs long as enchan...  uncommon
# 1      NaN          Flying\nVehicles you control have flying.  uncommon
# 2      NaN  Vigilance\nWhen Aether Inspector enters the ba...    common
# 3      NaN  Whenever Aethergeode Miner attacks, you get {E...      rare
# 4      NaN  Flying\nRevolt — When Airdrop Aeronauts enters...  uncommon
#
#          keywords supertypes        types          subtypes
# 0         Enchant             Enchantment              Aura
# 1          Flying                Creature      Human, Pilot
# 2       Vigilance                Creature  Dwarf, Artificer
# 3                                Creature      Dwarf, Scout
# 4  Flying, Revolt                Creature      Dwarf, Scout

# %%
df_merged.to_csv('cleaned_datasets/allsets_cleaned.csv')

# %% [markdown]
# We now have a relatively clean dataset for each of the 28 sets that we're considering for this analysis, as well a master dataframe that consists of a little over 7,000 cards.  We can now comfortably move on to doing some exploratory data analysis and statistical description of our dataset.

# %%
import pandas as pd
import json

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# The files we are using are from the project MTGJSON (https://mtgjson.com/), and are actively maintained, so we won't expect much in the way of missing or incorrect information.  However, the original format includes a lot of extranneous information, and we'll need to do several different transformations of datatypes and similar small formatting in order to get each dataframe into the shape that we want for Exploratory Data Analysis and, eventually, model building.  I'll be downloading individual `.json` files for each set that will be included in our analysis, so we will start by looking at what is necessary to clean one file, then create a function that will allow us to quickly and easily clean up any additional sets.
#
#
# Each `.json` file is named via a three-character set abbreviation.  We'll use the Adventures in the Forgotten Realms (AFR) set to do our initial step-by-step cleaning.

# %%
df = pd.read_json('datasets/AFR.json', orient='index')
df
# Out:
#            date         version  baseSetSize  \
# meta 2022-06-20  5.2.0+20220620          NaN
# data        NaT             NaN        281.0
#
#                                                 booster  \
# meta                                                NaN
# data  {'arena': {'boosters': [{'contents': {'common'...
#
#                                                   cards  cardsphereSetId code  \
# meta                                                NaN              NaN  NaN
# data  [{'artist': 'Jarel Threat', 'availability': ['...           1337.0  AFR
#
#       isFoilOnly  isOnlineOnly keyruneCode   mcmId  mcmIdExtras  \
# meta         NaN           NaN         NaN     NaN          NaN
# data         0.0           0.0         AFR  4259.0       4260.0
#
#                                  mcmName mtgoCode  \
# meta                                 NaN      NaN
# data  Adventures in the Forgotten Realms      AFR
#
#                                     name releaseDate  \
# meta                                 NaN         NaN
# data  Adventures in the Forgotten Realms  2021-07-23
#
#                                           sealedProduct  tcgplayerGroupId  \
# meta                                                NaN               NaN
# data  [{'identifiers': {'tcgplayerProductId': '23873...            2823.0
#
#                                                  tokens  totalSetSize  \
# meta                                                NaN           NaN
# data  [{'artist': 'Irina Nordsol', 'availability': [...         402.0
#
#      translations       type
# meta          NaN        NaN
# data           {}  expansion

# %% [markdown]
# The initial dataframe consists of only two rows, "meta" and "data."  All of the data that we're currently interested in can be found in the cards column of the data row, so we will extract that as its own dataframe.

# %%
df = pd.DataFrame(df.cards[1])

# %%
df.head()
# Out:
#              artist          availability boosterTypes borderColor  \
# 0      Jarel Threat  [arena, mtgo, paper]      [draft]       black
# 1       Justyna Gil  [arena, mtgo, paper]      [draft]       black
# 2   Oriana Menendez  [arena, mtgo, paper]      [draft]       black
# 3  Daniel Ljunggren  [arena, mtgo, paper]      [draft]       black
# 4     Johannes Voss  [arena, mtgo, paper]      [draft]       black
#
#   colorIdentity colors  convertedManaCost  edhrecRank         finishes  \
# 0           [W]    [W]                2.0     11959.0  [nonfoil, foil]
# 1           [W]    [W]                4.0     16970.0  [nonfoil, foil]
# 2           [W]    [W]                3.0     12876.0  [nonfoil, foil]
# 3           [W]    [W]                3.0      3378.0  [nonfoil, foil]
# 4           [W]    [W]                3.0      7131.0  [nonfoil, foil]
#
#                                           flavorText  \
# 0  The weight of this magic weapon falls heavy on...
# 1  The noble steeds of the elven gods can sometim...
# 2  Blink dogs protect the wild places of the worl...
# 3                                                NaN
# 4            When all hope fails, its light remains.
#
#                                          foreignData frameVersion  hasFoil  \
# 0                                                 []         2015     True
# 1  [{'flavorText': 'Die edlen Reittiere der elfis...         2015     True
# 2  [{'flavorText': 'Flimmerhunde beschützen die w...         2015     True
# 3  [{'language': 'German', 'multiverseId': 527551...         2015     True
# 4  [{'flavorText': 'Wenn alle Hoffnung schwindet,...         2015     True
#
#    hasNonFoil                                        identifiers  \
# 0        True  {'cardKingdomFoilId': '248423', 'cardKingdomId...
# 1        True  {'cardKingdomFoilId': '248542', 'cardKingdomId...
# 2        True  {'cardKingdomFoilId': '248564', 'cardKingdomId...
# 3        True  {'cardKingdomFoilId': '248511', 'cardKingdomId...
# 4        True  {'cardKingdomFoilId': '248369', 'cardKingdomId...
#
#           keywords language  layout  \
# 0          [Equip]  English  normal
# 1         [Flying]  English  normal
# 2  [Double strike]  English  normal
# 3              NaN  English  normal
# 4              NaN  English  normal
#
#                                           legalities   manaCost  manaValue  \
# 0  {'alchemy': 'Legal', 'brawl': 'Legal', 'comman...     {1}{W}        2.0
# 1  {'alchemy': 'Legal', 'brawl': 'Legal', 'comman...     {3}{W}        4.0
# 2  {'alchemy': 'Legal', 'brawl': 'Legal', 'comman...     {2}{W}        3.0
# 3  {'alchemy': 'Legal', 'brawl': 'Legal', 'comman...  {W}{W}{W}        3.0
# 4  {'alchemy': 'Legal', 'brawl': 'Legal', 'comman...     {2}{W}        3.0
#
#                         name number    printings  \
# 0                    +2 Mace      1        [AFR]
# 1            Arborea Pegasus      2        [AFR]
# 2                  Blink Dog      3        [AFR]
# 3  The Book of Exalted Deeds      4  [AFR, PAFR]
# 4          Celestial Unicorn      5        [AFR]
#
#                                         purchaseUrls    rarity  \
# 0  {'cardKingdom': 'https://mtgjson.com/links/246...    common
# 1  {'cardKingdom': 'https://mtgjson.com/links/d46...    common
# 2  {'cardKingdom': 'https://mtgjson.com/links/d18...  uncommon
# 3  {'cardKingdom': 'https://mtgjson.com/links/eba...    mythic
# 4  {'cardKingdom': 'https://mtgjson.com/links/7c6...    common
#
#                                              rulings setCode     subtypes  \
# 0                                                 []     AFR  [Equipment]
# 1                                                 []     AFR    [Pegasus]
# 2  [{'date': '2021-07-23', 'text': 'Phased out pe...     AFR        [Dog]
# 3  [{'date': '2021-07-23', 'text': 'The enlighten...     AFR           []
# 4  [{'date': '2021-07-23', 'text': 'If you gain l...     AFR    [Unicorn]
#
#     supertypes                                               text  \
# 0           []  Equipped creature gets +2/+2.\nEquip {3} ({3}:...
# 1           []  Flying\nWhen Arborea Pegasus enters the battle...
# 2           []  Double strike\nTeleport — {3}{W}: Blink Dog ph...
# 3  [Legendary]  At the beginning of your end step, if you gain...
# 4           []  Whenever you gain life, put a +1/+1 counter on...
#
#                    type       types                                  uuid  \
# 0  Artifact — Equipment  [Artifact]  84d2e61d-46ef-5fa7-aeff-7a4cd8db71c8
# 1    Creature — Pegasus  [Creature]  6d3bc1d2-45a5-5010-b36b-6cc33c962d33
# 2        Creature — Dog  [Creature]  567a3bb4-1ad0-529f-9e0b-fe882f560c93
# 3    Legendary Artifact  [Artifact]  e5465719-ba59-52ef-b475-f553e6fc57f9
# 4    Creature — Unicorn  [Creature]  c228e9d4-2a6c-5f5c-bf27-93b3a8bd0852
#
#   power toughness                              variations frameEffects  \
# 0   NaN       NaN                                     NaN          NaN
# 1     2         3  [245a7947-877e-5b5d-b523-69bdf17a0950]          NaN
# 2     1         1  [196318b1-4d1a-5f41-a024-256e63c89a55]          NaN
# 3   NaN       NaN  [5031765f-0bd8-5866-89ac-2e9a3ec1b7e7]  [legendary]
# 4     3         2  [80a6282b-7e49-583e-b725-7d0d4ba8a13d]          NaN
#
#   securityStamp rebalancedPrintings isAlternative isOnlineOnly isRebalanced  \
# 0           NaN                 NaN           NaN          NaN          NaN
# 1           NaN                 NaN           NaN          NaN          NaN
# 2           NaN                 NaN           NaN          NaN          NaN
# 3          oval                 NaN           NaN          NaN          NaN
# 4           NaN                 NaN           NaN          NaN          NaN
#
#   isStarter originalPrintings leadershipSkills loyalty isReprint promoTypes  \
# 0       NaN               NaN              NaN     NaN       NaN        NaN
# 1       NaN               NaN              NaN     NaN       NaN        NaN
# 2       NaN               NaN              NaN     NaN       NaN        NaN
# 3       NaN               NaN              NaN     NaN       NaN        NaN
# 4       NaN               NaN              NaN     NaN       NaN        NaN
#
#   isPromo watermark
# 0     NaN       NaN
# 1     NaN       NaN
# 2     NaN       NaN
# 3     NaN       NaN
# 4     NaN       NaN

# %%
df.shape
# Out:
# (420, 51)

# %% [markdown]
# We can see from our row count that we have 420 different cards represented, however a quick reference of the List of MTG Sets article on Wikipedia (https://en.wikipedia.org/wiki/List_of_Magic:_The_Gathering_sets#Expansion_sets) tells us we should expect to see only 281 cards.  The MTGJSON files include separate entries for promotional versions of cards with alternate art as well as digital-only versions of cards that won't be important to our analysis, so we'll drop these from the list.

# %%
df = df[df['promoTypes'].isnull()]
df.shape
# Out:
# (299, 51)

# %%
df = df.loc[df['securityStamp'] != 'arena']
df.shape
# Out:
# (281, 51)

# %% [markdown]
# 281 cards is exactly what we expect to see, so now we will drop the Basic Lands from the dataset.  Every expansion includes the five basic land cards that are necessary to play the game, but they are in and of themselves irrelevant to any analysis that we plan to do, so we can drop them from each of the sets that we include in our analysis.

# %%
df = df.loc[~df['supertypes'].map(lambda x: bool('Basic' in x))]
df.shape
# Out:
# (261, 51)

# %% [markdown]
# The MTGJSON files include a wealth of information about each card, most of which will not be germaine to this specific analysis, so we choose a number that should be relevant, and drop the rest.

# %%
df = df.loc[:, ['name', 'colors', 'manaValue', 'manaCost', 'power', 'toughness', 
                    'loyalty', 'text', 'rarity', 'keywords', 'supertypes', 'types']]

# %%
df.head(10)
# Out:
#                          name colors  manaValue   manaCost power toughness  \
# 0                     +2 Mace    [W]        2.0     {1}{W}   NaN       NaN
# 1             Arborea Pegasus    [W]        4.0     {3}{W}     2         3
# 2                   Blink Dog    [W]        3.0     {2}{W}     1         1
# 3   The Book of Exalted Deeds    [W]        3.0  {W}{W}{W}   NaN       NaN
# 4           Celestial Unicorn    [W]        3.0     {2}{W}     3         2
# 5                Cleric Class    [W]        1.0        {W}   NaN       NaN
# 6           Cloister Gargoyle    [W]        3.0     {2}{W}     0         4
# 8               Dancing Sword    [W]        2.0     {1}{W}   NaN       NaN
# 9          Dawnbringer Cleric    [W]        2.0     {1}{W}     1         3
# 10             Delver's Torch    [W]        2.0     {1}{W}   NaN       NaN
#
#    loyalty                                               text    rarity  \
# 0      NaN  Equipped creature gets +2/+2.\nEquip {3} ({3}:...    common
# 1      NaN  Flying\nWhen Arborea Pegasus enters the battle...    common
# 2      NaN  Double strike\nTeleport — {3}{W}: Blink Dog ph...  uncommon
# 3      NaN  At the beginning of your end step, if you gain...    mythic
# 4      NaN  Whenever you gain life, put a +1/+1 counter on...    common
# 5      NaN  (Gain the next level as a sorcery to add its a...  uncommon
# 6      NaN  When Cloister Gargoyle enters the battlefield,...  uncommon
# 8      NaN  Equipped creature gets +2/+1.\nWhen equipped c...      rare
# 9      NaN  When Dawnbringer Cleric enters the battlefield...    common
# 10     NaN  Equipped creature gets +1/+1.\nWhenever equipp...    common
#
#                              keywords   supertypes                 types
# 0                             [Equip]           []            [Artifact]
# 1                            [Flying]           []            [Creature]
# 2                     [Double strike]           []            [Creature]
# 3                                 NaN  [Legendary]            [Artifact]
# 4                                 NaN           []            [Creature]
# 5                                 NaN           []         [Enchantment]
# 6          [Venture into the dungeon]           []  [Artifact, Creature]
# 8                             [Equip]           []            [Artifact]
# 9                                 NaN           []            [Creature]
# 10  [Equip, Venture into the dungeon]           []            [Artifact]

# %% [markdown]
# Several columns of information that will be important to us are formatted as lists, which makes getting to the information with Pandas a bit tricky, so we're going to convert them from lists to strings.  We'll do this for the columns "colors", "keywords", "supertypes", and "types".  Unfortunately, the keywords column has NaN values instead of empty lists if the card has no keywords, so we'll first replace those NaNs with empty strings.

# %%
df['keywords'].fillna('', inplace=True)
to_unlist = ['colors', 'types', 'supertypes', 'keywords']
for column in to_unlist:
    df[column] = [', '.join(map(str, l)) for l in df[column]]

# %%
df.head(10)
# Out:
#                          name colors  manaValue   manaCost power toughness  \
# 0                     +2 Mace      W        2.0     {1}{W}   NaN       NaN
# 1             Arborea Pegasus      W        4.0     {3}{W}     2         3
# 2                   Blink Dog      W        3.0     {2}{W}     1         1
# 3   The Book of Exalted Deeds      W        3.0  {W}{W}{W}   NaN       NaN
# 4           Celestial Unicorn      W        3.0     {2}{W}     3         2
# 5                Cleric Class      W        1.0        {W}   NaN       NaN
# 6           Cloister Gargoyle      W        3.0     {2}{W}     0         4
# 8               Dancing Sword      W        2.0     {1}{W}   NaN       NaN
# 9          Dawnbringer Cleric      W        2.0     {1}{W}     1         3
# 10             Delver's Torch      W        2.0     {1}{W}   NaN       NaN
#
#    loyalty                                               text    rarity  \
# 0      NaN  Equipped creature gets +2/+2.\nEquip {3} ({3}:...    common
# 1      NaN  Flying\nWhen Arborea Pegasus enters the battle...    common
# 2      NaN  Double strike\nTeleport — {3}{W}: Blink Dog ph...  uncommon
# 3      NaN  At the beginning of your end step, if you gain...    mythic
# 4      NaN  Whenever you gain life, put a +1/+1 counter on...    common
# 5      NaN  (Gain the next level as a sorcery to add its a...  uncommon
# 6      NaN  When Cloister Gargoyle enters the battlefield,...  uncommon
# 8      NaN  Equipped creature gets +2/+1.\nWhen equipped c...      rare
# 9      NaN  When Dawnbringer Cleric enters the battlefield...    common
# 10     NaN  Equipped creature gets +1/+1.\nWhenever equipp...    common
#
#                            keywords supertypes               types
# 0                             Equip                       Artifact
# 1                            Flying                       Creature
# 2                     Double strike                       Creature
# 3                                    Legendary            Artifact
# 4                                                         Creature
# 5                                                      Enchantment
# 6          Venture into the dungeon             Artifact, Creature
# 8                             Equip                       Artifact
# 9                                                         Creature
# 10  Equip, Venture into the dungeon                       Artifact

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 261 entries, 0 to 278
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        261 non-null    object
#  1   colors      261 non-null    object
#  2   manaValue   261 non-null    float64
#  3   manaCost    252 non-null    object
#  4   power       142 non-null    object
#  5   toughness   142 non-null    object
#  6   loyalty     5 non-null      object
#  7   text        261 non-null    object
#  8   rarity      261 non-null    object
#  9   keywords    261 non-null    object
#  10  supertypes  261 non-null    object
#  11  types       261 non-null    object
# dtypes: float64(1), object(11)
# memory usage: 26.5+ KB

# %% [markdown]
# We can see that there are four numeric columns that will likely interest us:  manaValue, power, toughness & loyalty.  However, the latter three are currently formatted as strings, so we will fix that. There is the possibility that values in these lists may include the value '*', indicating that they value is variable.  For simplicity's sake, we will use `errors='coerce'` to replace the variable power indicator with NaN.

# %%
to_convert = ['power', 'toughness', 'loyalty']
for column in to_convert:
    df[column] = pd.to_numeric(df[column], errors='coerce')

# %% [markdown]
# We've removed some items from the set, so we'll go ahead and reset the index numbers.

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        261 non-null    object
#  1   colors      261 non-null    object
#  2   manaValue   261 non-null    float64
#  3   manaCost    252 non-null    object
#  4   power       142 non-null    float64
#  5   toughness   142 non-null    float64
#  6   loyalty     5 non-null      float64
#  7   text        261 non-null    object
#  8   rarity      261 non-null    object
#  9   keywords    261 non-null    object
#  10  supertypes  261 non-null    object
#  11  types       261 non-null    object
# dtypes: float64(4), object(8)
# memory usage: 24.6+ KB

# %% [markdown]
# This looks like a good place to start from, so we'll create a function that includes all of these steps.  We can then put each of the individual sets that we want to clean in a list and iterate over it with the function to give us a list of dataframes, which we can then write out to `.csv` format to give us a number of cleaned individual datasets that are identically formatted, which will allow us to easily combine them.

# %% [markdown]
# #### Handling Modal Cards
#
# Many cards in the sets that we are considering are modal in nature, meaning that a single card can be played in one of two distinct ways.  In the MTGJSON datasets, each mode of a single card has its own row, but both rows have the same name in the format "MODE 1 // MODE 2". For the sake of this analysis, we will treat each mode of such a card as its own card. We will add a function to be called within our cleaning function that will rename each of these entries to reflect the name of casting that specific mode.

# %%
def drop_modal_names (df):
    indexes = df.loc[df.name.str.contains('//'), ['name']].index
    for count, value in enumerate(df.loc[df.name.str.contains('//'), ['name']].name):
        if count % 2 == 0:
            c = value.find('/') - 1
            df.iat[indexes[count], 0] = value[:c]
        else:
            c = value.find('/') + 3
            df.iat[indexes[count], 0] = value[c:]

# %%
def initial_cleaning(json_file):
    df = pd.read_json(json_file, orient='index')
    df = pd.DataFrame(df.cards[1])
    # Removing promos, online only cards, basic lands.    
    df = df[df['promoTypes'].isnull()]
    df = df.loc[df['securityStamp'] != 'arena']
    df = df.loc[~df['supertypes'].map(lambda x: bool('Basic' in x))]
    # Choosing the columns we want to keep.
    df = df.loc[:, ['name', 'colors', 'manaValue', 'manaCost', 'power', 'toughness', 
                    'loyalty', 'text', 'rarity', 'keywords', 'supertypes', 'types']]
    # Resetting the index before we do anything else.
    df.reset_index(drop=True, inplace=True)
    # Changing list values to string values
    to_unlist = ['colors', 'types', 'supertypes', 'keywords']
    df['keywords'].fillna('', inplace=True)
    for column in to_unlist:
        df[column] = [', '.join(map(str, l)) for l in df[column]]
    # Converting numeric columns to numeric datatypes
    to_convert = ['power', 'toughness', 'loyalty']
    for column in to_convert:
        df[column] = pd.to_numeric(df[column], errors='coerce')
    # Renaming modal cards
    drop_modal_names(df)
    # Just in case we missed any duplicated entries with our initial cleaning steps, we drop them here and
    # reset the index one last time.
    df.drop_duplicates(inplace=True)
    df.reset_index(drop=True, inplace=True)
    return df

# %%
files = ['AFR', 'ELD', 'IKO', 'KHM', 'MID', 'NEO', 'SNC', 'STX', 'THB', 'VOW', 'ZNR']
dfs = []

# %%
for f in files:
    dfs.append(initial_cleaning('datasets/'+f+'.json'))

# %%
for df, f in zip(dfs, files):
    df.to_csv('cleaned_datasets/'+f+'_cleaned.csv')

# %% [markdown]
# With our individual sets cleaned and exported, we'll now merge them all in to a single dataframe, using the `reduce()` function.

# %%
from functools import reduce

# %%
df_merged = reduce(lambda left,right: pd.merge(left, right, how='outer'), dfs)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3120 entries, 0 to 3119
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        3120 non-null   object
#  1   colors      3120 non-null   object
#  2   manaValue   3120 non-null   float64
#  3   manaCost    2827 non-null   object
#  4   power       1667 non-null   float64
#  5   toughness   1672 non-null   float64
#  6   loyalty     44 non-null     float64
#  7   text        3096 non-null   object
#  8   rarity      3120 non-null   object
#  9   keywords    3120 non-null   object
#  10  supertypes  3120 non-null   object
#  11  types       3120 non-null   object
# dtypes: float64(4), object(8)
# memory usage: 316.9+ KB

# %%
df_merged[df_merged.duplicated(subset= 'name', keep=False)]
# Out:
#                   name colors  manaValue   manaCost  power  toughness  \
# 1164  Grafted Identity      U        4.0  {2}{U}{U}    NaN        NaN
# 1165  Grafted Identity      U        4.0  {2}{U}{U}    NaN        NaN
#
#       loyalty                                               text rarity  \
# 1164      NaN  As an additional cost to cast this spell, sacr...   rare
# 1165      NaN  As an additional cost to cast this spell, sacr...   rare
#
#      keywords supertypes        types
# 1164  Enchant             Enchantment
# 1165  Enchant             Enchantment

# %%
df_merged.describe()
# Out:
#          manaValue        power    toughness    loyalty
# count  3120.000000  1667.000000  1672.000000  44.000000
# mean      2.944231     2.659868     2.898923   4.045455
# std       1.620276     1.551854     1.570204   0.861436
# min       0.000000     0.000000     0.000000   2.000000
# 25%       2.000000     2.000000     2.000000   3.750000
# 50%       3.000000     2.000000     3.000000   4.000000
# 75%       4.000000     3.000000     4.000000   5.000000
# max      15.000000    11.000000    17.000000   5.000000

# %%
df_merged.drop_duplicates(subset='name')
# Out:
#                                 name         colors  manaValue  \
# 0                            +2 Mace              W        2.0
# 1                    Arborea Pegasus              W        4.0
# 2                          Blink Dog              W        3.0
# 3          The Book of Exalted Deeds              W        3.0
# 4                  Celestial Unicorn              W        3.0
# 5                       Cleric Class              W        1.0
# 6                  Cloister Gargoyle              W        3.0
# 7                      Dancing Sword              W        2.0
# 8                 Dawnbringer Cleric              W        2.0
# 9                     Delver's Torch              W        2.0
# 10                   Devoted Paladin              W        5.0
# 11                      Divine Smite              W        2.0
# 12                 Dragon's Disciple              W        2.0
# 13                Dwarfhold Champion              W        2.0
# 14                            Flumph              W        2.0
# 15                     Gloom Stalker              W        3.0
# 16           Grand Master of Flowers              W        4.0
# 17                 Guardian of Faith              W        3.0
# 18                     Half-Elf Monk              W        4.0
# 19          Icingdeath, Frost Tyrant              W        4.0
# 20                   Ingenious Smith              W        2.0
# 21                 Keen-Eared Sentry              W        2.0
# 22                    Loyal Warhound              W        2.0
# 23               Minimus Containment              W        3.0
# 24             Monk of the Open Hand              W        1.0
# 25               Moon-Blessed Cleric              W        3.0
# 26          Nadaar, Selfless Paladin              W        3.0
# 27               Oswald Fiddlebender              W        2.0
# 28                     Paladin Class              W        1.0
# 29                  Paladin's Shield              W        2.0
# 30                       Planar Ally              W        5.0
# 31                       Plate Armor              W        3.0
# 32                     Portable Hole              W        1.0
# 33                 Potion of Healing              W        2.0
# 34            Priest of Ancient Lore              W        3.0
# 35                    Rally Maneuver              W        3.0
# 36                     Ranger's Hawk              W        1.0
# 37                 Steadfast Paladin              W        2.0
# 38              Teleportation Circle              W        4.0
# 39                Veteran Dungeoneer              W        4.0
# 40                      White Dragon              W        6.0
# 41       You Hear Something on Watch              W        2.0
# 42       You're Ambushed on the Road              W        1.0
# 43            Aberrant Mind Sorcerer              U        5.0
# 44                Air-Cult Elemental              U        6.0
# 45               Arcane Investigator              U        2.0
# 46                      Bar the Gate              U        3.0
# 47       The Blackstaff of Waterdeep              U        1.0
# 48                       Blue Dragon              U        7.0
# 49                     Charmed Sleep              U        3.0
# 50                   Clever Conjurer              U        3.0
# 51               Contact Other Plane              U        4.0
# 52                          Demilich              U        4.0
# 53                   Displacer Beast              U        3.0
# 54                   Djinni Windseer              U        4.0
# 55                     Dragon Turtle              U        3.0
# 56              Eccentric Apprentice              U        3.0
# 57                 Feywild Trickster              U        3.0
# 58                               Fly              U        1.0
# 59       Grazilaxx, Illithid Scholar              U        3.0
# 60                       Guild Thief              U        2.0
# 61              Iymrith, Desert Doom              U        5.0
# 62                       Mind Flayer              U        5.0
# 63                      Mordenkainen              U        6.0
# 64          Mordenkainen's Polymorph              U        2.0
# 65                       Pixie Guide              U        2.0
# 66               Power of Persuasion              U        3.0
# 67                      Ray of Frost              U        2.0
# 68            Rimeshield Frost Giant              U        5.0
# 69                   Scion of Stygia              U        3.0
# 70                       Secret Door              U        1.0
# 71                    Shocking Grasp              U        2.0
# 72                   Shortcut Seeker              U        4.0
# 73                      Silver Raven              U        1.0
# 74                     Soulknife Spy              U        3.0
# 75                   Split the Party              U        5.0
# 76                    Sudden Insight              U        6.0
# 77          Tasha's Hideous Laughter              U        3.0
# 78              Trickster's Talisman              U        1.0
# 79                    True Polymorph              U        6.0
# 80                      Wizard Class              U        1.0
# 81                Wizard's Spellbook              U        7.0
# 82               You Come to a River              U        2.0
# 83       You Find the Villains' Lair              U        3.0
# 84          You See a Guard Approach              U        1.0
# 85                   Yuan-Ti Malison              U        2.0
# 86             Acererak the Archlich              B        3.0
# 87            Asmodeus the Archfiend              B        6.0
# 88                  Baleful Beholder              B        6.0
# 89                      Black Dragon              B        7.0
# 90         The Book of Vile Darkness              B        3.0
# 91                   Check for Traps              B        2.0
# 92              Clattering Skeletons              B        4.0
# 93                    Deadly Dispute              B        2.0
# 94            Death-Priest of Myrkul              B        4.0
# 95             Demogorgon's Clutches              B        3.0
# 96                  Devour Intellect              B        1.0
# 97                            Drider              B        5.0
# 98                   Dungeon Crawler              B        1.0
# 99              Ebondeath, Dracolich              B        4.0
# 100             Eyes of the Beholder              B        6.0
# 101                  Fates' Reversal              B        2.0
# 102                      Feign Death              B        1.0
# 103                 Forsworn Paladin              B        1.0
# 104                  Gelatinous Cube              B        4.0
# 105                      Grim Bounty              B        4.0
# 106                    Grim Wanderer              B        2.0
# 107                  Herald of Hadar              B        5.0
# 108                   Hired Hexblade              B        2.0
# 109                     Hoard Robber              B        2.0
# 110                  Lightfoot Rogue              B        2.0
# 111              Lolth, Spider Queen              B        5.0
# 112                        Manticore              B        4.0
# 113                  Power Word Kill              B        2.0
# 114                 Precipitous Drop              B        3.0
# 115              Ray of Enfeeblement              B        1.0
# 116                Reaper's Talisman              B        1.0
# 117                  Sepulcher Ghoul              B        2.0
# 118                  Shambling Ghast              B        1.0
# 119               Skullport Merchant              B        3.0
# 120           Sphere of Annihilation              B        1.0
# 121                   Thieves' Tools              B        2.0
# 122                    Vampire Spawn              B        3.0
# 123                     Vorpal Sword              B        1.0
# 124                    Warlock Class              B        1.0
# 125                  Westgate Regent              B        5.0
# 126                            Wight              B        2.0
# 127               Yuan-Ti Fang-Blade              B        3.0
# 128                      Zombie Ogre              B        5.0
# 129                   Armory Veteran              R        2.0
# 130                  Barbarian Class              R        1.0
# 131                Battle Cry Goblin              R        2.0
# 132                   Boots of Speed              R        1.0
# 133                     Brazen Dwarf              R        2.0
# 134                    Burning Hands              R        2.0
# 135                  Chaos Channeler              R        4.0
# 136                     Critical Hit              R        2.0
# 137                Delina, Wild Mage              R        4.0
# 138                    Dragon's Fire              R        2.0
# 139                   Dueling Rapier              R        1.0
# 140             Earth-Cult Elemental              R        6.0
# 141               Farideh's Fireball              R        5.0
# 142                       Flameskull              R        3.0
# 143                Goblin Javelineer              R        1.0
# 144               Goblin Morningstar              R        2.0
# 145                    Hoarding Ogre              R        4.0
# 146            Hobgoblin Bandit Lord              R        3.0
# 147                Hobgoblin Captain              R        2.0
# 148                  Hulking Bugbear              R        3.0
# 149              Improvised Weaponry              R        3.0
# 150       Inferno of the Star Mounts              R        6.0
# 151                 Jaded Sell-Sword              R        4.0
# 152                 Kick in the Door              R        1.0
# 153                    Magic Missile              R        3.0
# 154                     Meteor Swarm              R        3.0
# 155             Minion of the Mighty              R        1.0
# 156                Orb of Dragonkind              R        2.0
# 157             Plundering Barbarian              R        3.0
# 158                 Price of Loyalty              R        3.0
# 159                       Red Dragon              R        6.0
# 160                     Rust Monster              R        3.0
# 161                 Swarming Goblins              R        5.0
# 162               Tiger-Tribe Hunter              R        5.0
# 163              Unexpected Windfall              R        4.0
# 164                     Valor Singer              R        3.0
# 165                             Wish              R        3.0
# 166                             Xorn              R        3.0
# 167       You Come to the Gnoll Camp              R        2.0
# 168          You Find Some Prisoners              R        2.0
# 169        You See a Pair of Goblins              R        3.0
# 170           Zalto, Fire Giant Duke              R        5.0
# 171      Zariel, Archduke of Avernus              R        4.0
# 172                          Bulette              G        4.0
# 173                  Bull's Strength              G        2.0
# 174               Choose Your Weapon              G        3.0
# 175           Circle of Dreams Druid              G        3.0
# 176         Circle of the Moon Druid              G        3.0
# 177                   Compelled Duel              G        2.0
# 178                Dire Wolf Prowler              G        3.0
# 179                      Druid Class              G        2.0
# 180             Ellywick Tumblestrum              G        4.0
# 181                 Elturgard Ranger              G        5.0
# 182                    Find the Path              G        3.0
# 183                       Froghemoth              G        5.0
# 184                     Gnoll Hunter              G        2.0
# 185                     Green Dragon              G        6.0
# 186            Hill Giant Herdgorger              G        6.0
# 187                    Hunter's Mark              G        4.0
# 188                   Inspiring Bard              G        4.0
# 189          Instrument of the Bards              G        1.0
# 190               Intrepid Outlander              G        2.0
# 191                  Loathsome Troll              G        5.0
# 192                        Long Rest              G        3.0
# 193                    Lurking Roper              G        3.0
# 194                Neverwinter Dryad              G        1.0
# 195                      Ochre Jelly              G        1.0
# 196                     Old Gnawbone              G        7.0
# 197                          Owlbear              G        5.0
# 198                          Plummet              G        2.0
# 199             Prosperous Innkeeper              G        2.0
# 200                      Purple Worm              G        7.0
# 201                     Ranger Class              G        2.0
# 202                 Ranger's Longbow              G        2.0
# 203                 Scaled Herbalist              G        2.0
# 204               Spoils of the Hunt              G        3.0
# 205                  Sylvan Shepherd              G        3.0
# 206                    The Tarrasque              G        9.0
# 207               Underdark Basilisk              G        2.0
# 208        Varis, Silverymoon Ranger              G        3.0
# 209             Wandering Troubadour              G        4.0
# 210             Werewolf Pack Leader              G        2.0
# 211                       Wild Shape              G        1.0
# 212           You Find a Cursed Idol              G        2.0
# 213            You Happen On a Glade              G        3.0
# 214             You Meet in a Tavern              G        4.0
# 215                Adult Gold Dragon           R, W        5.0
# 216                       Bard Class           G, R        2.0
# 217          Barrowin of Clan Undurr           B, W        4.0
# 218             Bruenor Battlehammer           R, W        4.0
# 219                  Drizzt Do'Urden           G, W        5.0
# 220          Farideh, Devil's Chosen           R, U        4.0
# 221                    Fighter Class           R, W        2.0
# 222             Gretchen Titchwillow           G, U        2.0
# 223         Hama Pashar, Ruin Seeker           U, W        3.0
# 224        Kalain, Reclusive Painter           B, R        2.0
# 225          Krydle of Baldur's Gate           B, U        2.0
# 226            Minsc, Beloved Ranger        G, R, W        3.0
# 227                       Monk Class           U, W        2.0
# 228         Orcus, Prince of Undeath           B, R        4.0
# 229                      Rogue Class           B, U        2.0
# 230         Shessra, Death's Whisper           B, G        4.0
# 231                Skeletal Swarming           B, G        5.0
# 232                   Sorcerer Class           R, U        2.0
# 233       Targ Nar, Demon-Fang Gnoll           G, R        2.0
# 234                           Tiamat  B, G, R, U, W        7.0
# 235          Trelasarra, Moon Dancer           G, W        2.0
# 236            Triumphant Adventurer           B, W        2.0
# 237          Volo, Guide to Monsters           G, U        4.0
# 238          Xanathar, Guild Kingpin           B, U        6.0
# 239                   Bag of Holding                       1.0
# 240          The Deck of Many Things                       5.0
# 241                      Dungeon Map                       3.0
# 242                     Eye of Vecna                       2.0
# 243               Fifty Feet of Rope                       1.0
# 244                         Greataxe                       1.0
# 245                    Hand of Vecna                       3.0
# 246                       Iron Golem                       4.0
# 247                    Leather Armor                       1.0
# 248                            Mimic                       2.0
# 249                     Spare Dagger                       1.0
# 250                  Spiked Pit Trap                       1.0
# 251                   Treasure Chest                       3.0
# 252         Cave of the Frost Dragon                       0.0
# 253               Den of the Bugbear                       0.0
# 254                  Dungeon Descent                       0.0
# 255                   Evolving Wilds                       0.0
# 256             Hall of Storm Giants                       0.0
# 257           Hive of the Eye Tyrant                       0.0
# 258                Lair of the Hydra                       0.0
# 259       Temple of the Dragon Queen                       0.0
# 260                   Treasure Vault                       0.0
# 261              Acclaimed Contender              W        3.0
# 262                All That Glitters              W        2.0
# 263             Archon of Absolution              W        4.0
# 264                Ardenvale Paladin              W        4.0
# 265              Ardenvale Tactician              W        3.0
# 266                   Dizzying Swoop              W        3.0
# 267                     Bartered Cow              W        4.0
# 268                 Beloved Princess              W        1.0
# 269                  Charming Prince              W        2.0
# 270            The Circle of Loyalty              W        6.0
# 271                Deafening Silence              W        1.0
# 272               Faerie Guidemother              W        1.0
# 273                  Gift of the Fae              W        1.0
# 274                       Flutterfox              W        2.0
# 275            Fortifying Provisions              W        3.0
# 276                     Giant Killer              W        1.0
# 277                        Chop Down              W        1.0
# 278                     Glass Casket              W        2.0
# 279               Happily Ever After              W        3.0
# 280                Harmonious Archon              W        6.0
# 281                      Hushbringer              W        2.0
# 282               Knight of the Keep              W        3.0
# 283      Linden, the Steadfast Queen              W        3.0
# 284                 Lonesome Unicorn              W        5.0
# 285                    Rider in Need              W        5.0
# 286           Mysterious Pathlighter              W        3.0
# 287                         Outflank              W        1.0
# 288                   Prized Griffin              W        5.0
# 289             Rally for the Throne              W        3.0
# 290              Realm-Cloaked Giant              W        7.0
# 291                         Cast Off              W        7.0
# 292                    Righteousness              W        1.0
# 293            Shepherd of the Flock              W        2.0
# 294                  Usher to Safety              W        2.0
# 295                    Shining Armor              W        2.0
# 296               Silverflame Ritual              W        4.0
# 297               Silverflame Squire              W        2.0
# 298                         On Alert              W        2.0
# 299        Syr Alin, the Lion's Claw              W        5.0
# 300             Trapped in the Tower              W        2.0
# 301                 True Love's Kiss              W        4.0
# 302                 Venerable Knight              W        1.0
# 303                    Worthy Knight              W        2.0
# 304                  Youthful Knight              W        2.0
# 305                 Animating Faerie              U        3.0
# 306                    Bring to Life              U        3.0
# 307                  Brazen Borrower              U        3.0
# 308                      Petty Theft              U        3.0
# 309                 Corridor Monitor              U        2.0
# 310                Didn't Say Please              U        3.0
# 311         Emry, Lurker of the Loch              U        3.0
# 312                    Fae of Wishes              U        2.0
# 313                          Granted              U        2.0
# 314                    Faerie Vandal              U        2.0
# 315                 Folio of Fancies              U        2.0
# 316                          Frogify              U        2.0
# 317             Gadwick, the Wizened              U        3.0
# 318                  Hypnotic Sprite              U        2.0
# 319                   Mesmeric Glare              U        2.0
# 320                   Into the Story              U        7.0
# 321                 The Magic Mirror              U        9.0
# 322                  Mantle of Tides              U        1.0
# 323             Merfolk Secretkeeper              U        1.0
# 324                   Venture Deeper              U        1.0
# 325                   Midnight Clock              U        3.0
# 326                       Mirrormade              U        3.0
# 327            Mistford River Turtle              U        4.0
# 328               Moonlit Scavengers              U        6.0
# 329                 Mystical Dispute              U        3.0
# 330                              Opt              U        1.0
# 331           Overwhelmed Apprentice              U        1.0
# 332                     Queen of Ice              U        3.0
# 333                   Rage of Winter              U        3.0
# 334                Run Away Together              U        2.0
# 335                Sage of the Falls              U        5.0
# 336                          So Tiny              U        1.0
# 337                Steelgaze Griffin              U        5.0
# 338                Stolen by the Fae              U        2.0
# 339      Syr Elenora, the Discerning              U        5.0
# 340                      Tome Raider              U        3.0
# 341              Turn into a Pumpkin              U        4.0
# 342               Unexplained Vision              U        5.0
# 343                Vantress Gargoyle              U        2.0
# 344                 Vantress Paladin              U        4.0
# 345                  Wishful Merfolk              U        2.0
# 346                    Witching Well              U        1.0
# 347        Ayara, First of Locthwain              B        3.0
# 348                  Bake into a Pie              B        4.0
# 349                   Barrow Witches              B        5.0
# 350               Belle of the Brawl              B        3.0
# 351               Blacklance Paragon              B        2.0
# 352                      Bog Naughty              B        5.0
# 353                Cauldron Familiar              B        1.0
# 354         The Cauldron of Eternity              B       12.0
# 355                  Cauldron's Gift              B        5.0
# 356                Clackbridge Troll              B        5.0
# 357                    Epic Downfall              B        2.0
# 358                    Eye Collector              B        1.0
# 359                  Festive Funeral              B        5.0
# 360                 Foreboding Fruit              B        3.0
# 361                    Forever Young              B        2.0
# 362                  Foulmire Knight              B        1.0
# 363                  Profane Insight              B        1.0
# 364                   Giant's Skewer              B        2.0
# 365                   Lash of Thorns              B        1.0
# 366                Locthwain Paladin              B        4.0
# 367                      Lost Legion              B        3.0
# 368                 Malevolent Noble              B        2.0
# 369                     Memory Theft              B        3.0
# 370                  Murderous Rider              B        3.0
# 371                        Swift End              B        3.0
# 372                 Oathsworn Knight              B        3.0
# 373                Order of Midnight              B        2.0
# 374                       Alter Fate              B        2.0
# 375               Piper of the Swarm              B        2.0
# 376         Rankle, Master of Pranks              B        4.0
# 377                  Reaper of Night              B        7.0
# 378                     Harvest Fear              B        7.0
# 379                       Reave Soul              B        2.0
# 380                Revenge of Ravens              B        4.0
# 381              Smitten Swordmaster              B        2.0
# 382                      Curry Favor              B        2.0
# 383                 Specter's Shriek              B        1.0
# 384             Syr Konrad, the Grim              B        5.0
# 385                   Tempting Witch              B        3.0
# 386                  Wicked Guardian              B        4.0
# 387                Wishclaw Talisman              B        2.0
# 388                Witch's Vengeance              B        3.0
# 389                         Barge In              R        1.0
# 390              Bloodhaze Wolverine              R        2.0
# 391             Blow Your House Down              R        3.0
# 392                Bonecrusher Giant              R        3.0
# 393                            Stomp              R        3.0
# 394              Brimstone Trebuchet              R        3.0
# 395             Burning-Yard Trainer              R        5.0
# 396              Claim the Firstborn              R        1.0
# 397                  Crystal Slipper              R        2.0
# 398                      Embercleave              R        6.0
# 399                 Embereth Paladin              R        4.0
# 400           Embereth Shieldbreaker              R        2.0
# 401                   Battle Display              R        2.0
# 402            Ferocity of the Wilds              R        3.0
# 403                 Fervent Champion              R        1.0
# 404               Fires of Invention              R        4.0
# 405                            Fling              R        2.0
# 406                    Irencrag Feat              R        4.0
# 407              Irencrag Pyromancer              R        3.0
# 408                            Joust              R        2.0
# 409                       Mad Ratter              R        4.0
# 410             Merchant of the Vale              R        3.0
# 411                           Haggle              R        3.0
# 412                      Ogre Errant              R        4.0
# 413             Opportunistic Dragon              R        4.0
# 414                    Raging Redcap              R        3.0
# 415                     Redcap Melee              R        1.0
# 416                   Redcap Raiders              R        3.0
# 417                   Rimrock Knight              R        2.0
# 418                     Boulder Rush              R        2.0
# 419               Robber of the Rich              R        2.0
# 420             Scorching Dragonfire              R        2.0
# 421                  Searing Barrage              R        5.0
# 422                    Seven Dwarves              R        2.0
# 423                Skullknocker Ogre              R        4.0
# 424                     Slaying Fire              R        3.0
# 425                 Sundering Stroke              R        7.0
# 426              Syr Carah, the Bold              R        5.0
# 427            Thrill of Possibility              R        2.0
# 428       Torbran, Thane of Red Fell              R        4.0
# 429                Weaselback Redcap              R        1.0
# 430                  Beanstalk Giant              G        7.0
# 431                Fertile Footsteps              G        7.0
# 432                     Curious Pair              G        2.0
# 433                  Treats to Share              G        2.0
# 434               Edgewall Innkeeper              G        1.0
# 435              Feasting Troll King              G        6.0
# 436                Fell the Pheasant              G        2.0
# 437              Fierce Witchstalker              G        4.0
# 438                  Flaxen Intruder              G        1.0
# 439                     Welcome Home              G        1.0
# 440                 Garenbrig Carver              G        4.0
# 441                   Shield's Might              G        4.0
# 442                Garenbrig Paladin              G        5.0
# 443                 Garenbrig Squire              G        2.0
# 444                Giant Opportunity              G        3.0
# 445                     Gilded Goose              G        1.0
# 446                  The Great Henge              G        9.0
# 447              Insatiable Appetite              G        2.0
# 448                 Keeper of Fables              G        5.0
# 449         Kenrith's Transformation              G        2.0
# 450                 Lovestruck Beast              G        3.0
# 451                   Heart's Desire              G        3.0
# 452                   Maraleaf Rider              G        2.0
# 453                Oakhame Adversary              G        4.0
# 454                  Once and Future              G        4.0
# 455                 Once Upon a Time              G        2.0
# 456                        Outmuscle              G        4.0
# 457                   Questing Beast              G        4.0
# 458        Return of the Wildspeaker              G        5.0
# 459                 Return to Nature              G        2.0
# 460                Rosethorn Acolyte              G        3.0
# 461                  Seasonal Ritual              G        3.0
# 462                Rosethorn Halberd              G        1.0
# 463                  Sporecap Spider              G        3.0
# 464       Syr Faren, the Hengehammer              G        2.0
# 465              Tall as a Beanstalk              G        4.0
# 466                  Trail of Crumbs              G        2.0
# 467                Tuinvale Treefolk              G        6.0
# 468                       Oaken Boon              G        6.0
# 469                      Wicked Wolf              G        4.0
# 470               Wildborn Preserver              G        2.0
# 471                 Wildwood Tracker              G        1.0
# 472                    Wolf's Quarry              G        6.0
# 473         Yorvo, Lord of Garenbrig              G        3.0
# 474               Dance of the Manse           U, W        2.0
# 475                    Doom Foretold           B, W        4.0
# 476                Drown in the Loch           B, U        2.0
# 477              Escape to the Wilds           G, R        5.0
# 478                  Faeburrow Elder           G, W        3.0
# 479          Garruk, Cursed Huntsman           B, G        6.0
# 480          Grumgully, the Generous           G, R        3.0
# 481              Improbable Alliance           R, U        2.0
# 482                Inspiring Veteran           R, W        2.0
# 483                 Lochmere Serpent           B, U        6.0
# 484                   Maraleaf Pixie           G, U        2.0
# 485             Oko, Thief of Crowns           G, U        3.0
# 486               Outlaws' Merriment           R, W        4.0
# 487                 The Royal Scions           R, U        3.0
# 488                     Savvy Hunter           B, G        3.0
# 489                      Shinechaser           U, W        3.0
# 490                  Steelclaw Lance           B, R        2.0
# 491               Stormfist Crusader           B, R        2.0
# 492                       Wandermare           G, W        3.0
# 493             Wintermoor Commander           B, W        2.0
# 494                   Arcanist's Owl           U, W        4.0
# 495                    Covetous Urge           B, U        4.0
# 496                 Deathless Knight           B, G        4.0
# 497                 Elite Headhunter           B, R        4.0
# 498                  Fireborn Knight           R, W        4.0
# 499                      Loch Dragon           R, U        4.0
# 500                   Oakhame Ranger           W, G        4.0
# 501                       Bring Back           W, G        4.0
# 502                  Rampart Smasher           G, R        4.0
# 503                   Resolute Rider           B, W        4.0
# 504               Thunderous Snapper           G, U        4.0
# 505                Clockwork Servant                       3.0
# 506              Crashing Drawbridge                       2.0
# 507               Enchanted Carriage                       5.0
# 508                      Gingerbrute                       1.0
# 509                       Golden Egg                       2.0
# 510                     Henge Walker                       3.0
# 511                  Heraldic Banner                       3.0
# 512               Inquisitive Puppet                       1.0
# 513                   Jousting Dummy                       2.0
# 514               Locthwain Gargoyle                       1.0
# 515                     Lucky Clover                       2.0
# 516              Prophet of the Peak                       6.0
# 517                      Roving Keep                       7.0
# 518                Scalding Cauldron                       1.0
# 519                   Shambling Suit                       3.0
# 520               Signpost Scarecrow                       4.0
# 521                 Sorcerer's Broom                       2.0
# 522               Sorcerous Spyglass                       2.0
# 523                   Spinning Wheel                       3.0
# 524                Stonecoil Serpent                       0.0
# 525                      Weapon Rack                       4.0
# 526                     Witch's Oven                       1.0
# 527                 Castle Ardenvale                       0.0
# 528                  Castle Embereth                       0.0
# 529                 Castle Garenbrig                       0.0
# 530                 Castle Locthwain                       0.0
# 531                  Castle Vantress                       0.0
# 532                     Dwarven Mine                       0.0
# 533                   Fabled Passage                       0.0
# 534                Gingerbread Cabin                       0.0
# 535                   Idyllic Grange                       0.0
# 536                 Mystic Sanctuary                       0.0
# 537               Tournament Grounds                       0.0
# 538                  Witch's Cottage                       0.0
# 539        Rowan, Fearless Sparkmage              R        5.0
# 540                 Garrison Griffin              W        3.0
# 541              Rowan's Battleguard              R        4.0
# 542                Rowan's Stalwarts              R        5.0
# 543                Wind-Scarred Crag                       0.0
# 544               Oko, the Trickster           G, U        6.0
# 545                Oko's Accomplices              U        3.0
# 546                 Bramblefort Fink              G        2.0
# 547                Oko's Hospitality           G, U        5.0
# 548                  Thornwood Falls                       0.0
# 549               Adaptive Shimmerer                       5.0
# 550                        Farfinder                       3.0
# 551                   Mysterious Egg                       1.0
# 552                     Blade Banish              W        4.0
# 553               Checkpoint Officer              W        2.0
# 554               Coordinated Charge              W        5.0
# 555                        Cubwarden              W        4.0
# 556                 Daysquad Marshal              W        4.0
# 557                     Divine Arrow              W        2.0
# 558                  Drannith Healer              W        2.0
# 559              Drannith Magistrate              W        2.0
# 560                     Fight as One              W        1.0
# 561                  Flourishing Fox              W        1.0
# 562                     Garrison Cat              W        1.0
# 563                    Helica Glider              W        3.0
# 564                 Huntmaster Liger              W        4.0
# 565               Imposing Vantasaur              W        6.0
# 566                 Keensight Mentor              W        3.0
# 567               Lavabrink Venturer              W        3.0
# 568                    Light of Hope              W        1.0
# 569               Luminous Broodmoth              W        4.0
# 570                Majestic Auricorn              W        5.0
# 571                     Maned Serval              W        2.0
# 572                Mythos of Snapdax              W        4.0
# 573                         Pacifism              W        2.0
# 574                    Patagia Tiger              W        5.0
# 575               Perimeter Sergeant              W        3.0
# 576               Sanctuary Lockdown              W        3.0
# 577                 Savai Sabertooth              W        2.0
# 578                  Snare Tactician              W        3.0
# 579                    Solid Footing              W        1.0
# 580                    Splendor Mare              W        3.0
# 581               Spontaneous Flight              W        3.0
# 582               Stormwild Capridor              W        3.0
# 583                    Swallow Whole              W        1.0
# 584                  Valiant Rescuer              W        2.0
# 585                        Vulpikeet              W        4.0
# 586           Will of the All-Hunter              W        2.0
# 587                     Aegis Turtle              U        1.0
# 588                       Anticipate              U        2.0
# 589                    Archipelagore              U        7.0
# 590                     Avian Oddity              U        4.0
# 591           Boon of the Wish-Giver              U        6.0
# 592                   Capture Sphere              U        4.0
# 593                        Convolute              U        3.0
# 594                       Crystacean              U        4.0
# 595                  Dreamtail Heron              U        5.0
# 596                  Escape Protocol              U        2.0
# 597                  Essence Scatter              U        2.0
# 598                     Facet Reader              U        2.0
# 599                       Frost Lynx              U        3.0
# 600                 Frostveil Ambush              U        5.0
# 601                      Glimmerbell              U        2.0
# 602                     Gust of Wind              U        4.0
# 603                  Hampering Snare              U        2.0
# 604                        Keep Safe              U        2.0
# 605                   Mystic Subdual              U        2.0
# 606                 Mythos of Illuna              U        4.0
# 607                       Neutralize              U        3.0
# 608                      Of One Mind              U        3.0
# 609                     Ominous Seas              U        2.0
# 610                    Phase Dolphin              U        3.0
# 611                Pollywog Symbiote              U        2.0
# 612              Pouncing Shoreshark              U        5.0
# 613           Reconnaissance Mission              U        4.0
# 614               Sea-Dasher Octopus              U        3.0
# 615                    Shark Typhoon              U        6.0
# 616            Startling Development              U        2.0
# 617                   Thieving Otter              U        3.0
# 618             Voracious Greatshark              U        5.0
# 619                  Wingfold Pteron              U        6.0
# 620                  Wingspan Mentor              U        3.0
# 621           Bastion of Remembrance              B        3.0
# 622                      Blitz Leech              B        6.0
# 623                     Blood Curdle              B        4.0
# 624                      Boot Nipper              B        2.0
# 625                 Bushmeat Poacher              B        4.0
# 626        Call of the Death-Dweller              B        3.0
# 627                 Cavern Whisperer              B        5.0
# 628             Chittering Harvester              B        6.0
# 629                     Corpse Churn              B        2.0
# 630                     Dark Bargain              B        4.0
# 631                      Dead Weight              B        1.0
# 632                        Dirge Bat              B        4.0
# 633                  Durable Coilbug              B        2.0
# 634                  Duskfang Mentor              B        3.0
# 635                        Easy Prey              B        2.0
# 636                 Extinction Event              B        4.0
# 637                   Gloom Pangolin              B        3.0
# 638                       Grimdancer              B        3.0
# 639                    Heartless Act              B        2.0
# 640                 Hunted Nightmare              B        3.0
# 641             Insatiable Hemophage              B        4.0
# 642                  Lurking Deadeye              B        4.0
# 643                      Memory Leak              B        3.0
# 644               Mutual Destruction              B        1.0
# 645                Mythos of Nethroi              B        3.0
# 646              Nightsquad Commando              B        3.0
# 647                Serrated Scorpion              B        1.0
# 648                Suffocating Fumes              B        3.0
# 649                 Unbreakable Bond              B        5.0
# 650                 Unexpected Fangs              B        2.0
# 651                     Unlikely Aid              B        2.0
# 652                    Void Beckoner              B        8.0
# 653                    Whisper Squad              B        1.0
# 654                     Zagoth Mamba              B        1.0
# 655                   Blazing Volley              R        1.0
# 656              Blisterspit Gremlin              R        1.0
# 657      Blitz of the Thunder-Raptor              R        2.0
# 658                Cathartic Reunion              R        2.0
# 659                  Clash of Titans              R        5.0
# 660                     Cloudpiercer              R        5.0
# 661                 Drannith Stinger              R        2.0
# 662                Everquill Phoenix              R        4.0
# 663              Ferocious Tigorilla              R        4.0
# 664                    Fire Prophecy              R        2.0
# 665                      Flame Spill              R        3.0
# 666                  Footfall Crater              R        1.0
# 667             Forbidden Friendship              R        2.0
# 668                  Frenzied Raptor              R        3.0
# 669                Frillscare Mentor              R        3.0
# 670                     Go for Blood              R        2.0
# 671              Heightened Reflexes              R        1.0
# 672                     Lava Serpent              R        6.0
# 673        Lukka, Coppercoat Outcast              R        5.0
# 674                 Momentum Rumbler              R        4.0
# 675                 Mythos of Vadrok              R        4.0
# 676                      Porcuparrot              R        4.0
# 677                 Prickly Marmoset              R        3.0
# 678                     Pyroceratops              R        4.0
# 679                     Raking Claws              R        2.0
# 680             Reptilian Reflection              R        3.0
# 681                   Rooting Moloch              R        5.0
# 682               Rumbling Rockslide              R        4.0
# 683                Sanctuary Smasher              R        6.0
# 684                   Shredded Sails              R        2.0
# 685             Spelleater Wolverine              R        3.0
# 686             Tentative Connection              R        4.0
# 687            Unpredictable Cyclone              R        5.0
# 688           Weaponize the Monsters              R        1.0
# 689        Yidaro, Wandering Monster              R        7.0
# 690              Adventurous Impulse              G        1.0
# 691               Almighty Brushwagg              G        1.0
# 692               Auspicious Starrix              G        5.0
# 693                   Barrier Breach              G        3.0
# 694                   Bristling Boar              G        4.0
# 695      Charge of the Forever-Beast              G        3.0
# 696                  Colossification              G        7.0
# 697                 Essence Symbiote              G        2.0
# 698                  Excavation Mole              G        3.0
# 699               Exuberant Wolfbear              G        4.0
# 700                         Fertilid              G        3.0
# 701              Flycatcher Giraffid              G        5.0
# 702                      Fully Grown              G        3.0
# 703                         Gemrazer              G        4.0
# 704                Glowstone Recluse              G        3.0
# 705                 Greater Sandwurm              G        7.0
# 706                    Honey Mammoth              G        6.0
# 707                  Hornbash Mentor              G        3.0
# 708                Humble Naturalist              G        2.0
# 709                    Ivy Elemental              G        1.0
# 710             Kogla, the Titan Ape              G        6.0
# 711                Lead the Stampede              G        3.0
# 712                   Migration Path              G        4.0
# 713              Migratory Greathorn              G        4.0
# 714                   Monstrous Step              G        5.0
# 715                  Mosscoat Goriak              G        3.0
# 716                Mythos of Brokkos              G        4.0
# 717                      Ram Through              G        2.0
# 718                Sudden Spinnerets              G        1.0
# 719                  Survivors' Bond              G        2.0
# 720                 Thwart the Enemy              G        3.0
# 721                     Titanoth Rex              G        9.0
# 722       Vivien, Monsters' Advocate              G        5.0
# 723                             Wilt              G        2.0
# 724                    Back for More           B, G        6.0
# 725                  Boneyard Lurker           B, G        4.0
# ...
# 2587                Instant
# 2588               Creature
# 2589            Enchantment
# 2590               Creature
# 2591            Enchantment
# 2592            Enchantment
# 2593               Creature
# 2594               Creature
# 2595               Creature
# 2596                Instant
# 2597               Creature
# 2598               Creature
# 2599                Instant
# 2600               Creature
# 2601               Artifact
# 2602               Creature
# 2603               Creature
# 2604               Creature
# 2605               Creature
# 2606                Instant
# 2607                Instant
# 2608                Instant
# 2609               Creature
# 2610                Instant
# 2611               Creature
# 2612                Instant
# 2613                Sorcery
# 2614               Creature
# 2615                Sorcery
# 2616               Creature
# 2617                Instant
# 2618               Artifact
# 2619               Creature
# 2620               Creature
# 2621               Creature
# 2622               Creature
# 2623               Creature
# 2624               Creature
# 2625               Creature
# 2626               Creature
# 2627               Creature
# 2628               Creature
# 2629                Sorcery
# 2630               Creature
# 2631               Creature
# 2632               Creature
# 2633               Creature
# 2634                Sorcery
# 2635               Creature
# 2636            Enchantment
# 2637                Sorcery
# 2638               Creature
# 2639               Creature
# 2640            Enchantment
# 2641               Creature
# 2642               Creature
# 2643                Sorcery
# 2644               Artifact
# 2645               Creature
# 2646               Creature
# 2647               Creature
# 2648                Instant
# 2649               Creature
# 2650               Creature
# 2651               Creature
# 2652                Instant
# 2653                Sorcery
# 2654               Creature
# 2655                Sorcery
# 2656               Creature
# 2657               Creature
# 2658               Creature
# 2659               Creature
# 2660               Creature
# 2661               Creature
# 2662           Planeswalker
# 2663               Creature
# 2664               Creature
# 2665                Instant
# 2666               Creature
# 2667                Sorcery
# 2668               Creature
# 2669               Creature
# 2670               Creature
# 2671                Instant
# 2672                Sorcery
# 2673               Creature
# 2674               Creature
# 2675                Sorcery
# 2676               Creature
# 2677               Creature
# 2678               Creature
# 2679               Creature
# 2680               Creature
# 2681                Sorcery
# 2682               Creature
# 2683           Planeswalker
# 2684                Sorcery
# 2685               Creature
# 2686            Enchantment
# 2687               Creature
# 2688               Creature
# 2689                Sorcery
# 2690               Creature
# 2691               Creature
# 2692               Creature
# 2693                Instant
# 2694               Creature
# 2695               Artifact
# 2696               Creature
# 2697               Creature
# 2698               Creature
# 2699                Sorcery
# 2700               Creature
# 2701               Creature
# 2702                Sorcery
# 2703               Creature
# 2704               Creature
# 2705               Creature
# 2706               Creature
# 2707               Creature
# 2708                Sorcery
# 2709               Creature
# 2710               Creature
# 2711                Sorcery
# 2712                Instant
# 2713               Creature
# 2714               Artifact
# 2715            Enchantment
# 2716                Instant
# 2717                Instant
# 2718               Creature
# 2719               Creature
# 2720               Creature
# 2721               Creature
# 2722               Creature
# 2723               Creature
# 2724               Creature
# 2725               Creature
# 2726               Creature
# 2727               Creature
# 2728               Creature
# 2729               Creature
# 2730                Sorcery
# 2731               Creature
# 2732               Creature
# 2733            Enchantment
# 2734                Instant
# 2735               Creature
# 2736               Creature
# 2737                Sorcery
# 2738            Enchantment
# 2739               Creature
# 2740               Creature
# 2741            Enchantment
# 2742               Creature
# 2743               Creature
# 2744               Creature
# 2745               Creature
# 2746            Enchantment
# 2747               Creature
# 2748               Creature
# 2749               Creature
# 2750               Creature
# 2751            Enchantment
# 2752                Instant
# 2753               Creature
# 2754                Sorcery
# 2755            Enchantment
# 2756               Creature
# 2757               Creature
# 2758               Creature
# 2759               Creature
# 2760                Sorcery
# 2761               Creature
# 2762               Creature
# 2763            Enchantment
# 2764               Artifact
# 2765                Sorcery
# 2766               Creature
# 2767               Creature
# 2768               Creature
# 2769               Creature
# 2770               Creature
# 2771               Creature
# 2772               Creature
# 2773                Instant
# 2774                Instant
# 2775               Creature
# 2776               Creature
# 2777               Creature
# 2778               Creature
# 2779               Creature
# 2780               Creature
# 2781            Enchantment
# 2782               Creature
# 2783               Creature
# 2784               Creature
# 2785            Enchantment
# 2786               Creature
# 2787               Artifact
# 2788               Creature
# 2789               Creature
# 2790               Creature
# 2791           Planeswalker
# 2792               Creature
# 2793               Creature
# 2794               Creature
# 2795               Creature
# 2796               Creature
# 2797               Creature
# 2798               Creature
# 2799               Creature
# 2800               Creature
# 2801               Creature
# 2802               Creature
# 2803               Creature
# 2804     Artifact, Creature
# 2805               Artifact
# 2806               Artifact
# 2807               Artifact
# 2808     Artifact, Creature
# 2809     Artifact, Creature
# 2810               Artifact
# 2811               Artifact
# 2812               Artifact
# 2813               Artifact
# 2814                   Land
# 2815                   Land
# 2816                   Land
# 2817                   Land
# 2818                   Land
# 2819                   Land
# 2820                Instant
# 2821               Creature
# 2822               Creature
# 2823               Creature
# 2824               Creature
# 2825               Creature
# 2826               Creature
# 2827               Creature
# 2828                Instant
# 2829                Instant
# 2830               Creature
# 2831                Sorcery
# 2832                   Land
# 2833               Creature
# 2834               Creature
# 2835               Creature
# 2836            Enchantment
# 2837            Enchantment
# 2838               Creature
# 2839                Instant
# 2840                   Land
# 2841               Creature
# 2842               Creature
# 2843               Creature
# 2844               Creature
# 2845               Creature
# 2846               Creature
# 2847                Sorcery
# 2848                   Land
# 2849               Artifact
# 2850               Creature
# 2851            Enchantment
# 2852                Sorcery
# 2853                   Land
# 2854               Creature
# 2855                Instant
# 2856                Instant
# 2857               Creature
# 2858                Instant
# 2859               Creature
# 2860                Instant
# 2861                   Land
# 2862               Creature
# 2863               Creature
# 2864               Creature
# 2865                   Land
# 2866               Creature
# 2867                Instant
# 2868               Creature
# 2869               Creature
# 2870                Instant
# 2871                Instant
# 2872                   Land
# 2873            Enchantment
# 2874               Creature
# 2875               Creature
# 2876                Instant
# 2877               Creature
# 2878                Instant
# 2879            Enchantment
# 2880               Creature
# 2881               Creature
# 2882                Instant
# 2883               Creature
# 2884                Sorcery
# 2885                Instant
# 2886               Creature
# 2887                   Land
# 2888                Sorcery
# 2889                Instant
# 2890           Planeswalker
# 2891                Instant
# 2892                   Land
# 2893               Creature
# 2894                Sorcery
# 2895                Sorcery
# 2896               Creature
# 2897               Creature
# 2898               Creature
# 2899                Instant
# 2900               Creature
# 2901               Creature
# 2902            Enchantment
# 2903               Creature
# 2904                Sorcery
# 2905                   Land
# 2906               Creature
# 2907               Creature
# 2908                Instant
# 2909                Instant
# 2910                   Land
# 2911                Sorcery
# 2912               Creature
# 2913               Creature
# 2914               Creature
# 2915               Creature
# 2916               Creature
# 2917                   Land
# 2918               Creature
# 2919               Creature
# 2920               Creature
# 2921                Sorcery
# 2922                   Land
# 2923               Creature
# 2924                   Land
# 2925                Sorcery
# 2926                Sorcery
# 2927                Sorcery
# 2928                Sorcery
# 2929                Instant
# 2930               Creature
# 2931               Creature
# 2932               Creature
# 2933               Creature
# 2934               Creature
# 2935                Sorcery
# 2936               Creature
# 2937               Creature
# 2938               Creature
# 2939                Instant
# 2940                   Land
# 2941               Creature
# 2942                Sorcery
# 2943            Enchantment
# 2944               Creature
# 2945                Instant
# 2946                   Land
# 2947               Creature
# 2948               Artifact
# 2949                Sorcery
# 2950               Creature
# 2951               Creature
# 2952               Creature
# 2953               Creature
# 2954                Instant
# 2955                Sorcery
# 2956                   Land
# 2957               Creature
# 2958               Creature
# 2959               Creature
# 2960                Sorcery
# 2961               Creature
# 2962               Creature
# 2963                Instant
# 2964                Instant
# 2965               Creature
# 2966                Sorcery
# 2967                Instant
# 2968                Sorcery
# 2969                   Land
# 2970               Creature
# 2971               Creature
# 2972                   Land
# 2973               Creature
# 2974                Instant
# 2975                Sorcery
# 2976               Creature
# 2977               Creature
# 2978               Creature
# 2979               Creature
# 2980               Creature
# 2981               Creature
# 2982                Instant
# 2983               Creature
# 2984                Instant
# 2985                   Land
# 2986               Creature
# 2987               Creature
# 2988                Instant
# 2989               Creature
# 2990                Sorcery
# 2991               Creature
# 2992               Creature
# 2993               Creature
# 2994                Sorcery
# 2995            Enchantment
# 2996               Artifact
# 2997               Creature
# 2998               Creature
# 2999               Creature
# 3000                Sorcery
# 3001                   Land
# 3002                Instant
# 3003               Creature
# 3004               Creature
# 3005                Sorcery
# 3006                   Land
# 3007                Instant
# 3008                   Land
# 3009               Creature
# 3010                Instant
# 3011               Creature
# 3012                Sorcery
# 3013               Creature
# 3014                Sorcery
# 3015               Creature
# 3016                Instant
# 3017                   Land
# 3018            Enchantment
# 3019               Creature
# 3020                Sorcery
# 3021               Creature
# 3022               Creature
# 3023                Sorcery
# 3024                   Land
# 3025               Creature
# 3026               Creature
# 3027               Creature
# 3028               Creature
# 3029                Instant
# 3030               Creature
# 3031               Creature
# 3032               Creature
# 3033                   Land
# 3034               Creature
# 3035               Creature
# 3036                Instant
# 3037                   Land
# 3038               Creature
# 3039                Instant
# 3040               Creature
# 3041               Creature
# 3042            Enchantment
# 3043               Creature
# 3044                Sorcery
# 3045                Sorcery
# 3046                Instant
# 3047                Sorcery
# 3048               Creature
# 3049               Artifact
# 3050               Creature
# 3051                Sorcery
# 3052               Creature
# 3053               Creature
# 3054               Creature
# 3055               Creature
# 3056               Creature
# 3057                   Land
# 3058               Creature
# 3059               Creature
# 3060               Creature
# 3061                Sorcery
# 3062                   Land
# 3063                Instant
# 3064                   Land
# 3065                Sorcery
# 3066               Creature
# 3067               Creature
# 3068               Creature
# 3069               Creature
# 3070               Creature
# 3071               Creature
# 3072               Creature
# 3073               Creature
# 3074               Creature
# 3075               Creature
# 3076               Creature
# 3077               Creature
# 3078           Planeswalker
# 3079           Planeswalker
# 3080               Creature
# 3081               Creature
# 3082               Creature
# 3083               Artifact
# 3084               Creature
# 3085                Instant
# 3086               Creature
# 3087               Creature
# 3088               Creature
# 3089               Creature
# 3090               Creature
# 3091               Artifact
# 3092               Artifact
# 3093               Artifact
# 3094     Artifact, Creature
# 3095               Artifact
# 3096               Artifact
# 3097     Artifact, Creature
# 3098               Artifact
# 3099     Artifact, Creature
# 3100               Artifact
# 3101     Artifact, Creature
# 3102               Artifact
# 3103     Artifact, Creature
# 3104               Artifact
# 3105                   Land
# 3106                   Land
# 3107                   Land
# 3108                   Land
# 3109                   Land
# 3110                   Land
# 3111                   Land
# 3112                   Land
# 3113                   Land
# 3114                   Land
# 3115                   Land
# 3116                   Land
# 3117                   Land
# 3118                   Land
# 3119                   Land
